# %% [markdown]
# ## Providence Hospital Provider Affiliation Web Scrape
#
# The goal of this project is to find all the provider info from the Providence FAP website (https://www.seton.net/providers/)
#
# Notes: the complete list of provider info is on that page; each bio page contains affiliation info; Same website structure as Seton (both Ascension hosps)
#
# ### Overview
# 1. Get all provider info from initial page
# 2. Use provider Roster to get individual provider page list
# 3. Scrape affiliation information from individual provider page
#
# ### STEP 1: Get all Provider Info/Roster

# %%
import pandas as pd
import time
import numpy as np

# %%
import requests
page = requests.get("https://www.providence.net/providers/")
page.status_code
# Out:
# 200

# %%
from bs4 import BeautifulSoup, CData
soup = BeautifulSoup(page.content, 'html.parser')

# %%
script = soup.findAll('script')

# %%
#all doc info in script[8]

#NOTE: the script has extra text; must be stripped
#start: <script type="text/javascript">
#//<![CDATA[
#RunGA = true;searchParams = {"SearchPhrase":"","GroupName":null,"SpecialtyName":null,"LastNameIs":null,"LastNameStartsWith":null,"IncludeMale":true,"IncludeFemale":true,"IncludeSFOD":false,"IncludeSHA":false,"IncludeC4T":false,"IncludeAccepting":false,"IncludePC":false,"LanguageName":null,"AffiliationName":null,"ProviderTypeName":null,"InsuranceName":null};defer(function() { jQuery(document).ready(function() {CheckMap(); }); });findADoctorResults = 
#end: ;//]]>
#</script>

import re
string = str(script[8])
stringlist1 = string.split('findADoctorResults = ')
stringlist1[0]
string2 = stringlist1[1]
stringlist2 = string2.split(';//]]')
stringlist2[1]
doclist = stringlist2[0]

# %%
#the remaining text is in JSON format; use pandas built-in function to convert to DF
fap_df = pd.read_json(doclist)

# %%
fap_df.head()
# Out:
#                                     AddressFormatted Associations Credentials  \
# 0  405 Londonderry Dr <br />Suite 105 <br />Waco,...          C4T          MD
# 1  7125 New Sanger Rd <br />Suite 516 <br />Waco,...           CE          MD
# 2  3445 Executive Center Dr. <br />Suite 250 <br ...                       MD
# 3  3000 N. IH 35 <br />Suite 700 <br />Austin, TX...                       MD
# 4  3000 North IH 35 <br />Suite 700 <br />Austin,...                       MD
#
#            DisplayName  Distance    FirstName  FirstNameID  \
# 0       Chidi Achilefu        -1        Chidi        chidi
# 1  Oluwarotimi Adesina        -1  Oluwarotimi  oluwarotimi
# 2        Joan Admirand        -1         Joan         joan
# 3        Amin Al-Ahmad        -1         Amin         amin
# 4        Amin Al-Ahmad        -1         Amin         amin
#
#                                               Groups  LastName LastNameID  \
# 0                Mid Tex Anesthesia Associates, P.A.  Achilefu   achilefu
# 1  Ascension Medical Group Providence Orthopedic ...   Adesina    adesina
# 2                      Clinical Pathology Associates  Admirand   admirand
# 3                           Texas Cardiac Arrhythmia  Al-Ahmad   al_ahmad
# 4                           Texas Cardiac Arrhythmia  Al-Ahmad   al_ahmad
#
#     Latitude  Longitude                                         MapAddress  \
# 0  31.513468  -97.19951        405 Londonderry Dr Suite 105 Waco, TX 76712
# 1  31.515670  -97.20348        7125 New Sanger Rd Suite 516 Waco, TX 76712
# 2  30.359690  -97.74781  3445 Executive Center Dr. Suite 250 Austin, TX...
# 3  30.227207  -97.74614           3000 N. IH 35 Suite 700 Austin, TX 78705
# 4  30.227186  -97.74618        3000 North IH 35 Suite 700 Austin, TX 78705
#
#   PhoneFormatted                            Specialties
# 0   254-776-0266                         Anesthesiology
# 1   254-752-9638                        Sports Medicine
# 2   512-579-4000                              Pathology
# 3   512-807-3150  Cardiology, Cardiac Electrophysiology
# 4   512-807-3150  Cardiology, Cardiac Electrophysiology

# %%
#check structure
print(fap_df.shape)
print(fap_df.columns)
# Out:
# (3385, 15)
# Index(['AddressFormatted', 'Associations', 'Credentials', 'DisplayName',
#        'Distance', 'FirstName', 'FirstNameID', 'Groups', 'LastName',
#        'LastNameID', 'Latitude', 'Longitude', 'MapAddress', 'PhoneFormatted',
#        'Specialties'],
#       dtype='object')

# %% [markdown]
# #### Write out the Roster Scrape to xlsx

# %%
# Create a Pandas Excel writer using XlsxWriter as the engine.
writer = pd.ExcelWriter('ProvidenceRoster_20190815.xlsx', engine='xlsxwriter')

# Convert the dataframe to an XlsxWriter Excel object.
fap_df.to_excel(writer, sheet_name='RosterResults')

# Close the Pandas Excel writer and output the Excel file.
writer.save()

# %% [markdown]
# #### Hospital Specialties
#
# For this project, we are only interested in getting affiliation information for facility-based specialties: Anesthesiology, Radiology, Pathology, Neonatology, and Emergency Medicine. See also: any doc listed as a form of Hospitalist.
#
# Each hospital website has slightly different specialties listed.  Here, I manually curate the list of specialties I want to scrape.

# %%
fap_df['Specialties'].value_counts()
# Out:
# Family Medicine                                                                  72
#                                                                                  51
# Emergency Medicine                                                               39
# Pathology                                                                        28
# Anesthesiology                                                                   20
# Nephrology                                                                       13
# Cardiology, Internal Medicine, Cardiac Electrophysiology                         12
# Cardiology                                                                       11
# Pulmonary Disease, Sleep Medicine, Critical Care Medicine, Pulmonary Medicine    11
# Hospitalist                                                                      10
# Obstetrics and Gynecology, Gynecology                                             8
# Radiology                                                                         8
# Orthopedics, Sports Medicine                                                      8
# General Surgery                                                                   7
# Pulmonary Disease, Critical Care Medicine, Pulmonary Medicine                     6
# Urology                                                                           6
# Internal Medicine                                                                 6
# Urgent Care                                                                       5
# Podiatry                                                                          5
# Pulmonary Medicine                                                                5
# Cardiology, Cardiac Electrophysiology                                             4
# Neurosurgery                                                                      4
# Pediatrics, Pediatric Emergency Medicine, Emergency Medicine                      4
# Pediatrics                                                                        4
# Psychiatry                                                                        4
# Psychiatry, Psychiatry (General)/Child & Adolescent Psychiatry                    3
# Thoracic Surgery, Vascular Surgery                                                3
# Cardiac Electrophysiology                                                         3
# Ophthalmology                                                                     2
# Radiology, Neuroradiology                                                         2
# Pediatric Emergency Medicine, Emergency Medicine                                  2
# Emergency Medicine, Pediatrics                                                    2
# Sleep Medicine                                                                    1
# General Surgery, Vascular Surgery                                                 1
# Wound Care                                                                        1
# Pain Management, Anesthesiology                                                   1
# Gynecology                                                                        1
# Gastroenterology                                                                  1
# Hospitalist, Family Medicine                                                      1
# Dermatology, Pathology                                                            1
# Endocrinology, Diabetes & Metabolism                                              1
# Podiatry, Wound Care                                                              1
# Sports Medicine                                                                   1
# Orthopedics, Orthopedic Traumatology                                              1
# Name: Specialties, dtype: int64

# %%
#make list of hospital specialties to scrape
hosp_specs = ['Pathology','Anesthesiology','Hospitalist','Radiology','Radiology, Neuroradiology','Pediatric Emergency Medicine, Emergency Medicine','Emergency Medicine, Pediatrics','Pain Management, Anesthesiology','Hospitalist, Family Medicine']

# %%
#subset roster for all hosp spec docs
hospSpecFAP_df = fap_df[fap_df.Specialties.isin(hosp_specs)]
hospSpecFAP_df.head()
# Out:
#                                      AddressFormatted Associations  \
# 0   405 Londonderry Dr <br />Suite 105 <br />Waco,...          C4T
# 2   3445 Executive Center Dr. <br />Suite 250 <br ...
# 35          6901 Medical Parkway <br />Waco, TX 76712
# 36  6300 La Calma Dr. <br />Suite 200 <br />Austin...
# 38          6901 Medical Parkway <br />Waco, TX 76712          C4T
#
#    Credentials     DisplayName  Distance FirstName FirstNameID  \
# 0           MD  Chidi Achilefu        -1     Chidi       chidi
# 2           MD   Joan Admirand        -1      Joan        joan
# 35          MD   Kathleen Berg        -1  Kathleen    kathleen
# 36          MD   Kathleen Berg        -1  Kathleen    kathleen
# 38          DO      John Biboa        -1      John        john
#
#                                                Groups  LastName LastNameID  \
# 0                 Mid Tex Anesthesia Associates, P.A.  Achilefu   achilefu
# 2                       Clinical Pathology Associates  Admirand   admirand
# 35  US Acute Care Solutions, US Acute Care Solutio...      Berg       berg
# 36  US Acute Care Solutions, US Acute Care Solutio...      Berg       berg
# 38         McLennan County Hospitalist Services, P.C.     Biboa      biboa
#
#      Latitude  Longitude                                         MapAddress  \
# 0   31.513468 -97.199510        405 Londonderry Dr Suite 105 Waco, TX 76712
# 2   30.359690 -97.747810  3445 Executive Center Dr. Suite 250 Austin, TX...
# 35  31.514454 -97.199490                6901 Medical Parkway Waco, TX 76712
# 36  30.324444 -97.703026       6300 La Calma Dr. Suite 200 Austin, TX 78752
# 38  31.514465 -97.199530                6901 Medical Parkway Waco, TX 76712
#
#    PhoneFormatted                                       Specialties
# 0    254-776-0266                                    Anesthesiology
# 2    512-579-4000                                         Pathology
# 35   254-751-4180  Pediatric Emergency Medicine, Emergency Medicine
# 36   512-452-8533  Pediatric Emergency Medicine, Emergency Medicine
# 38   254-751-4551                                       Hospitalist

# %%
seven_day = soup.find(id="seven-day-forecast")
name_tags = seven_day.select(".fad-result-info .fad-result-name")
periods = [pt.get_text() for pt in period_tags]

# %% [markdown]
# ### STEP 2: Get Affiliations from each doc's bio page
#
# Once we have the hosp spec roster, I will use those doc names and individual provider websites to scrape affiliation data for each page.

# %%
#url structure "https://www.providence.net/providers/bio/kameron-harrison"

# %%
#testing example

#Chidi Achilefu
firstname = "Chidi"
lastname = "Achilefu"

url = "https://www.providence.net/providers/bio/" + firstname + "-" + lastname
docpage = requests.get(url)
print(docpage.status_code)
soup = BeautifulSoup(docpage.content, 'html5lib')
affiliations = soup.find(id="physicianAffiliations")
affil_tags = affiliations.select(".affiliation")
doc_affils = [at.get_text().rstrip().strip() for at in affil_tags]
doc_affils
# Out:
# 200
# ['Providence Health Center']

# %%
#define web scrape function

def doc_affils(dataframe):
    affil_list = []
    seconds = 2 #define seconds to wait between get requests
    for index, row in dataframe.iterrows():
        firstname = row['FirstNameID']
        lastname = row['LastNameID']
        url = "https://www.providence.net/providers/bio/" + firstname + "-" + lastname #concat url
        docpage = requests.get(url,time.sleep(seconds)) #get html from url, with delay to prevent website blacklisting
        print(docpage.status_code)
        soup = BeautifulSoup(docpage.content, 'html5lib') #parse html with BeautifulSoup
        affiliations = soup.find(id="physicianAffiliations") #find physicianAffiliations section of website
        try: 
            affil_tags = affiliations.select(".affiliation") #get all affiliations via affiliation ids
            doc_affils1 = [at.get_text().rstrip().strip() for at in affil_tags] #get text and strip whitespace
            dict1 = {'firstName': firstname, 'lastName': lastname, 'hospitalAffiliations': doc_affils1} #make name and affils into dictionary
            affil_list.append(dict1)
            print("Added Affil for "+firstname+" "+lastname)
        except:
            pass
            print("Affil ERROR for"+firstname+" "+lastname)
    return(affil_list)

# %% [markdown]
# #### Provider page affil scrape test

# %%
test = hospSpecFAP_df.iloc[0:10, :]

# %%
test_list = doc_affils(test)
pd.DataFrame(test_list)
# Out:
# 200
# Added Affil for chidi achilefu
# 200
# Added Affil for joan admirand
# 200
# Added Affil for kathleen berg
# 200
# Added Affil for kathleen berg
# 200
# Added Affil for john biboa
# 200
# Added Affil for adam borowski
# 200
# Added Affil for steven burgard
# 200
# Added Affil for larry cartmell
# 200
# Added Affil for larry cartmell
# 200
# Added Affil for cary chisholm
#   firstName        hospitalAffiliations  lastName
# 0     chidi  [Providence Health Center]  achilefu
# 1      joan  [Providence Health Center]  admirand
# 2  kathleen  [Providence Health Center]      berg
# 3  kathleen  [Providence Health Center]      berg
# 4      john  [Providence Health Center]     biboa
# 5      adam  [Providence Health Center]  borowski
# 6    steven  [Providence Health Center]   burgard
# 7     larry  [Providence Health Center]  cartmell
# 8     larry  [Providence Health Center]  cartmell
# 9      cary  [Providence Health Center]  chisholm

# %% [markdown]
# ### Get that data!

# %%
prov_affil_list = doc_affils(hospSpecFAP_df)
# Out:
# 200
# Added Affil for chidi achilefu
# 200
# Added Affil for joan admirand
# 200
# Added Affil for kathleen berg
# 200
# Added Affil for kathleen berg
# 200
# Added Affil for john biboa
# 200
# Added Affil for adam borowski
# 200
# Added Affil for steven burgard
# 200
# Added Affil for larry cartmell
# 200
# Added Affil for larry cartmell
# 200
# Added Affil for cary chisholm
# 200
# Added Affil for g clark
# 200
# Added Affil for amy coffey
# 200
# Added Affil for holly davis
# 200
# Added Affil for larry davis
# 200
# Added Affil for nelson destaffany
# 200
# Added Affil for tamara dutter
# 200
# Added Affil for steven elwell
# 200
# Added Affil for gary fischer
# 200
# Added Affil for nathan forrest
# 200
# Added Affil for paul gaudin
# 200
# Added Affil for gary geldmeier
# 200
# Added Affil for gary geldmeier
# 200
# Added Affil for james goodsett
# 200
# Added Affil for christopher greener
# 200
# Added Affil for rebecca guess
# 200
# Added Affil for casey hector
# 200
# Added Affil for r hendricks
# 200
# Added Affil for eric higginbotham
# 200
# Added Affil for eric higginbotham
# 200
# Added Affil for adam johnson
# 200
# Added Affil for adam johnson
# 200
# Added Affil for mark johnson
# 200
# Added Affil for soni jose
# 200
# Added Affil for james kavanagh
# 200
# Added Affil for howard klaskin
# 200
# Added Affil for timothy kolda
# 200
# Added Affil for chandra krishnan
# 200
# Added Affil for chandra krishnan
# 200
# Added Affil for brent kutach
# 200
# Added Affil for benjamin lagrone
# 200
# Added Affil for suzanne ledet
# 200
# Added Affil for derek lee
# 200
# Added Affil for jeffrey manning
# 200
# Added Affil for amy mccourt
# 200
# Added Affil for douglas michaels
# 200
# Added Affil for douglas michaels
# 200
# Added Affil for gregory newman
# 200
# Added Affil for alan northcutt
# 200
# Added Affil for alan northcutt
# 200
# Added Affil for james olmsted
# 200
# Added Affil for susan pacinda
# 200
# Added Affil for dennis parks
# 200
# Added Affil for erin prince
# 200
# Added Affil for amanda rivera_begeman
# 200
# Added Affil for claudius robinson
# 200
# Added Affil for claudius robinson
# 200
# Added Affil for roxann samples
# 200
# Added Affil for roxann samples
# 200
# Added Affil for timothy schmidt
# 200
# Added Affil for barry shefa
# 200
# Added Affil for daniel smith
# 200
# Added Affil for daniel smith
# 200
# Added Affil for kathleen sorensen
# 200
# Added Affil for horacio sosa
# 200
# Added Affil for michael teichelmann
# 200
# Affil ERROR forchristopher thompson
# 200
# Affil ERROR forchristopher thompson
# 200
# Added Affil for gustavo villarreal
# 200
# Added Affil for min wang
# 200
# Added Affil for ann white
# 200
# Added Affil for jeffery white
# 200
# Affil ERROR forthomas white
# 200
# Added Affil for eliot wickliff
# 200
# Added Affil for roger williams

# %%
#convert to pandas df
Affils_df = pd.DataFrame(prov_affil_list)

# %%
#join scraped affils back to roster
FAP_with_affils = pd.merge(hospSpecFAP_df, Affils_df,
              left_on=['FirstNameID', 'LastNameID'],
              right_on=['firstName', 'lastName'],
              how='left')

# %%
#check structure
FAP_with_affils.columns
# Out:
# Index(['AddressFormatted', 'Associations', 'Credentials', 'DisplayName',
#        'Distance', 'FirstName', 'FirstNameID', 'Groups', 'LastName',
#        'LastNameID', 'Latitude', 'Longitude', 'MapAddress', 'PhoneFormatted',
#        'Specialties', 'firstName', 'hospitalAffiliations', 'lastName'],
#       dtype='object')

# %%
FAP_with_affils
# Out:
#                                      AddressFormatted Associations  \
# 0   405 Londonderry Dr <br />Suite 105 <br />Waco,...          C4T
# 1   3445 Executive Center Dr. <br />Suite 250 <br ...
# 2           6901 Medical Parkway <br />Waco, TX 76712
# 3           6901 Medical Parkway <br />Waco, TX 76712
# 4   6300 La Calma Dr. <br />Suite 200 <br />Austin...
# 5   6300 La Calma Dr. <br />Suite 200 <br />Austin...
# 6           6901 Medical Parkway <br />Waco, TX 76712          C4T
# 7           6901 Medical Parkway <br />Waco, TX 76712          C4T
# 8   405 Londonderry Dr <br />Suite 105 <br />Waco,...          C4T
# 9   601 West State Highway 6 <br />Suite 111 <br /...          C4T
# 10  601 West State Highway 6 <br />Suite 111 <br /...          C4T
# 11          6901 Medical Parkway <br />Waco, TX 76712          C4T
# 12          6901 Medical Parkway <br />Waco, TX 76712          C4T
# 13            7106 Sanger Avenue <br />Waco, TX 76712          C4T
# 14          6901 Medical Parkway <br />Waco, TX 76712          C4T
# 15  3445 Executive Center Dr. <br />Suite 250 <br ...
# 16  405 Londonderry Dr <br />Suite 105 <br />Waco,...          C4T
# 17          6901 Medical Parkway <br />Waco, TX 76712          C4T
# 18  405 Londonderry Dr <br />Suite 105 <br />Waco,...          C4T
# 19  405 Londonderry Dr <br />Suite 105 <br />Waco,...          C4T
# 20          6901 Medical Parkway <br />Waco, TX 76712          C4T
# 21  405 Londonderry Dr <br />Suite 105 <br />Waco,...          C4T
# 22          6901 Medical Parkway <br />Waco, TX 76712          C4T
# 23  3445 Executive Center Dr. <br />Suite 250 <br ...
# 24  601 West State Highway 6 <br />Suite 111 <br /...          C4T
# 25  601 West State Highway 6 <br />Suite 111 <br /...          C4T
# 26          6901 Medical Parkway <br />Waco, TX 76712          C4T
# 27          6901 Medical Parkway <br />Waco, TX 76712          C4T
# 28          6901 Medical Parkway <br />Waco, TX 76712          C4T
# 29  405 Londonderry Dr <br />Suite 105 <br />Waco,...          C4T
# ..                                                ...          ...
# 66  3445 Executive Center Dr. <br />Suite 250 <br ...
# 67          6901 Medical Parkway <br />Waco, TX 76712          C4T
# 68          6901 Medical Parkway <br />Waco, TX 76712          C4T
# 69  3445 Executive Center Dr. <br />Suite 250 <br ...
# 70  601 West State Highway 6 <br />Suite 111 <br /...          C4T
# 71  601 West State Highway 6 <br />Suite 111 <br /...          C4T
# 72          6901 Medical Parkway <br />Waco, TX 76712          C4T
# 73          6901 Medical Parkway <br />Waco, TX 76712          C4T
# 74          6901 Medical Parkway <br />Waco, TX 76712      C4T, CE
# 75          6901 Medical Parkway <br />Waco, TX 76712      C4T, CE
# 76  301 Londonderry @ DePaul Center <br />Waco, TX...      C4T, CE
# 77  301 Londonderry @ DePaul Center <br />Waco, TX...      C4T, CE
# 78  405 Londonderry Dr <br />Suite 105 <br />Waco,...          C4T
# 79          6901 Medical Parkway <br />Waco, TX 76712          C4T
# 80  601 West Highway 6 <br />Suite 111 <br />Waco,...          C4T
# 81  601 West Highway 6 <br />Suite 111 <br />Waco,...          C4T
# 82          6901 Medical Parkway <br />Waco, TX 76712          C4T
# 83          6901 Medical Parkway <br />Waco, TX 76712          C4T
# 84          6901 Medical Parkway <br />Waco, TX 76712          C4T
# 85          6901 Medical Parkway <br />Waco, TX 76712
# 86  405 Londonderry Dr <br />Suite 105 <br />Waco,...          C4T
# 87  601 West Highway 6 <br />Suite 111 <br />Waco,...          C4T
# 88          6901 Medical Parkway <br />Waco, TX 76712          C4T
# 89          6901 Medical Parkway <br />Waco, TX 76712          C4T
# 90  3445 Executive Center Dr. <br />Suite 250 <br ...
# 91  3445 Executive Center Dr. <br />Suite 250 <br ...
# 92          6901 Medical Parkway <br />Waco, TX 76712          C4T
# 93  405 Londonderry Dr <br />Suite 105 <br />Waco,...          C4T
# 94  405 Londonderry Dr <br />Suite 311 <br />Waco,...      C4T, CE
# 95  405 Londonderry Dr <br />Suite 105 <br />Waco,...          C4T
#
#    Credentials            DisplayName  Distance    FirstName  FirstNameID  \
# 0           MD         Chidi Achilefu        -1        Chidi        chidi
# 1           MD          Joan Admirand        -1         Joan         joan
# 2           MD          Kathleen Berg        -1     Kathleen     kathleen
# 3           MD          Kathleen Berg        -1     Kathleen     kathleen
# 4           MD          Kathleen Berg        -1     Kathleen     kathleen
# 5           MD          Kathleen Berg        -1     Kathleen     kathleen
# 6           DO             John Biboa        -1         John         john
# 7           MD          Adam Borowski        -1         Adam         adam
# 8           MD         Steven Burgard        -1       Steven       steven
# 9           MD         Larry Cartmell        -1        Larry        larry
# 10          MD         Larry Cartmell        -1        Larry        larry
# 11          MD         Larry Cartmell        -1        Larry        larry
# 12          MD         Larry Cartmell        -1        Larry        larry
# 13          MD          Cary Chisholm        -1         Cary         cary
# 14     MD, PhD               G. Clark        -1           G.            g
# 15          MD             Amy Coffey        -1          Amy          amy
# 16          MD            Holly Davis        -1        Holly        holly
# 17          MD            Larry Davis        -1        Larry        larry
# 18          MD      Nelson DeStaffany        -1       Nelson       nelson
# 19          MD          Tamara Dutter        -1       Tamara       tamara
# 20          MD          Steven Elwell        -1       Steven       steven
# 21          MD           Gary Fischer        -1         Gary         gary
# 22          DO         Nathan Forrest        -1       Nathan       nathan
# 23          MD            Paul Gaudin        -1         Paul         paul
# 24          MD         Gary Geldmeier        -1         Gary         gary
# 25          MD         Gary Geldmeier        -1         Gary         gary
# 26          MD         Gary Geldmeier        -1         Gary         gary
# 27          MD         Gary Geldmeier        -1         Gary         gary
# 28          MD         James Goodsett        -1        James        james
# 29          MD    Christopher Greener        -1  Christopher  christopher
# ..         ...                    ...       ...          ...          ...
# 66          MD          Susan Pacinda        -1        Susan        susan
# 67          MD           Dennis Parks        -1       Dennis       dennis
# 68          MD            Erin Prince        -1         Erin         erin
# 69          DO  Amanda Rivera-Begeman        -1       Amanda       amanda
# 70          MD      Claudius Robinson        -1     Claudius     claudius
# 71          MD      Claudius Robinson        -1     Claudius     claudius
# 72          MD      Claudius Robinson        -1     Claudius     claudius
# 73          MD      Claudius Robinson        -1     Claudius     claudius
# 74          MD         Roxann Samples        -1       Roxann       roxann
# 75          MD         Roxann Samples        -1       Roxann       roxann
# 76          MD         Roxann Samples        -1       Roxann       roxann
# 77          MD         Roxann Samples        -1       Roxann       roxann
# 78          MD        Timothy Schmidt        -1      Timothy      timothy
# 79          MD            Barry Shefa        -1        Barry        barry
# 80          DO           Daniel Smith        -1       Daniel       daniel
# 81          DO           Daniel Smith        -1       Daniel       daniel
# 82          DO           Daniel Smith        -1       Daniel       daniel
# 83          DO           Daniel Smith        -1       Daniel       daniel
# 84          MD      Kathleen Sorensen        -1     Kathleen     kathleen
# 85          DO           Horacio Sosa        -1      Horacio      horacio
# 86          MD    Michael Teichelmann        -1      Michael      michael
# 87          MD   Christopher Thompson        -1  Christopher  christopher
# 88          MD   Christopher Thompson        -1  Christopher  christopher
# 89          MD     Gustavo Villarreal        -1      Gustavo      gustavo
# 90          MD               Min Wang        -1          Min          min
# 91          MD              Ann White        -1          Ann          ann
# 92          MD          Jeffery White        -1      Jeffery      jeffery
# 93          MD           Thomas White        -1       Thomas       thomas
# 94          MD         Eliot Wickliff        -1        Eliot        eliot
# 95          MD         Roger Williams        -1        Roger        roger
#
#                                                Groups        LastName  \
# 0                 Mid Tex Anesthesia Associates, P.A.        Achilefu
# 1                       Clinical Pathology Associates        Admirand
# 2   US Acute Care Solutions, US Acute Care Solutio...            Berg
# 3   US Acute Care Solutions, US Acute Care Solutio...            Berg
# 4   US Acute Care Solutions, US Acute Care Solutio...            Berg
# 5   US Acute Care Solutions, US Acute Care Solutio...            Berg
# 6          McLennan County Hospitalist Services, P.C.           Biboa
# 7                                Waco Radiology, P.A.        Borowski
# 8                 Mid Tex Anesthesia Associates, P.A.         Burgard
# 9            Central Texas Pathology Laboratory, P.A.        Cartmell
# 10           Central Texas Pathology Laboratory, P.A.        Cartmell
# 11           Central Texas Pathology Laboratory, P.A.        Cartmell
# 12           Central Texas Pathology Laboratory, P.A.        Cartmell
# 13                         Epiphany Dermatology, P.A.        Chisholm
# 14         McLennan County Hospitalist Services, P.C.           Clark
# 15                      Clinical Pathology Associates          Coffey
# 16                Mid Tex Anesthesia Associates, P.A.           Davis
# 17         McLennan County Hospitalist Services, P.C.           Davis
# 18                Mid Tex Anesthesia Associates, P.A.      DeStaffany
# 19                Mid Tex Anesthesia Associates, P.A.          Dutter
# 20         McLennan County Hospitalist Services, P.C.          Elwell
# 21                Mid Tex Anesthesia Associates, P.A.         Fischer
# 22                               Waco Radiology, P.A.         Forrest
# 23                      Clinical Pathology Associates          Gaudin
# 24           Central Texas Pathology Laboratory, P.A.       Geldmeier
# 25           Central Texas Pathology Laboratory, P.A.       Geldmeier
# 26           Central Texas Pathology Laboratory, P.A.       Geldmeier
# 27           Central Texas Pathology Laboratory, P.A.       Geldmeier
# 28         McLennan County Hospitalist Services, P.C.        Goodsett
# 29                Mid Tex Anesthesia Associates, P.A.         Greener
# ..                                                ...             ...
# 66                      Clinical Pathology Associates         Pacinda
# 67                               Waco Radiology, P.A.           Parks
# 68                               Waco Radiology, P.A.          Prince
# 69                      Clinical Pathology Associates  Rivera-Begeman
# 70           Central Texas Pathology Laboratory, P.A.        Robinson
# 71           Central Texas Pathology Laboratory, P.A.        Robinson
# 72           Central Texas Pathology Laboratory, P.A.        Robinson
# 73           Central Texas Pathology Laboratory, P.A.        Robinson
# 74     McLennan County Hospitalist Services, P.C./PHA         Samples
# 75     McLennan County Hospitalist Services, P.C./PHA         Samples
# 76     McLennan County Hospitalist Services, P.C./PHA         Samples
# 77     McLennan County Hospitalist Services, P.C./PHA         Samples
# 78                Mid Tex Anesthesia Associates, P.A.         Schmidt
# 79         McLennan County Hospitalist Services, P.C.           Shefa
# 80           Central Texas Pathology Laboratory, P.A.           Smith
# 81           Central Texas Pathology Laboratory, P.A.           Smith
# 82           Central Texas Pathology Laboratory, P.A.           Smith
# 83           Central Texas Pathology Laboratory, P.A.           Smith
# 84                               Waco Radiology, P.A.        Sorensen
# 85         McLennan County Hospitalist Services, P.C.            Sosa
# 86                Mid Tex Anesthesia Associates, P.A.     Teichelmann
# 87           Central Texas Pathology Laboratory, P.A.        Thompson
# 88           Central Texas Pathology Laboratory, P.A.        Thompson
# 89                               Waco Radiology, P.A.      Villarreal
# 90                      Clinical Pathology Associates            Wang
# 91                      Clinical Pathology Associates           White
# 92                               Waco Radiology, P.A.           White
# 93                Mid Tex Anesthesia Associates, P.A.           White
# 94  Ascension Medical Group Providence Pain Manage...        Wickliff
# 95                Mid Tex Anesthesia Associates, P.A.        Williams
#
#         LastNameID   Latitude     Longitude  \
# 0         achilefu  31.513468 -9.719951e+01
# 1         admirand  30.359690 -9.774781e+01
# 2             berg  31.514454 -9.719949e+01
# 3             berg  31.514454 -9.719949e+01
# 4             berg  30.324444 -9.770303e+01
# 5             berg  30.324444 -9.770303e+01
# 6            biboa  31.514465 -9.719953e+01
# 7         borowski  31.514418 -9.719958e+01
# 8          burgard  31.513401 -9.719957e+01
# 9         cartmell  -0.000039 -1.739128e-05
# 10        cartmell  -0.000039 -1.739128e-05
# 11        cartmell  31.514418 -9.719958e+01
# 12        cartmell  31.514418 -9.719958e+01
# 13        chisholm  31.517200 -9.720391e+01
# 14           clark  31.514444 -9.719958e+01
# 15          coffey  30.359714 -9.774786e+01
# 16           davis  31.513473 -9.719955e+01
# 17           davis  31.514433 -9.719957e+01
# 18      destaffany  31.513422 -9.719955e+01
# 19          dutter  31.513466 -9.719950e+01
# 20          elwell  31.514471 -9.719958e+01
# 21         fischer  31.513388 -9.719952e+01
# 22         forrest  31.514397 -9.719952e+01
# 23          gaudin  30.359667 -9.774786e+01
# 24       geldmeier   0.000005  1.313920e-07
# 25       geldmeier   0.000005  1.313920e-07
# 26       geldmeier  31.514414 -9.719953e+01
# 27       geldmeier  31.514414 -9.719953e+01
# 28        goodsett  31.514473 -9.719954e+01
# 29         greener  31.513403 -9.719954e+01
# ..             ...        ...           ...
# 66         pacinda  30.359657 -9.774784e+01
# 67           parks  31.514427 -9.719956e+01
# 68          prince  31.514488 -9.719952e+01
# 69  rivera_begeman  30.359703 -9.774787e+01
# 70        robinson  -0.000008 -9.759204e-06
# 71        robinson  -0.000008 -9.759204e-06
# 72        robinson  31.514427 -9.719953e+01
# 73        robinson  31.514427 -9.719953e+01
# 74         samples  31.514400 -9.719949e+01
# 75         samples  31.514400 -9.719949e+01
# 76         samples  31.510996 -9.719836e+01
# 77         samples  31.510996 -9.719836e+01
# 78         schmidt  31.513441 -9.719955e+01
# 79           shefa  31.514431 -9.719958e+01
# 80           smith  31.516794 -9.719917e+01
# 81           smith  31.516794 -9.719917e+01
# 82           smith  31.514412 -9.719958e+01
# 83           smith  31.514412 -9.719958e+01
# 84        sorensen  31.514452 -9.719956e+01
# 85            sosa  31.514433 -9.719957e+01
# 86     teichelmann  31.513437 -9.719949e+01
# 87        thompson  31.516760 -9.719919e+01
# 88        thompson  31.514458 -9.719952e+01
# 89      villarreal  31.514479 -9.719951e+01
# 90            wang  30.359667 -9.774784e+01
# 91           white  30.359732 -9.774785e+01
# 92           white  31.514427 -9.719958e+01
# 93           white  31.513450 -9.719950e+01
# 94        wickliff  31.513382 -9.719956e+01
# 95        williams  31.513400 -9.719953e+01
#
#                                            MapAddress PhoneFormatted  \
# 0         405 Londonderry Dr Suite 105 Waco, TX 76712   254-776-0266
# 1   3445 Executive Center Dr. Suite 250 Austin, TX...   512-579-4000
# 2                 6901 Medical Parkway Waco, TX 76712   254-751-4180
# 3                 6901 Medical Parkway Waco, TX 76712   254-751-4180
# 4        6300 La Calma Dr. Suite 200 Austin, TX 78752   512-452-8533
# 5        6300 La Calma Dr. Suite 200 Austin, TX 78752   512-452-8533
# 6                 6901 Medical Parkway Waco, TX 76712   254-751-4551
# 7                 6901 Medical Parkway Waco, TX 76712   254-751-4299
# 8         405 Londonderry Dr Suite 105 Waco, TX 76712   254-776-0266
# 9   601 West State Highway 6 Suite 111 Waco, TX 76...   254-752-9621
# 10  601 West State Highway 6 Suite 111 Waco, TX 76...   254-752-9621
# 11                6901 Medical Parkway Waco, TX 76712   254-751-4719
# 12                6901 Medical Parkway Waco, TX 76712   254-751-4719
# 13                  7106 Sanger Avenue Waco, TX 76712   254-537-1265
# 14                6901 Medical Parkway Waco, TX 76712   254-751-4551
# 15  3445 Executive Center Dr. Suite 250 Austin, TX...   512-579-4000
# 16        405 Londonderry Dr Suite 105 Waco, TX 76712   254-776-0266
# 17                6901 Medical Parkway Waco, TX 76712   254-751-4551
# 18        405 Londonderry Dr Suite 105 Waco, TX 76712   254-776-0266
# 19        405 Londonderry Dr Suite 105 Waco, TX 76712   254-776-0266
# 20                6901 Medical Parkway Waco, TX 76712   254-751-4551
# 21        405 Londonderry Dr Suite 105 Waco, TX 76712   254-776-0266
# 22                6901 Medical Parkway Waco, TX 76712   254-751-4299
# 23  3445 Executive Center Dr. Suite 250 Austin, TX...   512-579-4000
# 24  601 West State Highway 6 Suite 111 Waco, TX 76...   254-752-9621
# 25  601 West State Highway 6 Suite 111 Waco, TX 76...   254-752-9621
# 26                6901 Medical Parkway Waco, TX 76712   254-751-4719
# 27                6901 Medical Parkway Waco, TX 76712   254-751-4719
# 28                6901 Medical Parkway Waco, TX 76712   254-751-4551
# 29        405 Londonderry Dr Suite 105 Waco, TX 76712   254-776-0266
# ..                                                ...            ...
# 66  3445 Executive Center Dr. Suite 250 Austin, TX...   512-579-4000
# 67                6901 Medical Parkway Waco, TX 76712   254-751-4299
# 68                6901 Medical Parkway Waco, TX 76712   254-751-4299
# 69  3445 Executive Center Dr. Suite 250 Austin, TX...   512-579-4000
# 70  601 West State Highway 6 Suite 111 Waco, TX 76...   254-752-9621
# 71  601 West State Highway 6 Suite 111 Waco, TX 76...   254-752-9621
# 72                6901 Medical Parkway Waco, TX 76712   254-751-4719
# 73                6901 Medical Parkway Waco, TX 76712   254-751-4719
# 74                6901 Medical Parkway Waco, TX 76712   254-751-4551
# 75                6901 Medical Parkway Waco, TX 76712   254-751-4551
# 76     301 Londonderry @ DePaul Center Waco, TX 76712   254-776-5970
# 77     301 Londonderry @ DePaul Center Waco, TX 76712   254-776-5970
# 78        405 Londonderry Dr Suite 105 Waco, TX 76712   254-776-0266
# 79                6901 Medical Parkway Waco, TX 76712   254-751-4551
# 80   601 West Highway 6 Suite 111 Waco, TX 76710-5592   254-752-9621
# 81   601 West Highway 6 Suite 111 Waco, TX 76710-5592   254-752-9621
# 82                6901 Medical Parkway Waco, TX 76712   254-751-4719
# 83                6901 Medical Parkway Waco, TX 76712   254-751-4719
# 84                6901 Medical Parkway Waco, TX 76712   254-751-4299
# 85                6901 Medical Parkway Waco, TX 76712   254-751-4551
# 86        405 Londonderry Dr Suite 105 Waco, TX 76712   254-776-0266
# 87   601 West Highway 6 Suite 111 Waco, TX 76710-5592   254-752-9621
# 88                6901 Medical Parkway Waco, TX 76712   254-751-4719
# 89                6901 Medical Parkway Waco, TX 76712   254-751-4299
# 90  3445 Executive Center Dr. Suite 250 Austin, TX...   512-579-4000
# 91  3445 Executive Center Dr. Suite 250 Austin, TX...   512-579-4000
# 92                6901 Medical Parkway Waco, TX 76712   254-751-4299
# 93        405 Londonderry Dr Suite 105 Waco, TX 76712   254-776-0266
# 94        405 Londonderry Dr Suite 311 Waco, TX 76711   254-537-6550
# 95        405 Londonderry Dr Suite 105 Waco, TX 76712   254-776-0266
#
#                                          Specialties    firstName  \
# 0                                     Anesthesiology        chidi
# 1                                          Pathology         joan
# 2   Pediatric Emergency Medicine, Emergency Medicine     kathleen
# 3   Pediatric Emergency Medicine, Emergency Medicine     kathleen
# 4   Pediatric Emergency Medicine, Emergency Medicine     kathleen
# 5   Pediatric Emergency Medicine, Emergency Medicine     kathleen
# 6                                        Hospitalist         john
# 7                          Radiology, Neuroradiology         adam
# 8                                     Anesthesiology       steven
# 9                                          Pathology        larry
# 10                                         Pathology        larry
# 11                                         Pathology        larry
# 12                                         Pathology        larry
# 13                                         Pathology         cary
# 14                                       Hospitalist            g
# 15                                         Pathology          amy
# 16                                    Anesthesiology        holly
# 17                                       Hospitalist        larry
# 18                                    Anesthesiology       nelson
# 19                                    Anesthesiology       tamara
# 20                                       Hospitalist       steven
# 21                                    Anesthesiology         gary
# 22                                         Radiology       nathan
# 23                                         Pathology         paul
# 24                                         Pathology         gary
# 25                                         Pathology         gary
# 26                                         Pathology         gary
# 27                                         Pathology         gary
# 28                                       Hospitalist        james
# 29                                    Anesthesiology  christopher
# ..                                               ...          ...
# 66                                         Pathology        susan
# 67                                         Radiology       dennis
# 68                                         Radiology         erin
# 69                                         Pathology       amanda
# 70                                         Pathology     claudius
# 71                                         Pathology     claudius
# 72                                         Pathology     claudius
# 73                                         Pathology     claudius
# 74                                       Hospitalist       roxann
# 75                                       Hospitalist       roxann
# 76                                       Hospitalist       roxann
# 77                                       Hospitalist       roxann
# 78                                    Anesthesiology      timothy
# 79                                       Hospitalist        barry
# 80                                         Pathology       daniel
# 81                                         Pathology       daniel
# 82                                         Pathology       daniel
# 83                                         Pathology       daniel
# 84                         Radiology, Neuroradiology     kathleen
# 85                      Hospitalist, Family Medicine      horacio
# 86                                    Anesthesiology      michael
# 87                                         Pathology          NaN
# 88                                         Pathology          NaN
# 89                                         Radiology      gustavo
# 90                                         Pathology          min
# 91                                         Pathology          ann
# 92                                         Radiology      jeffery
# 93                                    Anesthesiology          NaN
# 94                   Pain Management, Anesthesiology        eliot
# 95                                    Anesthesiology        roger
#
#           hospitalAffiliations        lastName
# 0   [Providence Health Center]        achilefu
# 1   [Providence Health Center]        admirand
# 2   [Providence Health Center]            berg
# 3   [Providence Health Center]            berg
# 4   [Providence Health Center]            berg
# 5   [Providence Health Center]            berg
# 6   [Providence Health Center]           biboa
# 7   [Providence Health Center]        borowski
# 8   [Providence Health Center]         burgard
# 9   [Providence Health Center]        cartmell
# 10  [Providence Health Center]        cartmell
# 11  [Providence Health Center]        cartmell
# 12  [Providence Health Center]        cartmell
# 13  [Providence Health Center]        chisholm
# 14  [Providence Health Center]           clark
# 15  [Providence Health Center]          coffey
# 16  [Providence Health Center]           davis
# 17  [Providence Health Center]           davis
# 18  [Providence Health Center]      destaffany
# 19  [Providence Health Center]          dutter
# 20  [Providence Health Center]          elwell
# 21  [Providence Health Center]         fischer
# 22  [Providence Health Center]         forrest
# 23  [Providence Health Center]          gaudin
# 24  [Providence Health Center]       geldmeier
# 25  [Providence Health Center]       geldmeier
# 26  [Providence Health Center]       geldmeier
# 27  [Providence Health Center]       geldmeier
# 28  [Providence Health Center]        goodsett
# 29  [Providence Health Center]         greener
# ..                         ...             ...
# 66  [Providence Health Center]         pacinda
# 67  [Providence Health Center]           parks
# 68  [Providence Health Center]          prince
# 69  [Providence Health Center]  rivera_begeman
# 70  [Providence Health Center]        robinson
# 71  [Providence Health Center]        robinson
# 72  [Providence Health Center]        robinson
# 73  [Providence Health Center]        robinson
# 74  [Providence Health Center]         samples
# 75  [Providence Health Center]         samples
# 76  [Providence Health Center]         samples
# 77  [Providence Health Center]         samples
# 78  [Providence Health Center]         schmidt
# 79  [Providence Health Center]           shefa
# 80  [Providence Health Center]           smith
# 81  [Providence Health Center]           smith
# 82  [Providence Health Center]           smith
# 83  [Providence Health Center]           smith
# 84  [Providence Health Center]        sorensen
# 85  [Providence Health Center]            sosa
# 86  [Providence Health Center]     teichelmann
# 87                         NaN             NaN
# 88                         NaN             NaN
# 89  [Providence Health Center]      villarreal
# 90  [Providence Health Center]            wang
# 91  [Providence Health Center]           white
# 92  [Providence Health Center]           white
# 93                         NaN             NaN
# 94  [Providence Health Center]        wickliff
# 95  [Providence Health Center]        williams
#
# [96 rows x 18 columns]

# %% [markdown]
# #### Initial data carpentry/cleansing

# %%
FAP_with_affils.drop_duplicates(subset = ['FirstName', 'LastName', 'MapAddress'], inplace = True)
FAP_with_affils.head()
# Out:
#                                     AddressFormatted Associations Credentials  \
# 0  405 Londonderry Dr <br />Suite 105 <br />Waco,...          C4T          MD
# 1  3445 Executive Center Dr. <br />Suite 250 <br ...                       MD
# 2          6901 Medical Parkway <br />Waco, TX 76712                       MD
# 4  6300 La Calma Dr. <br />Suite 200 <br />Austin...                       MD
# 6          6901 Medical Parkway <br />Waco, TX 76712          C4T          DO
#
#       DisplayName  Distance FirstName FirstNameID  \
# 0  Chidi Achilefu        -1     Chidi       chidi
# 1   Joan Admirand        -1      Joan        joan
# 2   Kathleen Berg        -1  Kathleen    kathleen
# 4   Kathleen Berg        -1  Kathleen    kathleen
# 6      John Biboa        -1      John        john
#
#                                               Groups  LastName LastNameID  \
# 0                Mid Tex Anesthesia Associates, P.A.  Achilefu   achilefu
# 1                      Clinical Pathology Associates  Admirand   admirand
# 2  US Acute Care Solutions, US Acute Care Solutio...      Berg       berg
# 4  US Acute Care Solutions, US Acute Care Solutio...      Berg       berg
# 6         McLennan County Hospitalist Services, P.C.     Biboa      biboa
#
#     Latitude  Longitude                                         MapAddress  \
# 0  31.513468 -97.199510        405 Londonderry Dr Suite 105 Waco, TX 76712
# 1  30.359690 -97.747810  3445 Executive Center Dr. Suite 250 Austin, TX...
# 2  31.514454 -97.199490                6901 Medical Parkway Waco, TX 76712
# 4  30.324444 -97.703026       6300 La Calma Dr. Suite 200 Austin, TX 78752
# 6  31.514465 -97.199530                6901 Medical Parkway Waco, TX 76712
#
#   PhoneFormatted                                       Specialties firstName  \
# 0   254-776-0266                                    Anesthesiology     chidi
# 1   512-579-4000                                         Pathology      joan
# 2   254-751-4180  Pediatric Emergency Medicine, Emergency Medicine  kathleen
# 4   512-452-8533  Pediatric Emergency Medicine, Emergency Medicine  kathleen
# 6   254-751-4551                                       Hospitalist      john
#
#          hospitalAffiliations  lastName
# 0  [Providence Health Center]  achilefu
# 1  [Providence Health Center]  admirand
# 2  [Providence Health Center]      berg
# 4  [Providence Health Center]      berg
# 6  [Providence Health Center]     biboa

# %%
#extract Zip for NPI search
FAP_with_affils['Zip'] = FAP_with_affils.MapAddress.str.extract('(\d{5})')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: currently extract(expand=None) means expand=False (return Index/Series/DataFrame) but in a future version of pandas this will be changed to expand=True (return DataFrame)

# %%
FAP_with_affils_formatted = FAP_with_affils[['FirstName', 'LastName', 'Credentials', 'Specialties', 'Groups', 'MapAddress', 'Zip', 'hospitalAffiliations']]
FAP_with_affils_formatted.head()
# Out:
#   FirstName  LastName Credentials  \
# 0     Chidi  Achilefu          MD
# 1      Joan  Admirand          MD
# 2  Kathleen      Berg          MD
# 4  Kathleen      Berg          MD
# 6      John     Biboa          DO
#
#                                         Specialties  \
# 0                                    Anesthesiology
# 1                                         Pathology
# 2  Pediatric Emergency Medicine, Emergency Medicine
# 4  Pediatric Emergency Medicine, Emergency Medicine
# 6                                       Hospitalist
#
#                                               Groups  \
# 0                Mid Tex Anesthesia Associates, P.A.
# 1                      Clinical Pathology Associates
# 2  US Acute Care Solutions, US Acute Care Solutio...
# 4  US Acute Care Solutions, US Acute Care Solutio...
# 6         McLennan County Hospitalist Services, P.C.
#
#                                           MapAddress    Zip  \
# 0        405 Londonderry Dr Suite 105 Waco, TX 76712  76712
# 1  3445 Executive Center Dr. Suite 250 Austin, TX...  78731
# 2                6901 Medical Parkway Waco, TX 76712  76712
# 4       6300 La Calma Dr. Suite 200 Austin, TX 78752  78752
# 6                6901 Medical Parkway Waco, TX 76712  76712
#
#          hospitalAffiliations
# 0  [Providence Health Center]
# 1  [Providence Health Center]
# 2  [Providence Health Center]
# 4  [Providence Health Center]
# 6  [Providence Health Center]

# %% [markdown]
# #### Write out Roster and Affils

# %%
from pandas import ExcelWriter
filename = 'Providence_HospSpecs_affiliations_20190815.xlsx'

with ExcelWriter(filename) as writer:
        FAP_with_affils_formatted.to_excel(writer, sheet_name='Providence Affiliations')

# %% [markdown]
# ### STEP 3: Get Accepting new patients from bio pages
#
# For Provider data Quality team--they'd like info for any docs accepting new patients.

# %%
fap_no_nans = fap_df.dropna(subset=['FirstNameID', 'LastNameID'])
fap_no_nans.shape
# Out:
# (3381, 15)

# %%
def doc_acceptFlags(dataframe):
    accept_list = []
    seconds = 2 #define seconds to wait between get requests
    for index, row in dataframe.iterrows():
        firstname = row['FirstNameID']
        lastname = row['LastNameID']
        try:
            url = "https://www.seton.net/providers/bio/" + firstname + "-" + lastname #concat url
            docpage = requests.get(url,time.sleep(seconds)) #get html from url, with delay to prevent website blacklisting
            print(docpage.status_code)
            soup = BeautifulSoup(docpage.content, 'html5lib') #parse html with BeautifulSoup
            affiliations = soup.find(id="physicianAffiliations") #find physicianAffiliations section of website
            accept_new = soup.find(id="physicianNewPatients").get_text() #get all accept code flags via physicianNewPatients ids
            dict1 = {'firstName': firstname, 'lastName': lastname, 'AcceptFlag': accept_new} #make name and acceptFlags into dictionary
            accept_list.append(dict1)
            print("Added AcceptFlag for "+firstname+" "+lastname)
        except:
            pass
            print("No AcceptFlag for "+firstname+" "+lastname)
    return(accept_list)

# %%
AcceptFlags = doc_acceptFlags(fap_no_nans)
print('All DocPages scraped!')

AcceptFlag_df = pd.DataFrame(AcceptFlags)

FAP_with_AcceptFlags = pd.merge(fap_df, AcceptFlag_df,
              left_on=['FirstNameID', 'LastNameID'],
              right_on=['firstName', 'lastName'],
              how='left')

from pandas import ExcelWriter
filename = 'Seton_FAP_AcceptingNewPatients_20190716.xlsx'

with ExcelWriter(filename) as writer:
        FAP_with_AcceptFlags.to_excel(writer, sheet_name='Seton FAP Info')

print('You Excel File is ready!')
# Out:
# 200
# No AcceptFlag for justin aaker
# 200
# No AcceptFlag for alan abando
# 200
# No AcceptFlag for madhava abburi
# 200
# No AcceptFlag for waleed abdelhafez
# 200
# No AcceptFlag for zainab abdulla
# 200
# No AcceptFlag for zainab abdulla
# 200
# No AcceptFlag for arthur abello
# 200
# No AcceptFlag for william abide
# 200
# No AcceptFlag for john abikhaled
# 200
# No AcceptFlag for shannon abikhaled
# 200
# No AcceptFlag for sami aboumatar
# 200
# No AcceptFlag for john abraham
# 200
# No AcceptFlag for merlin abraham
# 200
# No AcceptFlag for joshua abramowitz
# 200
# No AcceptFlag for david abrams
# 200
# No AcceptFlag for steven abrams
# 200
# No AcceptFlag for eric acheson
# 200
# No AcceptFlag for anne adams
# 200
# No AcceptFlag for bradley adams
# 200
# No AcceptFlag for clayton adams
# 200
# No AcceptFlag for david adams
# 200
# Added AcceptFlag for adewole adamson
# 200
# Added AcceptFlag for adewole adamson
# 200
# Added AcceptFlag for adewole adamson
# 200
# No AcceptFlag for debaroti addy
# 200
# No AcceptFlag for eric adelman
# 200
# No AcceptFlag for sikander adeni
# 200
# No AcceptFlag for titilola adio
# 200
# No AcceptFlag for colleen adkins
# 200
# No AcceptFlag for joan admirand
# 200
# No AcceptFlag for stephen agatston
# 200
# No AcceptFlag for deepak agrawal
# 200
# No AcceptFlag for rudxandra aguiar
# 200
# Added AcceptFlag for vivian aguilar
# 200
# Added AcceptFlag for vivian aguilar
# 200
# No AcceptFlag for jennifer agulnek
# 200
# Added AcceptFlag for ammar ahmed
# 200
# Added AcceptFlag for ammar ahmed
# 200
# Added AcceptFlag for ammar ahmed
# 200
# Added AcceptFlag for ammar ahmed
# 200
# No AcceptFlag for sarah ahmed
# 200
# No AcceptFlag for sohail ahmed
# 200
# No AcceptFlag for supriya ailnani
# 200
# No AcceptFlag for michael ainsworth
# 200
# No AcceptFlag for omar akhtar
# 200
# No AcceptFlag for mark akin
# 200
# No AcceptFlag for yamini akkanti
# 200
# No AcceptFlag for amin al_ahmad
# 200
# No AcceptFlag for amin al_ahmad
# 200
# No AcceptFlag for amin al_ahmad
# 200
# No AcceptFlag for tariq alam
# 200
# Added AcceptFlag for anupama alareddy
# 200
# Added AcceptFlag for anupama alareddy
# 200
# Added AcceptFlag for anupama alareddy
# 200
# Added AcceptFlag for kelly alberda
# 200
# No AcceptFlag for kimberly albert
# 200
# No AcceptFlag for michael albrecht
# 200
# No AcceptFlag for teresa albright
# 200
# No AcceptFlag for eduardo alcocer
# 200
# No AcceptFlag for booth aldred
# 200
# No AcceptFlag for brian aldred
# 200
# No AcceptFlag for micaela aleman
# 200
# No AcceptFlag for wais alemi
# 200
# No AcceptFlag for benyam alemu
# 200
# No AcceptFlag for anne alexander
# 200
# No AcceptFlag for jeffrey alford
# 200
# Added AcceptFlag for jawad ali
# 200
# No AcceptFlag for ramla ali
# 200
# No AcceptFlag for hassan alissa
# 200
# No AcceptFlag for christina allegretti
# 200
# No AcceptFlag for kristin allen
# 200
# No AcceptFlag for amanda allensworth
# 200
# No AcceptFlag for carly allred
# 200
# No AcceptFlag for jorge almeida
# 200
# No AcceptFlag for julie alonso_katzowitz
# 200
# No AcceptFlag for andrew alpar
# 200
# No AcceptFlag for miguel alvarado
# 200
# No AcceptFlag for alexander alvarez
# 200
# No AcceptFlag for ian alward
# 200
# No AcceptFlag for fidelis amadi
# 200
# Added AcceptFlag for jordan amadio
# 200
# Added AcceptFlag for jordan amadio
# 200
# No AcceptFlag for maneesh amancharla
# 200
# No AcceptFlag for sheila amar
# 200
# No AcceptFlag for rafael amaro
# 200
# No AcceptFlag for raimy amasha
# 200
# No AcceptFlag for malena amato
# 200
# No AcceptFlag for mark ambler
# 200
# No AcceptFlag for anne ames
# 200
# No AcceptFlag for benjamin amis
# 200
# No AcceptFlag for allison anderson
# 200
# No AcceptFlag for jennifer anderson
# 200
# No AcceptFlag for matthew anderson
# 200
# No AcceptFlag for norma anderson
# 200
# No AcceptFlag for aldo andino
# 200
# No AcceptFlag for kurt andreason
# 200
# No AcceptFlag for michael andreo
# 200
# No AcceptFlag for arush angirasa
# 200
# No AcceptFlag for valliammai annamalai_slavis
# 200
# No AcceptFlag for nadeem ansari
# 200
# No AcceptFlag for laura anton
# 200
# No AcceptFlag for tomas antonini
# 200
# No AcceptFlag for marcelo antunes
# 200
# No AcceptFlag for jeffrey apple
# 200
# Added AcceptFlag for ligiola aranaga_sanchez
# 200
# Added AcceptFlag for ligiola aranaga_sanchez
# 200
# Added AcceptFlag for ligiola aranaga_sanchez
# 200
# No AcceptFlag for jennifer aranda
# 200
# No AcceptFlag for vanessa arbino
# 200
# No AcceptFlag for komal arce
# 200
# No AcceptFlag for leroy arenivar
# 200
# No AcceptFlag for michael aronoff
# 200
# No AcceptFlag for amy arrant
# 200
# No AcceptFlag for anthony arredondo
# 200
# No AcceptFlag for francisco arredondo
# 200
# No AcceptFlag for albert arthur
# 200
# No AcceptFlag for randal aschenbeck
# 200
# No AcceptFlag for souhail asfouri
# 200
# No AcceptFlag for lauren ash
# 200
# Added AcceptFlag for ramsey ashour
# 200
# Added AcceptFlag for candace ashton
# 200
# No AcceptFlag for michelle ashworth
# 200
# No AcceptFlag for rodney ashworth
# 200
# No AcceptFlag for robert askew
# 200
# No AcceptFlag for william askew
# 200
# No AcceptFlag for michael aterno
# 200
# Added AcceptFlag for james attra
# 200
# No AcceptFlag for hana aubrechtova
# 200
# No AcceptFlag for mark auler
# 200
# No AcceptFlag for soe aung
# 200
# No AcceptFlag for thomas aung
# 200
# No AcceptFlag for geshia austin
# 200
# Added AcceptFlag for sara austin
# 200
# Added AcceptFlag for sara austin
# 200
# Added AcceptFlag for sara austin
# 200
# Added AcceptFlag for sara austin
# 200
# Added AcceptFlag for sara austin
# 200
# Added AcceptFlag for michael auth
# 200
# No AcceptFlag for ana avalos_mishaan
# 200
# Added AcceptFlag for swati avashia
# 200
# No AcceptFlag for anthony_tony aventa
# 200
# No AcceptFlag for sarah avery
# 200
# No AcceptFlag for kimberly edwards
# 200
# Added AcceptFlag for jayson aydelotte
# 200
# No AcceptFlag for gayle ayers
# 200
# No AcceptFlag for gayle ayers
# 200
# No AcceptFlag for jennifer ayres
# 200
# No AcceptFlag for krystel babaran
# 200
# No AcceptFlag for harsh babbar
# 200
# No AcceptFlag for harsh babbar
# 200
# No AcceptFlag for melanie babot
# 200
# No AcceptFlag for edgar bacares
# 200
# No AcceptFlag for farnel backer
# 200
# No AcceptFlag for susan baer
# 200
# No AcceptFlag for mehraj baig
# 200
# No AcceptFlag for christopher bailey
# 200
# No AcceptFlag for shane bailey
# 200
# No AcceptFlag for rebecca baine
# 200
# No AcceptFlag for brett baker
# 200
# No AcceptFlag for dana baker
# 200
# No AcceptFlag for james baker
# 200
# No AcceptFlag for james baker
# 200
# No AcceptFlag for joe baker
# 200
# No AcceptFlag for lakshmi balasubramanian
# 200
# No AcceptFlag for jeeathbell balbastro
# 200
# No AcceptFlag for susan balezentis
# 200
# No AcceptFlag for tiffany ballard
# 200
# No AcceptFlag for olukayode bamgbelu
# 200
# No AcceptFlag for john bangston
# 200
# No AcceptFlag for pamela banister
# 200
# No AcceptFlag for nancy banks
# 200
# No AcceptFlag for william banks
# 200
# No AcceptFlag for reginald baptiste
# 200
# No AcceptFlag for ory barak
# 200
# No AcceptFlag for luke barker
# 200
# Added AcceptFlag for leslie barkis
# 200
# No AcceptFlag for john barkley
# 200
# Added AcceptFlag for carrie barlow
# 200
# No AcceptFlag for ian baronofsky
# 200
# No AcceptFlag for lori barr
# 200
# No AcceptFlag for rodolfo barrera
# 200
# Added AcceptFlag for kellie barrett
# 200
# Added AcceptFlag for kellie barrett
# 200
# No AcceptFlag for grace barron
# 200
# No AcceptFlag for shanna barry
# 200
# Added AcceptFlag for adam barta
# 200
# No AcceptFlag for william bartek
# 200
# No AcceptFlag for elizabeth bartlett
# 200
# No AcceptFlag for ashvin baru
# 200
# No AcceptFlag for nicole basa
# 200
# No AcceptFlag for mohamed bassiouny
# 200
# No AcceptFlag for nabanita basu
# 200
# No AcceptFlag for augustin batlle
# 200
# No AcceptFlag for amy bayliss
# 200
# No AcceptFlag for jose bayona
# 200
# Added AcceptFlag for danielle beachler
# 200
# Added AcceptFlag for danielle beachler
# 200
# Added AcceptFlag for danielle beachler
# 200
# No AcceptFlag for brennen beatty
# 200
# No AcceptFlag for crystal becerra
# 200
# No AcceptFlag for crystal becerra
# 200
# No AcceptFlag for rehana becker
# 200
# No AcceptFlag for scott becker
# 200
# No AcceptFlag for scott becker
# 200
# Added AcceptFlag for ziv beckerman
# 200
# No AcceptFlag for patrick beckham
# 200
# No AcceptFlag for alysia bedgood
# 200
# No AcceptFlag for grace bednar
# 200
# No AcceptFlag for timothy bednar
# 200
# No AcceptFlag for john bedolla
# 200
# No AcceptFlag for john bedolla
# 200
# No AcceptFlag for laura beech
# 200
# No AcceptFlag for mahmuda begum
# 200
# No AcceptFlag for gene beisert
# 200
# Added AcceptFlag for stephen bekanich
# 200
# No AcceptFlag for anna bell
# 200
# No AcceptFlag for gregory bell
# 200
# No AcceptFlag for james bell
# 200
# No AcceptFlag for melanie belt
# 200
# No AcceptFlag for hillel ben_avi
# 200
# Added AcceptFlag for ghizlane benchekroune
# 200
# No AcceptFlag for matthew benevich
# 200
# No AcceptFlag for hans bengtson
# 200
# No AcceptFlag for thomas bening
# 200
# No AcceptFlag for bari bennett
# 200
# No AcceptFlag for dwayne bennett
# 200
# Added AcceptFlag for terrell benold
# 200
# No AcceptFlag for edward benton
# 200
# No AcceptFlag for jacques benun
# 200
# No AcceptFlag for craig berent
# 200
# No AcceptFlag for kathleen berg
# 200
# No AcceptFlag for kathleen berg
# 200
# No AcceptFlag for lloyd berg
# 200
# No AcceptFlag for brian berger
# 200
# No AcceptFlag for brian berger
# 200
# No AcceptFlag for dennis berger
# 200
# No AcceptFlag for michelle berger
# 200
# Added AcceptFlag for ryan bergeson
# 200
# Added AcceptFlag for deborah bergfeld
# 200
# Added AcceptFlag for deborah bergfeld
# 200
# Added AcceptFlag for rahel berhane
# 200
# No AcceptFlag for richard berkowitz
# 200
# No AcceptFlag for nicole bernard
# 200
# No AcceptFlag for kurt berneburg
# 200
# No AcceptFlag for david berry
# 200
# No AcceptFlag for crystal berry_roberts
# 200
# No AcceptFlag for john bertelson
# 200
# No AcceptFlag for john bertelson
# 200
# No AcceptFlag for john bertelson
# 200
# No AcceptFlag for john bertelson
# 200
# No AcceptFlag for john bertelson
# 200
# No AcceptFlag for aaron best
# 200
# Added AcceptFlag for jeanette bettes
# 200
# No AcceptFlag for judith betts
# 200
# No AcceptFlag for beenish bhaidani
# 200
# No AcceptFlag for ankur bhakta
# 200
# No AcceptFlag for sulochana bhandarkar
# 200
# No AcceptFlag for sonia bhatia
# 200
# No AcceptFlag for kunjan bhatt
# 200
# No AcceptFlag for shiva bhattarai
# 200
# No AcceptFlag for maqsood bhatti
# 200
# No AcceptFlag for meenu bhatti
# 200
# No AcceptFlag for william biel
# 200
# Added AcceptFlag for raymond bietry
# 200
# No AcceptFlag for craig billeaud
# 200
# No AcceptFlag for varsha bilolikar
# 200
# No AcceptFlag for nancy binford
# 200
# No AcceptFlag for julie bingham
# 200
# No AcceptFlag for larry birdwell
# 200
# No AcceptFlag for sonali birewar
# 200
# No AcceptFlag for glenn birnbaum
# 200
# No AcceptFlag for carl bischoff
# 200
# No AcceptFlag for jack bissett
# 200
# No AcceptFlag for antonious bittar
# 200
# Added AcceptFlag for margarete bivens
# 200
# No AcceptFlag for angela black
# 200
# No AcceptFlag for stephen blair
# 200
# No AcceptFlag for robert blais
# 200
# No AcceptFlag for jennifer blankenship
# 200
# No AcceptFlag for neal blauzvern
# 200
# No AcceptFlag for sean blaydon
# 200
# No AcceptFlag for maya bledsoe
# 200
# No AcceptFlag for dean blevins
# 200
# No AcceptFlag for thomas blevins
# 200
# No AcceptFlag for daniel bloom
# 200
# No AcceptFlag for guy blumhagen
# 200
# No AcceptFlag for mark bochey
# 200
# No AcceptFlag for mark bochey
# 200
# No AcceptFlag for ryan boeck
# 200
# No AcceptFlag for sheila boes
# 200
# No AcceptFlag for michael bogdanovich
# 200
# No AcceptFlag for david boltan
# 200
# No AcceptFlag for lindsay boltan
# 200
# No AcceptFlag for kim bolton
# 200
# No AcceptFlag for edward bombach
# 200
# No AcceptFlag for bradley boone
# 200
# No AcceptFlag for jeffrey boos
# 200
# No AcceptFlag for stephanie booth
# 200
# No AcceptFlag for steven booton
# 200
# Added AcceptFlag for loa borchert
# 200
# No AcceptFlag for drake borer
# 200
# No AcceptFlag for jay borick
# 200
# No AcceptFlag for scott boruchow
# 200
# Added AcceptFlag for jason bosco
# 200
# No AcceptFlag for marco bosquez
# 200
# No AcceptFlag for marouane bouchareb
# 200
# No AcceptFlag for megan bouchareb
# 200
# No AcceptFlag for eric boudreau
# 200
# No AcceptFlag for crystal bowden_mckay
# 200
# Added AcceptFlag for rachel bowman
# 200
# No AcceptFlag for gushyalatha boya
# 200
# Added AcceptFlag for beth boyarsky
# 200
# No AcceptFlag for james boyd
# 200
# No AcceptFlag for james boysen
# 200
# No AcceptFlag for kevin bozic
# 200
# No AcceptFlag for jason bradley
# 200
# No AcceptFlag for bridget brady
# 200
# No AcceptFlag for john branch
# 200
# No AcceptFlag for jeffrey brand
# 200
# No AcceptFlag for scott brandt
# 200
# No AcceptFlag for sharyl brasher_giles
# 200
# No AcceptFlag for emily bratton
# 200
# No AcceptFlag for mary braunstein
# 200
# No AcceptFlag for nathan breazeale
# 200
# Added AcceptFlag for michael breen
# 200
# No AcceptFlag for alissa brekken
# 200
# No AcceptFlag for andrew brenner
# 200
# No AcceptFlag for bradley brenner
# 200
# No AcceptFlag for b brent
# 200
# No AcceptFlag for b brent
# 200
# No AcceptFlag for elva brewster
# 200
# No AcceptFlag for ben brieger
# 200
# No AcceptFlag for elsa brieno
# 200
# No AcceptFlag for david brigati
# 200
# Added AcceptFlag for deborah briggs
# 200
# Added AcceptFlag for deborah briggs
# 200
# Added AcceptFlag for deborah briggs
# 200
# No AcceptFlag for michaelanne briggs
# 200
# No AcceptFlag for richard briggs
# 200
# No AcceptFlag for russell briggs
# 200
# No AcceptFlag for russell briggs
# 200
# No AcceptFlag for rachel brightwell
# 200
# No AcceptFlag for diane brinkman
# 200
# No AcceptFlag for cynthia brinson
# 200
# No AcceptFlag for delbert brod
# 200
# No AcceptFlag for donald brode
# 200
# No AcceptFlag for harris brodsky
# 200
# No AcceptFlag for william brooke
# 200
# No AcceptFlag for tera brooks
# 200
# No AcceptFlag for steven brotzman
# 200
# No AcceptFlag for bernadette brown
# 200
# Added AcceptFlag for carlos brown
# 200
# No AcceptFlag for ingrid brown
# 200
# No AcceptFlag for jennifer brown
# 200
# No AcceptFlag for kenton brown
# 200
# No AcceptFlag for kevin brown
# 200
# No AcceptFlag for kimberly brown
# 200
# No AcceptFlag for kirk brown
# 200
# No AcceptFlag for mark brown
# 200
# No AcceptFlag for stephen brown
# 200
# No AcceptFlag for thomas brown
# 200
# No AcceptFlag for brandon browne
# 200
# No AcceptFlag for carol_ann browning
# 200
# No AcceptFlag for stewart browning
# 200
# No AcceptFlag for erik bruce
# 200
# No AcceptFlag for robert bruce
# 200
# Added AcceptFlag for audrey brumback
# 200
# No AcceptFlag for ashley brundrett
# 200
# No AcceptFlag for richard bryarly
# 200
# Added AcceptFlag for robert buchanan
# 200
# Added AcceptFlag for robert buchanan
# 200
# No AcceptFlag for brian buck
# 200
# No AcceptFlag for dawn buckingham
# 200
# No AcceptFlag for edward buckingham
# 200
# No AcceptFlag for francis buckley
# 200
# No AcceptFlag for randy buckspan
# 200
# No AcceptFlag for eric buehler
# 200
# No AcceptFlag for charles bugg
# 200
# No AcceptFlag for charles bugg
# 200
# Added AcceptFlag for eric bui
# 200
# No AcceptFlag for marie bui
# 200
# No AcceptFlag for theresa bui
# 200
# No AcceptFlag for thieu bui
# 200
# Added AcceptFlag for radek bukowski
# 200
# Added AcceptFlag for radek bukowski
# 200
# No AcceptFlag for kenneth bunch
# 200
# No AcceptFlag for tina bunch
# 200
# No AcceptFlag for brianna burg
# 200
# No AcceptFlag for natalie burger
# 200
# No AcceptFlag for christine burgess
# 200
# Added AcceptFlag for candace burgoyne
# 200
# No AcceptFlag for phillip burket
# 200
# No AcceptFlag for john burkhardt
# 200
# Added AcceptFlag for kristi burkhart
# 200
# Added AcceptFlag for kristi burkhart
# 200
# No AcceptFlag for sudeep burman
# 200
# No AcceptFlag for mark burnett
# 200
# No AcceptFlag for melissa burnett
# 200
# No AcceptFlag for sahar burns
# 200
# No AcceptFlag for thomas burns
# 200
# No AcceptFlag for sarat burri
# 200
# No AcceptFlag for michael burris
# 200
# No AcceptFlag for maureen burrows
# 200
# No AcceptFlag for matthew burrus
# 200
# No AcceptFlag for grant burton
# 200
# No AcceptFlag for sukanya burugu
# 200
# No AcceptFlag for heidi busceme
# 200
# No AcceptFlag for paul bushart
# 200
# No AcceptFlag for david bushore
# 200
# No AcceptFlag for megyn busse
# 200
# No AcceptFlag for hanzy bustamante
# 200
# No AcceptFlag for kathleen butler
# 200
# No AcceptFlag for michael butler
# 200
# No AcceptFlag for robert butler
# 200
# No AcceptFlag for robert butler
# 200
# No AcceptFlag for chris butschek
# 200
# No AcceptFlag for karl buttermann
# 200
# Added AcceptFlag for lawrence buxton
# 200
# Added AcceptFlag for lawrence buxton
# 200
# No AcceptFlag for david byers
# 200
# No AcceptFlag for charles byrd
# 200
# No AcceptFlag for elizabeth cabrera
# 200
# No AcceptFlag for robert cain
# 200
# No AcceptFlag for william cain
# 200
# No AcceptFlag for enrique calderon
# 200
# No AcceptFlag for james callas
# 200
# No AcceptFlag for caroline camosy
# 200
# No AcceptFlag for lynn campbell
# 200
# No AcceptFlag for mitra campbell
# 200
# No AcceptFlag for robert canby
# 200
# No AcceptFlag for robert canby
# 200
# No AcceptFlag for robert canby
# 200
# No AcceptFlag for todd canon
# 200
# No AcceptFlag for jessica cantu
# 200
# No AcceptFlag for weiwei cao
# 200
# Added AcceptFlag for kevin caperton
# 200
# No AcceptFlag for christy capet
# 200
# Added AcceptFlag for tatiana cardenas
# 200
# No AcceptFlag for aaron cardon
# 200
# No AcceptFlag for meeta cardon
# 200
# No AcceptFlag for brent cardwell
# 200
# No AcceptFlag for jennifer cardwell
# 200
# No AcceptFlag for robert caridi
# 200
# No AcceptFlag for thomas carlson
# 200
# Added AcceptFlag for david carmack
# 200
# No AcceptFlag for daniel carrasco
# 200
# No AcceptFlag for benito carrera_leal
# 200
# No AcceptFlag for erica carroll
# 200
# Added AcceptFlag for tannon carroll
# 200
# Added AcceptFlag for tannon carroll
# 200
# Added AcceptFlag for tannon carroll
# 200
# Added AcceptFlag for tannon carroll
# 200
# No AcceptFlag for jack carsner
# 200
# Added AcceptFlag for kimberly carter
# 200
# No AcceptFlag for shelby carter
# 200
# No AcceptFlag for joseph casadonte
# 200
# No AcceptFlag for luis casaubon
# 200
# No AcceptFlag for ann_marie case
# 200
# Added AcceptFlag for julia case
# 200
# No AcceptFlag for kelly casey
# 200
# No AcceptFlag for ryan casey
# 200
# Added AcceptFlag for harry casmedes
# 200
# No AcceptFlag for melody cassels
# 200
# No AcceptFlag for cathy castillo
# 200
# No AcceptFlag for marcela castillo
# 200
# No AcceptFlag for rene castillo
# 200
# No AcceptFlag for gregory catlett
# 200
# Added AcceptFlag for clay cauthen
# 200
# Added AcceptFlag for clay cauthen
# 200
# No AcceptFlag for paul cauvin
# 200
# No AcceptFlag for vincent cavaretta
# 200
# No AcceptFlag for eduardo cepeda
# 200
# No AcceptFlag for eduardo cepeda
# 200
# No AcceptFlag for nitzia cepeda
# 200
# No AcceptFlag for cecilia cervantes
# 200
# No AcceptFlag for tessa cervantes
# 200
# No AcceptFlag for anurekha chadha
# 200
# No AcceptFlag for punit chadha
# 200
# No AcceptFlag for erin chaffe
# 200
# No AcceptFlag for marisa chagoya
# 200
# No AcceptFlag for samantha chai
# 200
# No AcceptFlag for tira chaicha_brom
# 200
# No AcceptFlag for renu chalasani
# 200
# Added AcceptFlag for fotini chalkias
# 200
# Added AcceptFlag for bharani challa
# 200
# Added AcceptFlag for bharani challa
# 200
# Added AcceptFlag for bharani challa
# 200
# Added AcceptFlag for bharani challa
# 200
# No AcceptFlag for sean chamberlain
# 200
# No AcceptFlag for pirahatai chamnongvongse
# 200
# No AcceptFlag for jacqueline champlain
# 200
# No AcceptFlag for annie chan
# 200
# Added AcceptFlag for mousumi chanda_kim
# 200
# Added AcceptFlag for mousumi chanda_kim
# 200
# No AcceptFlag for thomas chandler
# 200
# No AcceptFlag for austin chang
# 200
# No AcceptFlag for christopher chang
# 200
# No AcceptFlag for kris chang
# 200
# No AcceptFlag for ting_chuan chang
# 200
# No AcceptFlag for brenda chao
# 200
# No AcceptFlag for ricardo chapa
# 200
# No AcceptFlag for cynthia chaparro_krueger
# 200
# No AcceptFlag for nalinda charnsangavej
# 200
# No AcceptFlag for kiran chaudhry
# 200
# No AcceptFlag for saswati chaudhury
# 200
# No AcceptFlag for manish chauhan
# 200
# No AcceptFlag for christopher chavez
# 200
# No AcceptFlag for pompeyo chavez
# 200
# No AcceptFlag for jane chawla
# 200
# No AcceptFlag for andre chen
# 200
# No AcceptFlag for anthony chen
# 200
# No AcceptFlag for dean chen
# 200
# No AcceptFlag for franklin chen
# 200
# No AcceptFlag for huaizhen chen
# 200
# No AcceptFlag for melodie chen
# 200
# No AcceptFlag for sue chen
# 200
# No AcceptFlag for arthur cheng
# 200
# No AcceptFlag for norman chenven
# 200
# No AcceptFlag for peggy chern
# 200
# No AcceptFlag for peggy chern
# 200
# No AcceptFlag for frank cherpack
# 200
# No AcceptFlag for tara cherry
# 200
# No AcceptFlag for esther cheung_phillips
# 200
# No AcceptFlag for saradha chexal
# 200
# No AcceptFlag for saradha chexal
# 200
# No AcceptFlag for hatim chhatriwala
# 200
# No AcceptFlag for subir chhikara
# 200
# No AcceptFlag for frank chia
# 200
# No AcceptFlag for vanessa chiapetta
# 200
# No AcceptFlag for chuma chike_obi
# 200
# No AcceptFlag for jacob childers
# 200
# No AcceptFlag for jerry chiu
# 200
# No AcceptFlag for elizabeth chmelik
# 200
# No AcceptFlag for hubert chodkiewicz
# 200
# No AcceptFlag for julia choi
# 200
# No AcceptFlag for nahyung choi
# 200
# No AcceptFlag for richard chopp
# 200
# No AcceptFlag for laura chow
# 200
# Added AcceptFlag for selina chrane
# 200
# No AcceptFlag for jennifer christensen
# 200
# No AcceptFlag for tina chu
# 200
# No AcceptFlag for robert cinclair
# 200
# No AcceptFlag for cristian cipleu
# 200
# No AcceptFlag for cristian cipleu
# 200
# Added AcceptFlag for mary cishek
# 200
# No AcceptFlag for andra cisneros
# 200
# No AcceptFlag for andra cisneros
# 200
# No AcceptFlag for mark clark
# 200
# Added AcceptFlag for stacey clark
# 200
# Added AcceptFlag for william clark
# 200
# No AcceptFlag for amy clarkson
# 200
# No AcceptFlag for robert cline
# 200
# No AcceptFlag for scott clitheroe
# 200
# No AcceptFlag for scott clitheroe
# 200
# No AcceptFlag for john cluley
# 200
# No AcceptFlag for paul coffeen
# 200
# No AcceptFlag for amy coffey
# 200
# No AcceptFlag for amy coffman
# 200
# No AcceptFlag for joseph cohen
# 200
# No AcceptFlag for karen cohen
# 200
# Added AcceptFlag for shannon cohn
# 200
# No AcceptFlag for cheryl coldwater
# 200
# No AcceptFlag for donald_trey cole
# 200
# No AcceptFlag for jennifer cole
# 200
# No AcceptFlag for rex cole
# 200
# No AcceptFlag for kimberlee coleman_henderson
# 200
# No AcceptFlag for edward coles
# 200
# No AcceptFlag for alan collebrusco
# 200
# No AcceptFlag for samuel collier
# 200
# No AcceptFlag for samuel collier
# 200
# No AcceptFlag for kristina collins
# 200
# No AcceptFlag for melanie collins
# 200
# No AcceptFlag for kymberly colman
# 200
# Added AcceptFlag for patrick combs
# 200
# No AcceptFlag for constancio concepcion
# 200
# No AcceptFlag for jeffrey cone
# 200
# No AcceptFlag for matthew conner
# 200
# No AcceptFlag for william conner
# 200
# Added AcceptFlag for patrick connolly
# 200
# No AcceptFlag for gregory connor
# 200
# No AcceptFlag for lawrence conrad
# 200
# No AcceptFlag for melinda conroy
# 200
# No AcceptFlag for steven conroy
# 200
# No AcceptFlag for shane constable
# 200
# No AcceptFlag for minas constantinides
# 200
# No AcceptFlag for angelica contreras
# 200
# No AcceptFlag for jaime contreras
# 200
# No AcceptFlag for margaret cook
# 200
# No AcceptFlag for robert cook
# 200
# Added AcceptFlag for raven cooksey
# 200
# No AcceptFlag for caroline coombs_skiles
# 200
# Added AcceptFlag for thomas coopwood
# 200
# No AcceptFlag for jadranko corak
# 200
# No AcceptFlag for william corbett
# 200
# Added AcceptFlag for louis corne
# 200
# Added AcceptFlag for louis corne
# 200
# No AcceptFlag for kenneth cornell
# 200
# No AcceptFlag for jose cortez
# 200
# No AcceptFlag for robert cosentino
# 200
# No AcceptFlag for melissa cossey
# 200
# No AcceptFlag for david costantino
# 200
# No AcceptFlag for aaron cotrell
# 200
# No AcceptFlag for john cottey
# 200
# No AcceptFlag for gina cottle
# 200
# No AcceptFlag for craig couch
# 200
# No AcceptFlag for sean coughlin
# 200
# No AcceptFlag for deborah bryant
# 200
# No AcceptFlag for donald counts
# 200
# No AcceptFlag for michael coverman
# 200
# No AcceptFlag for josh covington
# 200
# No AcceptFlag for robert cowan
# 200
# No AcceptFlag for pamela cowper
# 200
# No AcceptFlag for geoffrey cox
# 200
# No AcceptFlag for shannon cox
# 200
# No AcceptFlag for andrew coyne
# 200
# No AcceptFlag for kimberly crabb
# 200
# Added AcceptFlag for christine craig
# 200
# No AcceptFlag for david craig
# 200
# No AcceptFlag for jason craig
# 200
# No AcceptFlag for nicholas cramer
# 200
# No AcceptFlag for john craven
# 200
# No AcceptFlag for jennifer crawford
# 200
# No AcceptFlag for matthew crawford
# 200
# No AcceptFlag for natalie crawford
# 200
# Added AcceptFlag for michael cricchio
# 200
# No AcceptFlag for carolyn crispell
# 200
# No AcceptFlag for emily croce
# 200
# No AcceptFlag for gretchen crook
# 200
# No AcceptFlag for steven crow
# 200
# No AcceptFlag for matthew crozier
# 200
# No AcceptFlag for joshua crum
# 200
# Added AcceptFlag for todd crump
# 200
# No AcceptFlag for ricardo cruz
# 200
# No AcceptFlag for roberto cruz_saldana
# 200
# No AcceptFlag for david cuellar
# 200
# Added AcceptFlag for james cullington
# 200
# Added AcceptFlag for elizabeth cummins
# 200
# Added AcceptFlag for elizabeth cummins
# 200
# Added AcceptFlag for elizabeth cummins
# 200
# No AcceptFlag for f cunningham
# 200
# No AcceptFlag for russell cunningham
# 200
# No AcceptFlag for tim curran
# 200
# No AcceptFlag for ann czarnik
# 200
# Added AcceptFlag for adriana da_silveira
# 200
# No AcceptFlag for rashad dabaghi
# 200
# No AcceptFlag for arsia dabiri
# 200
# Added AcceptFlag for brandi dach
# 200
# No AcceptFlag for vinoop daggubati
# 200
# No AcceptFlag for anas daghestani
# 200
# No AcceptFlag for eric dai
# 200
# No AcceptFlag for jarrod dale
# 200
# No AcceptFlag for john dallas
# 200
# Added AcceptFlag for samantha dallefeld
# 200
# No AcceptFlag for mark dalton
# 200
# No AcceptFlag for eimile dalton_fitzgerald
# 200
# No AcceptFlag for mark dammert
# 200
# No AcceptFlag for mark dammert
# 200
# No AcceptFlag for william dammert
# 200
# No AcceptFlag for meghana dandekar
# 200
# Added AcceptFlag for quan dang
# 200
# No AcceptFlag for tam dang
# 200
# No AcceptFlag for steven daniel
# 200
# No AcceptFlag for sarah daniels
# 200
# No AcceptFlag for christopher danney
# 200
# No AcceptFlag for kim dao
# 200
# Added AcceptFlag for yen dao
# 200
# No AcceptFlag for byron darby
# 200
# No AcceptFlag for adrienne darhower
# 200
# No AcceptFlag for christopher darnall
# 200
# No AcceptFlag for ashima das
# 200
# No AcceptFlag for rani das
# 200
# No AcceptFlag for nilanjana dasgupta
# 200
# No AcceptFlag for swati date
# 200
# No AcceptFlag for meredith davenport
# 200
# No AcceptFlag for elbert david
# 200
# No AcceptFlag for antonia davidson
# 200
# No AcceptFlag for joel davidson
# 200
# Added AcceptFlag for juan davila
# 200
# No AcceptFlag for jenna davis
# 200
# No AcceptFlag for joanne davis
# 200
# No AcceptFlag for l_l_tad davis
# 200
# No AcceptFlag for lindsay davis
# 200
# No AcceptFlag for lindsey davis
# 200
# No AcceptFlag for holly davison
# 200
# No AcceptFlag for mark dawson
# 200
# No AcceptFlag for thomas dawson
# 200
# No AcceptFlag for avis day
# 200
# No AcceptFlag for barakah day
# 200
# No AcceptFlag for michael de_lota
# 200
# No AcceptFlag for brendan de_marco
# 200
# No AcceptFlag for ximena desabra
# 200
# No AcceptFlag for craig de_waal
# 200
# No AcceptFlag for richard debehnke
# 200
# No AcceptFlag for zenebe debela
# 200
# Added AcceptFlag for bergfeld deborah
# 200
# No AcceptFlag for vincenz decastro
# 200
# No AcceptFlag for christopher dehan
# 200
# No AcceptFlag for robert dehne
# 200
# No AcceptFlag for dominic dekeratry
# 200
# No AcceptFlag for ashley deleon
# 200
# No AcceptFlag for gerald delk
# 200
# No AcceptFlag for steven dell
# 200
# No AcceptFlag for jeffrey deloach
# 200
# No AcceptFlag for daniel deming
# 200
# No AcceptFlag for martin denbar
# 200
# Added AcceptFlag for yue deng
# 200
# No AcceptFlag for melody denson
# 200
# No AcceptFlag for melody denson
# 200
# No AcceptFlag for kristen denton
# 200
# No AcceptFlag for aditi desai
# 200
# No AcceptFlag for anjuli desai
# 200
# No AcceptFlag for shiv desai
# 200
# No AcceptFlag for emily desantis
# 200
# No AcceptFlag for rhonda deschner
# 200
# No AcceptFlag for william deschner
# 200
# No AcceptFlag for alok desh
# 200
# No AcceptFlag for flint deshazo
# 200
# No AcceptFlag for sarika deshmukh
# 200
# No AcceptFlag for mrudula deshpande
# 200
# No AcceptFlag for naresh desireddi
# 200
# No AcceptFlag for brendan dewan
# 200
# No AcceptFlag for stephen dewan
# 200
# No AcceptFlag for achal dhruva
# 200
# No AcceptFlag for achal dhruva
# 200
# No AcceptFlag for michael di_iorio
# 200
# No AcceptFlag for david diaz
# 200
# Added AcceptFlag for lucia diaz
# 200
# No AcceptFlag for gustavo diaz_reyes
# 200
# No AcceptFlag for robert dickinson
# 200
# No AcceptFlag for michael diclemente
# 200
# No AcceptFlag for erik diebolt
# 200
# No AcceptFlag for john dieck
# 200
# No AcceptFlag for chad dieterichs
# 200
# No AcceptFlag for jessica dietert
# 200
# No AcceptFlag for jon dietlein
# 200
# No AcceptFlag for t dietz
# 200
# Added AcceptFlag for patrick dillawn
# 200
# No AcceptFlag for ann dimick
# 200
# No AcceptFlag for ming_chieh ding
# 200
# No AcceptFlag for ming_chieh ding
# 200
# No AcceptFlag for ming_chieh ding
# 200
# No AcceptFlag for ming_chieh ding
# 200
# No AcceptFlag for amanda disarro
# 200
# No AcceptFlag for shey ditto
# 200
# Added AcceptFlag for dayna diven
# 200
# Added AcceptFlag for dayna diven
# 200
# No AcceptFlag for lena dixit
# 200
# No AcceptFlag for frederick dixon
# 200
# No AcceptFlag for pamela dixon
# 200
# No AcceptFlag for pamela dixon
# 200
# No AcceptFlag for valla djafari
# 200
# No AcceptFlag for paul dlabal
# 200
# No AcceptFlag for christina doan
# 200
# No AcceptFlag for ellis doan
# 200
# No AcceptFlag for steven dobberfuhl
# 200
# No AcceptFlag for lee dockray
# 200
# No AcceptFlag for julie dodd
# 200
# No AcceptFlag for david dodgin
# 200
# No AcceptFlag for k_lindley dodson
# 200
# No AcceptFlag for adir doliner
# 200
# No AcceptFlag for debra dollar
# 200
# No AcceptFlag for kenneth domuczicz
# 200
# No AcceptFlag for heather donaghey
# 200
# Added AcceptFlag for missy donnell
# 200
# No AcceptFlag for james dooner
# 200
# No AcceptFlag for james dooner
# 200
# No AcceptFlag for suprina dorai
# 200
# No AcceptFlag for erin doss
# 200
# No AcceptFlag for robert dougherty
# 200
# No AcceptFlag for elizabeth douglass
# 200
# No AcceptFlag for joel dow
# 200
# No AcceptFlag for benjamin downie
# 200
# Added AcceptFlag for marilyn doyle
# 200
# No AcceptFlag for susan dozier
# 200
# No AcceptFlag for matthew driscoll
# 200
# No AcceptFlag for virginie drummond
# 200
# No AcceptFlag for randall dryer
# 200
# No AcceptFlag for sanjeev dubey
# 200
# No AcceptFlag for craig dubois
# 200
# No AcceptFlag for susan dubois
# 200
# No AcceptFlag for janet dubois
# 200
# No AcceptFlag for jennifer duc
# 200
# No AcceptFlag for anupama duddempudi
# 200
# No AcceptFlag for sushil duddempudi
# 200
# No AcceptFlag for lara dudek
# 200
# Added AcceptFlag for lisa dufner
# 200
# No AcceptFlag for mihnea dumitrescu
# 200
# No AcceptFlag for brannon duncan
# 200
# No AcceptFlag for yana duncan
# 200
# No AcceptFlag for hien duong
# 200
# No AcceptFlag for mai duong
# 200
# No AcceptFlag for meghan dupre
# 200
# Added AcceptFlag for sonia durairaj
# 200
# No AcceptFlag for vikram durairaj
# 200
# No AcceptFlag for teresa duran
# 200
# No AcceptFlag for ryan durel
# 200
# No AcceptFlag for newell dutton
# 200
# No AcceptFlag for anna dvorak
# 200
# No AcceptFlag for michael dwyer
# 200
# No AcceptFlag for ada earp
# 200
# Added AcceptFlag for david easley
# 200
# Added AcceptFlag for david easley
# 200
# Added AcceptFlag for david easley
# 200
# Added AcceptFlag for david easley
# 200
# Added AcceptFlag for david easley
# 200
# No AcceptFlag for laura eastep
# 200
# No AcceptFlag for amy easterling
# 200
# No AcceptFlag for andrew ebert
# 200
# No AcceptFlag for andrew ebert
# 200
# Added AcceptFlag for alireza ebneshahidi
# 200
# No AcceptFlag for sue eckhardt
# 200
# No AcceptFlag for screven edgerton
# 200
# Added AcceptFlag for jane edmond
# 200
# No AcceptFlag for emmanuel edoka
# 200
# No AcceptFlag for joanne edoka
# 200
# No AcceptFlag for ana eduardo
# 200
# Added AcceptFlag for sara edwards
# 200
# No AcceptFlag for brent egeland
# 200
# No AcceptFlag for john eggleston
# 200
# No AcceptFlag for tania eid
# 200
# No AcceptFlag for tania eid
# 200
# No AcceptFlag for nancy eisen
# 200
# No AcceptFlag for deborah ekery
# 200
# Added AcceptFlag for dalia el_bejjani
# 200
# No AcceptFlag for raymonda el_khoury
# 200
# No AcceptFlag for douglas elenz
# 200
# No AcceptFlag for kent ellington
# 200
# No AcceptFlag for kent ellington
# 200
# No AcceptFlag for matthew ellington
# 200
# No AcceptFlag for kenneth ellis
# 200
# No AcceptFlag for leighton ellis
# 200
# No AcceptFlag for leighton ellis
# 200
# No AcceptFlag for lisa ellis
# 200
# No AcceptFlag for ellen elmore
# 200
# No AcceptFlag for lindsay elton
# 200
# No AcceptFlag for lindsay elton
# 200
# No AcceptFlag for alexandra ely
# 200
# No AcceptFlag for carla emery
# 200
# No AcceptFlag for daniel emmett
# 200
# No AcceptFlag for judith enders
# 200
# No AcceptFlag for karen english
# 200
# No AcceptFlag for robert enloe
# 200
# No AcceptFlag for eun eoh
# 200
# No AcceptFlag for samatha eppakayala
# 200
# No AcceptFlag for aliza epstein
# 200
# No AcceptFlag for venkata erella
# 200
# No AcceptFlag for jessica erfan
# 200
# No AcceptFlag for jessica erfan
# 200
# No AcceptFlag for stephanie ericson
# 200
# No AcceptFlag for amsalu erko
# 200
# No AcceptFlag for robert ersek
# 200
# No AcceptFlag for david escamilla
# 200
# No AcceptFlag for kristin escamilla
# 200
# No AcceptFlag for bailey escarzaga
# 200
# No AcceptFlag for mark escott
# 200
# No AcceptFlag for vida esfandiari
# 200
# No AcceptFlag for helen dinkelspiel
# 200
# No AcceptFlag for melissa eshelman
# 200
# No AcceptFlag for james eskew
# 200
# No AcceptFlag for sandra esparza
# 200
# No AcceptFlag for valerie espinosa
# 200
# No AcceptFlag for alejandro esquivel
# 200
# No AcceptFlag for yvonne essandoh
# 200
# No AcceptFlag for james evans
# 200
# No AcceptFlag for seth evans
# 200
# No AcceptFlag for manuela ewing
# 200
# Added AcceptFlag for meisa ezekiel
# 200
# No AcceptFlag for olufunke ezekoye
# 200
# No AcceptFlag for marcia fagerberg
# 200
# No AcceptFlag for jerry fain
# 200
# No AcceptFlag for jacob falcon
# 200
# No AcceptFlag for oliver fannin
# 200
# No AcceptFlag for katherine farady
# 200
# No AcceptFlag for cyrus farahani
# 200
# No AcceptFlag for john fardal
# 200
# No AcceptFlag for nabeel farhataziz
# 200
# Added AcceptFlag for jennifer farley
# 200
# Added AcceptFlag for caron farrell
# 200
# Added AcceptFlag for caron farrell
# 200
# No AcceptFlag for steven fass
# 200
# Added AcceptFlag for holly fatter
# 200
# No AcceptFlag for tim faulkenberry
# 200
# No AcceptFlag for tim faulkenberry
# 200
# No AcceptFlag for kari fay
# 200
# No AcceptFlag for corey fearheiley
# 200
# No AcceptFlag for adrienne feasel
# 200
# No AcceptFlag for amber featherstone_uwague
# 200
# Added AcceptFlag for robert feinstein
# 200
# Added AcceptFlag for sarah felderhoff
# 200
# No AcceptFlag for david feldman
# 200
# No AcceptFlag for mark felger
# 200
# No AcceptFlag for arnold fenrich
# 200
# Added AcceptFlag for amber fenton
# 200
# No AcceptFlag for david ferguson
# 200
# No AcceptFlag for jim fernandez
# 200
# Added AcceptFlag for marisol fernandez
# 200
# Added AcceptFlag for marisol fernandez
# 200
# No AcceptFlag for sarah ferrero
# 200
# Added AcceptFlag for james ferriss
# 200
# Added AcceptFlag for james ferriss
# 200
# No AcceptFlag for jason feuerman
# 200
# Added AcceptFlag for w_ fielder
# 200
# No AcceptFlag for esther fields
# 200
# No AcceptFlag for jon filardi
# 200
# No AcceptFlag for eric fillman
# 200
# No AcceptFlag for gerald fincken
# 200
# No AcceptFlag for julie fisher
# 200
# No AcceptFlag for rebecca fisher
# 200
# No AcceptFlag for avrim fishkind
# 200
# No AcceptFlag for t fitzpatrick
# 200
# No AcceptFlag for david fleeger
# 200
# No AcceptFlag for lauren fleischer
# 200
# No AcceptFlag for richard fleming
# 200
# No AcceptFlag for jeanne flinn
# 200
# No AcceptFlag for derrick flint
# 200
# No AcceptFlag for alexandra florence
# 200
# No AcceptFlag for nicole flores
# 200
# No AcceptFlag for silvia flores_perkins
# 200
# No AcceptFlag for michael floyd
# 200
# No AcceptFlag for rebecca floyed
# 200
# No AcceptFlag for david flume
# 200
# No AcceptFlag for shiree flume
# 200
# No AcceptFlag for amy flynn
# 200
# No AcceptFlag for kevin flynn
# 200
# No AcceptFlag for hope folarin
# 200
# No AcceptFlag for michael foley
# 200
# No AcceptFlag for david folkers
# 200
# No AcceptFlag for linda fonseca
# 200
# No AcceptFlag for marion forbes
# 200
# Added AcceptFlag for wesley foreman
# 200
# No AcceptFlag for daniel fortes
# 200
# No AcceptFlag for david foss
# 200
# No AcceptFlag for nancy foster
# 200
# No AcceptFlag for robert foster
# 200
# No AcceptFlag for mazin foteh
# 200
# No AcceptFlag for jacqueline fournier
# 200
# No AcceptFlag for jessica foust
# 200
# Added AcceptFlag for amy_ fowler
# 200
# No AcceptFlag for april fox
# 200
# Added AcceptFlag for charlie fox
# 200
# No AcceptFlag for douglas fox
# 200
# No AcceptFlag for edward fox
# 200
# Added AcceptFlag for matthew fox
# 200
# No AcceptFlag for r fox
# 200
# No AcceptFlag for robert frachtman
# 200
# No AcceptFlag for robert frachtman
# 200
# No AcceptFlag for johnny franco
# 200
# No AcceptFlag for allan frank
# 200
# No AcceptFlag for allan frank
# 200
# No AcceptFlag for brannon frank
# 200
# No AcceptFlag for carl frank
# 200
# No AcceptFlag for jill frank
# 200
# No AcceptFlag for scott franklin
# 200
# No AcceptFlag for william franklin
# 200
# Added AcceptFlag for charles franz
# 200
# No AcceptFlag for charles fraser
# 200
# No AcceptFlag for sandra frasser
# 200
# No AcceptFlag for jenny frazier
# 200
# No AcceptFlag for jenny frazier
# 200
# No AcceptFlag for viviana frazier
# 200
# No AcceptFlag for daniel frederick
# 200
# No AcceptFlag for david frederick
# 200
# No AcceptFlag for john frederick
# 200
# No AcceptFlag for debra freedenberg
# 200
# No AcceptFlag for georgeanne freeman
# 200
# No AcceptFlag for richard freeman
# 200
# No AcceptFlag for michelle freeze
# 200
# No AcceptFlag for david freidberg
# 200
# Added AcceptFlag for julia freitag
# 200
# No AcceptFlag for sandra frellsen
# 200
# No AcceptFlag for julie fridlington
# 200
# No AcceptFlag for alice friedman
# 200
# No AcceptFlag for robert friedman
# 200
# No AcceptFlag for leonor frierson_stroud
# 200
# Added AcceptFlag for eric frischhertz
# 200
# Added AcceptFlag for eric frischhertz
# 200
# Added AcceptFlag for eric frischhertz
# 200
# No AcceptFlag for elliot frohman
# 200
# No AcceptFlag for sarah frommer
# 200
# No AcceptFlag for natalie frost
# 200
# No AcceptFlag for liam fry
# 200
# No AcceptFlag for gretchen fuller
# 200
# Added AcceptFlag for jason fuller
# 200
# No AcceptFlag for rob fuller
# 200
# Added AcceptFlag for jason fullmer
# 200
# Added AcceptFlag for jason fullmer
# 200
# No AcceptFlag for robert fulmer
# 200
# No AcceptFlag for linda funderburg
# 200
# No AcceptFlag for frederick fung
# 200
# Added AcceptFlag for matthew furman
# 200
# No AcceptFlag for edward furst
# 200
# No AcceptFlag for mary fuselier
# 200
# No AcceptFlag for steven fyfe
# 200
# No AcceptFlag for steven fyfe
# 200
# No AcceptFlag for jeremy gabrysch
# 200
# No AcceptFlag for mohan gadam
# 200
# No AcceptFlag for mohan gadam
# 200
# No AcceptFlag for umeshchandra gadaria
# 200
# Added AcceptFlag for meghana gadgil
# 200
# Added AcceptFlag for heather gage
# 200
# No AcceptFlag for todd gage
# 200
# No AcceptFlag for binaca gaglani
# 200
# No AcceptFlag for harish gagneja
# 200
# No AcceptFlag for harish gagneja
# 200
# Added AcceptFlag for mark gajjar
# 200
# No AcceptFlag for ava gallagher
# 200
# No AcceptFlag for patricia gallagher
# 200
# No AcceptFlag for sean gallagher
# 200
# No AcceptFlag for michelle gallas
# 200
# No AcceptFlag for gerald gallinghouse
# 200
# No AcceptFlag for gerald gallinghouse
# 200
# No AcceptFlag for gerald gallinghouse
# 200
# No AcceptFlag for kimberly galusha
# 200
# No AcceptFlag for semyon_sam gambarin
# 200
# No AcceptFlag for lauren gambill
# 200
# No AcceptFlag for maryann gamble
# 200
# No AcceptFlag for antonio gamboa
# 200
# No AcceptFlag for roger gammon
# 200
# No AcceptFlag for avanti gandhi
# 200
# No AcceptFlag for saurin gandhi
# 200
# No AcceptFlag for jorge ganem
# 200
# Added AcceptFlag for amy gann
# 200
# No AcceptFlag for sashi ganta
# 200
# Added AcceptFlag for lauren garapedian
# 200
# No AcceptFlag for virginia garay
# 200
# No AcceptFlag for dana garcia
# 200
# No AcceptFlag for derrick garcia
# 200
# No AcceptFlag for donald garcia
# 200
# No AcceptFlag for eugenia garcia
# 200
# No AcceptFlag for joseph garcia
# 200
# Added AcceptFlag for nilda garcia
# 200
# Added AcceptFlag for nilda garcia
# 200
# No AcceptFlag for patrick garcia
# 200
# No AcceptFlag for patrick garcia
# 200
# No AcceptFlag for pete garcia
# 200
# No AcceptFlag for peter garcia
# 200
# No AcceptFlag for jesus garcia_jacques
# 200
# No AcceptFlag for erica garcia_pittman
# 200
# No AcceptFlag for erica garcia_pittman
# 200
# Added AcceptFlag for garland sara
# 200
# Added AcceptFlag for christopher garrison
# 200
# Added AcceptFlag for christopher garrison
# 200
# No AcceptFlag for devin garza
# 200
# No AcceptFlag for diane garza
# 200
# No AcceptFlag for gabriel garza
# 200
# No AcceptFlag for richard garza
# 200
# No AcceptFlag for mary gasal
# 200
# No AcceptFlag for paul gaudin
# 200
# No AcceptFlag for sunita gaur
# 200
# No AcceptFlag for david gay
# 200
# Added AcceptFlag for matthew geck
# 200
# No AcceptFlag for elizabeth geddes_bruce
# 200
# No AcceptFlag for felix geller
# 200
# Added AcceptFlag for megan geloneck
# 200
# No AcceptFlag for michael gennrich
# 200
# No AcceptFlag for aneesh george
# 200
# No AcceptFlag for constance george
# 200
# No AcceptFlag for david george
# 200
# Added AcceptFlag for timothy george
# 200
# Added AcceptFlag for jaya george_abraham
# 200
# No AcceptFlag for brenna gerdelman
# 200
# Added AcceptFlag for cesar gerez_martinez
# 200
# No AcceptFlag for william getman
# 200
# Added AcceptFlag for kelly gettig
# 200
# No AcceptFlag for christopher getto
# 200
# No AcceptFlag for aron gewirtzman
# 200
# No AcceptFlag for darren geyer
# 200
# No AcceptFlag for ahmad ghafoori
# 200
# No AcceptFlag for shelley day
# 200
# Added AcceptFlag for jeny ghartey
# 200
# Added AcceptFlag for kobina ghartey
# 200
# No AcceptFlag for forough ghavami_shirehjini
# 200
# No AcceptFlag for raeeda gheewala
# 200
# No AcceptFlag for giri ghimire
# 200
# No AcceptFlag for ezam ghodsi
# 200
# No AcceptFlag for romy ghosh
# 200
# No AcceptFlag for angela gibson
# 200
# No AcceptFlag for james gibson
# 200
# Added AcceptFlag for caitlin giesler
# 200
# No AcceptFlag for eric giesler
# 200
# No AcceptFlag for sean gilbey
# 200
# No AcceptFlag for peter gilbreath
# 200
# No AcceptFlag for peter gilbreath
# 200
# No AcceptFlag for gary gilcrease
# 200
# Added AcceptFlag for mike gilheany
# 200
# No AcceptFlag for brad gillman
# 200
# No AcceptFlag for jason gillon
# 200
# No AcceptFlag for margaret gilmore
# 200
# No AcceptFlag for adana gipson
# 200
# No AcceptFlag for sarah givner
# 200
# No AcceptFlag for donald gladden
# 200
# No AcceptFlag for donald gladden
# 200
# No AcceptFlag for danielle glade
# 200
# No AcceptFlag for sylvia glaze
# 200
# No AcceptFlag for wesley glazener
# 200
# No AcceptFlag for abby glock
# 200
# No AcceptFlag for mark glover
# 200
# No AcceptFlag for stephanie glover
# 200
# No AcceptFlag for pooja godara
# 200
# No AcceptFlag for christopher godell
# 200
# No AcceptFlag for vikas godhania
# 200
# No AcceptFlag for sireesha gogineni
# 200
# No AcceptFlag for tyler goldberg
# 200
# No AcceptFlag for tyler goldberg
# 200
# No AcceptFlag for david goldblatt
# 200
# No AcceptFlag for kimberly golde
# 200
# No AcceptFlag for sarah goldshtrom
# 200
# No AcceptFlag for michael golf
# 200
# Added AcceptFlag for elizabeth goman
# 200
# No AcceptFlag for monica gomez
# 200
# No AcceptFlag for carlos gomez_meade
# 200
# No AcceptFlag for kelly gonzales
# 200
# No AcceptFlag for lisa gonzales
# 200
# No AcceptFlag for ashley gonzalez
# 200
# Added AcceptFlag for carrie gonzalez
# 200
# No AcceptFlag for ernesto gonzalez
# 200
# No AcceptFlag for helena gonzalez
# 200
# Added AcceptFlag for sonia gonzalez
# 200
# No AcceptFlag for jason gooch
# 200
# No AcceptFlag for jodie gooch
# 200
# No AcceptFlag for michelle gooch
# 200
# Added AcceptFlag for boone goodgame
# 200
# No AcceptFlag for james goodman
# 200
# No AcceptFlag for jennifer goodrich
# 200
# No AcceptFlag for arun gopal
# 200
# No AcceptFlag for ashley gordon
# 200
# No AcceptFlag for francois gordon
# 200
# No AcceptFlag for jennifer gordon
# 200
# No AcceptFlag for william gorman
# 200
# No AcceptFlag for michael gorn
# 200
# No AcceptFlag for allison gorrebeeck
# 200
# Added AcceptFlag for jennifer goss
# 200
# No AcceptFlag for peter gosselink
# 200
# No AcceptFlag for vivek goswami
# 200
# No AcceptFlag for erin gottlieb
# 200
# No AcceptFlag for hilton gottschalk
# 200
# No AcceptFlag for joel gotvald
# 200
# No AcceptFlag for kanaka_durga govindaraju
# 200
# No AcceptFlag for ashwin gowda
# 200
# No AcceptFlag for suma gowda
# 200
# No AcceptFlag for neelima gowrigari
# 200
# No AcceptFlag for leigh_ann grady
# 200
# No AcceptFlag for michael grady
# 200
# No AcceptFlag for jennifer graham
# 200
# No AcceptFlag for robert graham
# 200
# No AcceptFlag for danielle grant
# 200
# No AcceptFlag for maria granzotti
# 200
# No AcceptFlag for ernest graves
# 200
# No AcceptFlag for michael graves
# 200
# Added AcceptFlag for robert graves
# 200
# No AcceptFlag for david gray
# 200
# No AcceptFlag for megan gray
# 200
# No AcceptFlag for tara greendyk
# 200
# No AcceptFlag for david greenwell
# 200
# Added AcceptFlag for jeffrey gregerson
# 200
# No AcceptFlag for victoria gregg
# 200
# Added AcceptFlag for erich grethel
# 200
# Added AcceptFlag for erich grethel
# 200
# No AcceptFlag for kevin grieder
# 200
# No AcceptFlag for mark grier
# 200
# No AcceptFlag for moya griffin
# 200
# No AcceptFlag for violeta griffin
# 200
# No AcceptFlag for stephen griggs
# 200
# No AcceptFlag for andrew grimes
# 200
# No AcceptFlag for douglas grimm
# 200
# No AcceptFlag for ellen grimm
# 200
# No AcceptFlag for boris gritzka
# 200
# No AcceptFlag for meghan groghan
# 200
# No AcceptFlag for sally grogono
# 200
# No AcceptFlag for morris groves
# 200
# No AcceptFlag for robert groves
# 200
# Added AcceptFlag for maria guerra
# 200
# No AcceptFlag for juan guerrero
# 200
# No AcceptFlag for saurabh guleria
# 200
# No AcceptFlag for michael gunlock
# 200
# No AcceptFlag for holly gunn
# 200
# No AcceptFlag for nadege gunn
# 200
# No AcceptFlag for abhilasha gupta
# 200
# No AcceptFlag for ajay gupta
# 200
# No AcceptFlag for madhurima gupta
# 200
# No AcceptFlag for rajat gupta
# 200
# No AcceptFlag for rajeev gupta
# 200
# No AcceptFlag for andrea gust
# 200
# No AcceptFlag for clarissa gutierrez
# 200
# No AcceptFlag for emilio gutierrez
# 200
# No AcceptFlag for maria gutierrez
# 200
# No AcceptFlag for michael gutierrez
# 200
# Added AcceptFlag for karina gutierrez_lopez
# 200
# Added AcceptFlag for karina gutierrez_lopez
# 200
# No AcceptFlag for rodolfo gutierrez_macias
# 200
# No AcceptFlag for anne guyot
# 200
# No AcceptFlag for jacqueline haas
# 200
# No AcceptFlag for nabil habash
# 200
# No AcceptFlag for gregory hadden
# 200
# Added AcceptFlag for ernest haeusslein
# 200
# Added AcceptFlag for ernest haeusslein
# 200
# Added AcceptFlag for ernest haeusslein
# 200
# No AcceptFlag for adam hafemeister
# 200
# No AcceptFlag for conor hagen
# 200
# No AcceptFlag for jeff hagen
# 200
# No AcceptFlag for kara haggart
# 200
# No AcceptFlag for mumnoon haider
# 200
# No AcceptFlag for ross hairgrove
# 200
# No AcceptFlag for jeffrey hall
# 200
# No AcceptFlag for truly hall
# 200
# No AcceptFlag for daniel halloran
# 200
# No AcceptFlag for jeffrey halsell
# 200
# Added AcceptFlag for elaine hamilton
# 200
# No AcceptFlag for kaleb hamilton
# 200
# No AcceptFlag for lesley hamilton_fox
# 200
# No AcceptFlag for stanley handshy
# 200
# No AcceptFlag for valerie hanft
# 200
# No AcceptFlag for valerie hanft
# 200
# No AcceptFlag for patricia hanley
# 200
# No AcceptFlag for lisa hansard
# 200
# Added AcceptFlag for robert hansen
# 200
# Added AcceptFlag for robert hansen
# 200
# No AcceptFlag for kristen hansen_peterman
# 200
# Added AcceptFlag for naomi hanser
# 200
# No AcceptFlag for miriam hanson
# 200
# No AcceptFlag for keeli hanzelka
# 200
# No AcceptFlag for miranda hardee
# 200
# No AcceptFlag for stephen hardeman
# 200
# No AcceptFlag for roger harden
# 200
# No AcceptFlag for robert harding
# 200
# No AcceptFlag for robert harding
# 200
# No AcceptFlag for brian hardy
# 200
# No AcceptFlag for paul harford
# 200
# No AcceptFlag for kenneth hargrave
# 200
# Added AcceptFlag for john harkins
# 200
# No AcceptFlag for michael harmon
# 200
# No AcceptFlag for j haro
# 200
# No AcceptFlag for benjamin harper
# 200
# No AcceptFlag for clio harper
# 200
# No AcceptFlag for clio harper
# 200
# Added AcceptFlag for glenn harper
# 200
# Added AcceptFlag for glenn harper
# 200
# No AcceptFlag for michael harper
# 200
# No AcceptFlag for c harrington
# 200
# Added AcceptFlag for alexis harris
# 200
# No AcceptFlag for david harris
# 200
# No AcceptFlag for lindsay harrison
# 200
# No AcceptFlag for mary harrison
# 200
# No AcceptFlag for sue_ann harrison
# 200
# Added AcceptFlag for virginia harrod
# 200
# Added AcceptFlag for raymond harshbarger
# 200
# No AcceptFlag for timothy harstad
# 200
# No AcceptFlag for adam hart
# 200
# No AcceptFlag for chris hart
# 200
# No AcceptFlag for chris hart
# 200
# No AcceptFlag for steven hart
# 200
# No AcceptFlag for kristi harvey
# 200
# No AcceptFlag for keren hasbani
# 200
# No AcceptFlag for ateeq haseeb
# 200
# No AcceptFlag for michael hasegawa
# 200
# No AcceptFlag for michael hasegawa
# 200
# No AcceptFlag for patrick haskell
# 200
# No AcceptFlag for karen haslund
# 200
# No AcceptFlag for saman hassibi
# 200
# No AcceptFlag for newton hasson
# 200
# No AcceptFlag for amy hauck
# 200
# No AcceptFlag for sarmistha hauger
# 200
# No AcceptFlag for sarmistha hauger
# 200
# No AcceptFlag for lawrence hauser
# 200
# No AcceptFlag for sharon hausman_cohen
# 200
# No AcceptFlag for kenneth havard
# 200
# No AcceptFlag for benjamin havemann
# 200
# No AcceptFlag for john havlick
# 200
# No AcceptFlag for kristen hawthorne
# 200
# No AcceptFlag for georgia hay
# 200
# Added AcceptFlag for laura_ hayasaka
# 200
# No AcceptFlag for hans haydon
# 200
# No AcceptFlag for michael_scott haydon
# 200
# No AcceptFlag for david hayes
# 200
# No AcceptFlag for royce hayes
# 200
# No AcceptFlag for russell hayhurst
# 200
# No AcceptFlag for alex haynes
# 200
# No AcceptFlag for david hayward
# 200
# No AcceptFlag for andrew heaton
# 200
# No AcceptFlag for claire hebner
# 200
# No AcceptFlag for sanjay hegde
# 200
# No AcceptFlag for eric heinrich
# 200
# Added AcceptFlag for d_dyer heintz
# 200
# Added AcceptFlag for d_dyer heintz
# 200
# Added AcceptFlag for kristopher heinzman
# 200
# Added AcceptFlag for kristopher heinzman
# 200
# Added AcceptFlag for kristopher heinzman
# 200
# Added AcceptFlag for kristopher heinzman
# 200
# No AcceptFlag for beth hellerstedt
# 200
# No AcceptFlag for richard helmer
# 200
# No AcceptFlag for joseph hemerka
# 200
# No AcceptFlag for kathleen henderson
# 200
# No AcceptFlag for jay hendrix
# 200
# No AcceptFlag for jeff henke
# 200
# ...
# 200
# Added AcceptFlag for joseph tayar
# 200
# Added AcceptFlag for joseph tayar
# 200
# Added AcceptFlag for joseph tayar
# 200
# Added AcceptFlag for joseph tayar
# 200
# No AcceptFlag for steven taylor
# 200
# No AcceptFlag for alaa_eddin tayyem
# 200
# No AcceptFlag for dina tebcherany
# 200
# No AcceptFlag for matthew teicher
# 200
# Added AcceptFlag for pedro teixeira
# 200
# No AcceptFlag for javier tellez
# 200
# No AcceptFlag for brian temple
# 200
# No AcceptFlag for michael teneriello
# 200
# No AcceptFlag for rebecca teng
# 200
# No AcceptFlag for lakshmi tenneti
# 200
# No AcceptFlag for eddie tennison
# 200
# No AcceptFlag for raymond teoh
# 200
# No AcceptFlag for david terreson
# 200
# No AcceptFlag for wanda terry
# 200
# No AcceptFlag for daniel terwelp
# 200
# No AcceptFlag for monty tew
# 200
# No AcceptFlag for greg thaera
# 200
# No AcceptFlag for beth thai
# 200
# No AcceptFlag for martin thai
# 200
# No AcceptFlag for nehal thakkar
# 200
# No AcceptFlag for shimona thakrar
# 200
# No AcceptFlag for le_wai thant
# 200
# No AcceptFlag for dimple tharian
# 200
# No AcceptFlag for srivani thatikonda
# 200
# No AcceptFlag for ghulam thaver
# 200
# Added AcceptFlag for lauren thaxton
# 200
# No AcceptFlag for gregory thiel
# 200
# No AcceptFlag for craig thomajan
# 200
# No AcceptFlag for darryl thomas
# 200
# No AcceptFlag for griffith thomas
# 200
# No AcceptFlag for harry thomas
# 200
# No AcceptFlag for jerome thomas
# 200
# No AcceptFlag for sandra thomas
# 200
# No AcceptFlag for sherrie thomas
# 200
# No AcceptFlag for carla thompson
# 200
# No AcceptFlag for jennifer thompson
# 200
# No AcceptFlag for jessica thompson
# 200
# No AcceptFlag for jessica thompson
# 200
# No AcceptFlag for john thompson
# 200
# Added AcceptFlag for robert thompson
# 200
# Added AcceptFlag for tanna thompson
# 200
# No AcceptFlag for troy thompson
# 200
# No AcceptFlag for lynn thoreson
# 200
# No AcceptFlag for kelly thorstad
# 200
# No AcceptFlag for christopher thu
# 200
# No AcceptFlag for ryan tibbetts
# 200
# No AcceptFlag for eric tiblier
# 200
# No AcceptFlag for eric tiblier
# 200
# No AcceptFlag for ryan tierney
# 200
# Added AcceptFlag for jen tiller
# 200
# Added AcceptFlag for jeffrey titus
# 200
# Added AcceptFlag for jeffrey titus
# 200
# Added AcceptFlag for jeffrey titus
# 200
# No AcceptFlag for kelly tjelmeland
# 200
# No AcceptFlag for vincent tjia
# 200
# No AcceptFlag for jorge tobar
# 200
# No AcceptFlag for david tobey
# 200
# No AcceptFlag for laurence tokaz
# 200
# No AcceptFlag for charitha tokur_sridhar
# 200
# No AcceptFlag for scott tolan
# 200
# No AcceptFlag for christa tomc
# 200
# No AcceptFlag for amy tomkins
# 200
# No AcceptFlag for eugene tong
# 200
# No AcceptFlag for traci torbert
# 200
# No AcceptFlag for manuel torres
# 200
# No AcceptFlag for nadja torres
# 200
# No AcceptFlag for zoltan toth
# 200
# No AcceptFlag for leo toupin
# 200
# No AcceptFlag for marisa toups
# 200
# No AcceptFlag for bryan townsend
# 200
# No AcceptFlag for hien tran
# 200
# No AcceptFlag for kenny_bao tran
# 200
# Added AcceptFlag for viet tran
# 200
# Added AcceptFlag for viet tran
# 200
# Added AcceptFlag for viet tran
# 200
# No AcceptFlag for xuan tran
# 200
# No AcceptFlag for wade travis
# 200
# No AcceptFlag for david tremblay
# 200
# No AcceptFlag for elise trentham
# 200
# No AcceptFlag for elliot trester
# 200
# No AcceptFlag for anthony trevino
# 200
# No AcceptFlag for christine trevino
# 200
# Added AcceptFlag for jessica trevino
# 200
# No AcceptFlag for rogelio trevino
# 200
# No AcceptFlag for sandra treybig
# 200
# No AcceptFlag for sandra treybig
# 200
# No AcceptFlag for maria trirogoff
# 200
# No AcceptFlag for mark trisna
# 200
# No AcceptFlag for sigrid tristan
# 200
# No AcceptFlag for zoltan trizna
# 200
# No AcceptFlag for michael trotter
# 200
# No AcceptFlag for simon trubek
# 200
# No AcceptFlag for ginger truitt
# 200
# No AcceptFlag for binh truong
# 200
# No AcceptFlag for kimphuong truong
# 200
# Added AcceptFlag for marc trust
# 200
# Added AcceptFlag for eeric truumees
# 200
# No AcceptFlag for john tsai
# 200
# Added AcceptFlag for rita tsai
# 200
# No AcceptFlag for david tschopp
# 200
# No AcceptFlag for jessica tsourmas
# 200
# No AcceptFlag for annie tsui
# 200
# No AcceptFlag for paul tucker
# 200
# Added AcceptFlag for david tuggle
# 200
# Added AcceptFlag for david tuggle
# 200
# No AcceptFlag for william tullis
# 200
# No AcceptFlag for hari tumu
# 200
# No AcceptFlag for ryan turley
# 200
# No AcceptFlag for david turner
# 200
# No AcceptFlag for trevor turner
# 200
# Added AcceptFlag for john uecker
# 200
# No AcceptFlag for carla underhill
# 200
# No AcceptFlag for anselmo unite
# 200
# No AcceptFlag for athira unnikrishnan
# 200
# No AcceptFlag for marco uribe
# 200
# No AcceptFlag for rodolfo uriegas
# 200
# No AcceptFlag for jose urquidez
# 200
# No AcceptFlag for ana urukalo
# 200
# No AcceptFlag for stephen utts
# 200
# No AcceptFlag for jennifer uxer
# 200
# No AcceptFlag for james uyeki
# 200
# No AcceptFlag for timothy vachris
# 200
# No AcceptFlag for gregg vagner
# 200
# No AcceptFlag for lakshmy vaidyanathan
# 200
# Added AcceptFlag for dan vaisman
# 200
# No AcceptFlag for michael valastro
# 200
# No AcceptFlag for melissa valdez
# 200
# No AcceptFlag for j valenza
# 200
# No AcceptFlag for noreen valla
# 200
# No AcceptFlag for vani vallabhaneni
# 200
# No AcceptFlag for william van_de_graaf
# 200
# No AcceptFlag for amy van_dorfy
# 200
# No AcceptFlag for ryan vancura
# 200
# No AcceptFlag for mariana varga
# 200
# No AcceptFlag for deepa varshney
# 200
# Added AcceptFlag for pooja varshney
# 200
# Added AcceptFlag for pooja varshney
# 200
# No AcceptFlag for divya varu
# 200
# No AcceptFlag for vinit varu
# 200
# Added AcceptFlag for juliana vaughan
# 200
# Added AcceptFlag for juliana vaughan
# 200
# No AcceptFlag for thomas vaughn
# 200
# No AcceptFlag for abhishek vedavalli
# 200
# No AcceptFlag for abhishek vedavalli
# 200
# No AcceptFlag for abhishek vedavalli
# 200
# No AcceptFlag for srihari vegiraju
# 200
# No AcceptFlag for nelly velasquez
# 200
# No AcceptFlag for prasuna velur
# 200
# No AcceptFlag for prasuna velur
# 200
# No AcceptFlag for hareesha vemuganti
# 200
# No AcceptFlag for srinath vemuri
# 200
# No AcceptFlag for vanessa ven_huizen
# 200
# No AcceptFlag for zarmeena vendal
# 200
# No AcceptFlag for sujatha venkatesh
# 200
# No AcceptFlag for preeti venkatraman
# 200
# No AcceptFlag for montgomery verona
# 200
# Added AcceptFlag for thomas vetter
# 200
# Added AcceptFlag for thomas vetter
# 200
# No AcceptFlag for robert vezzetti
# 200
# No AcceptFlag for aleksandra vidacic
# 200
# No AcceptFlag for jay viernes
# 200
# No AcceptFlag for paul vigo
# 200
# No AcceptFlag for mike vik
# 200
# No AcceptFlag for john villacis
# 200
# No AcceptFlag for arturo villarreal
# 200
# Added AcceptFlag for ross vines
# 200
# No AcceptFlag for sanjay vinjamaram
# 200
# No AcceptFlag for malavika vinta
# 200
# No AcceptFlag for amar vira
# 200
# No AcceptFlag for anisha virani
# 200
# No AcceptFlag for anisha virani
# 200
# No AcceptFlag for jaclyn virant
# 200
# No AcceptFlag for david vo
# 200
# No AcceptFlag for glen vo
# 200
# No AcceptFlag for phu vo
# 200
# No AcceptFlag for laurier vocal
# 200
# Added AcceptFlag for katie volkers
# 200
# No AcceptFlag for joseph volpe
# 200
# No AcceptFlag for fred voorhees
# 200
# No AcceptFlag for nandagopal vrindavanam
# 200
# No AcceptFlag for anna vu_wallace
# 200
# No AcceptFlag for julie wachtel
# 200
# No AcceptFlag for julie wachtel
# 200
# No AcceptFlag for galen wachtman
# 200
# No AcceptFlag for john wages
# 200
# No AcceptFlag for nicholas wagner
# 200
# Added AcceptFlag for tara wagner
# 200
# No AcceptFlag for theresa wagner
# 200
# No AcceptFlag for toni wakefield
# 200
# No AcceptFlag for marek walczak
# 200
# No AcceptFlag for jennifer walden
# 200
# No AcceptFlag for james waldron
# 200
# No AcceptFlag for mylynda waldrop
# 200
# Added AcceptFlag for blair walker
# 200
# No AcceptFlag for megan skinner
# 200
# No AcceptFlag for desmar walkes
# 200
# No AcceptFlag for jason wallace
# 200
# No AcceptFlag for andrew walters
# 200
# No AcceptFlag for steven walters
# 200
# No AcceptFlag for thomas walters
# 200
# Added AcceptFlag for amy walton
# 200
# No AcceptFlag for laura waltrip
# 200
# No AcceptFlag for laura waltrip
# 200
# No AcceptFlag for jack walzel
# 200
# No AcceptFlag for andrew wang
# 200
# No AcceptFlag for diana wang
# 200
# No AcceptFlag for mary wang
# 200
# No AcceptFlag for min wang
# 200
# No AcceptFlag for stanley wang
# 200
# Added AcceptFlag for vincent wang
# 200
# Added AcceptFlag for vincent wang
# 200
# Added AcceptFlag for vincent wang
# 200
# Added AcceptFlag for steven warach
# 200
# Added AcceptFlag for steven warach
# 200
# Added AcceptFlag for steven warach
# 200
# No AcceptFlag for jennifer ward
# 200
# No AcceptFlag for michael ward
# 200
# No AcceptFlag for kirsten warhoe
# 200
# No AcceptFlag for kirsten warhoe
# 200
# No AcceptFlag for michael warner
# 200
# No AcceptFlag for kelley warwick
# 200
# No AcceptFlag for kelley warwick
# 200
# No AcceptFlag for lori wasserburger
# 200
# No AcceptFlag for shawn wassmuth
# 200
# No AcceptFlag for zachary wassmuth
# 200
# Added AcceptFlag for michael watkins
# 200
# Added AcceptFlag for michael watkins
# 200
# No AcceptFlag for rebecca watson
# 200
# No AcceptFlag for danny watts
# 200
# No AcceptFlag for dennis watts
# 200
# Added AcceptFlag for andrew weary
# 200
# No AcceptFlag for william weatherby
# 200
# No AcceptFlag for kristopher webb
# 200
# No AcceptFlag for rebecca weber
# 200
# No AcceptFlag for mandy webster
# 200
# No AcceptFlag for elizabeth wedberg
# 200
# No AcceptFlag for elizabeth wedberg
# 200
# No AcceptFlag for elizabeth wedberg
# 200
# No AcceptFlag for david weeks
# 200
# Added AcceptFlag for chamalee weeratunge
# 200
# Added AcceptFlag for chamalee weeratunge
# 200
# No AcceptFlag for blake weidaw
# 200
# No AcceptFlag for eric weidmann
# 200
# No AcceptFlag for thomas weil
# 200
# Added AcceptFlag for adam weinfeld
# 200
# Added AcceptFlag for adam weinfeld
# 200
# No AcceptFlag for jordan weingarten
# 200
# No AcceptFlag for edward weir
# 200
# No AcceptFlag for tracey weir
# 200
# No AcceptFlag for janna welch
# 200
# No AcceptFlag for jonathan welch
# 200
# No AcceptFlag for karen welch
# 200
# Added AcceptFlag for donald wells
# 200
# No AcceptFlag for jennifer wells
# 200
# No AcceptFlag for joe wells
# 200
# No AcceptFlag for leslie wells
# 200
# No AcceptFlag for stephen wells
# 200
# No AcceptFlag for scott welsh
# 200
# No AcceptFlag for john wendel
# 200
# Added AcceptFlag for marc wenzel
# 200
# Added AcceptFlag for marc wenzel
# 200
# No AcceptFlag for isela werchan
# 200
# No AcceptFlag for walter werchan
# 200
# No AcceptFlag for jennifer werdenberg
# 200
# No AcceptFlag for deborah west
# 200
# No AcceptFlag for sara westgate
# 200
# No AcceptFlag for greg westmoreland
# 200
# No AcceptFlag for koren weston
# 200
# No AcceptFlag for robert weston
# 200
# No AcceptFlag for suzanne wetherold
# 200
# No AcceptFlag for kathryn wheeler
# 200
# No AcceptFlag for valerie wheelock
# 200
# No AcceptFlag for timothy whitaker
# 200
# No AcceptFlag for winnie whitaker
# 200
# No AcceptFlag for winnie whitaker
# 200
# No AcceptFlag for alan white
# 200
# Added AcceptFlag for amanda white
# 200
# Added AcceptFlag for amanda white
# 200
# No AcceptFlag for ann white
# 200
# No AcceptFlag for christina white
# 200
# No AcceptFlag for eric white
# 200
# No AcceptFlag for megan white
# 200
# No AcceptFlag for chad whited
# 200
# No AcceptFlag for jeffrey whitehill
# 200
# No AcceptFlag for amanda whiteley
# 200
# No AcceptFlag for amanda whiteley
# 200
# No AcceptFlag for mark whitesides
# 200
# No AcceptFlag for robert whitfield
# 200
# Added AcceptFlag for margaret whitney
# 200
# No AcceptFlag for rebecca wiatrek
# 200
# No AcceptFlag for james widner
# 200
# No AcceptFlag for alfred wilder
# 200
# No AcceptFlag for tyler wildey
# 200
# No AcceptFlag for matthew wilkinson
# 200
# No AcceptFlag for george willeford
# 200
# No AcceptFlag for clarence williams
# 200
# No AcceptFlag for david williams
# 200
# No AcceptFlag for donald williams
# 200
# No AcceptFlag for john williams
# 200
# No AcceptFlag for john williams
# 200
# No AcceptFlag for noelle williams
# 200
# No AcceptFlag for ronald williams
# 200
# Added AcceptFlag for marian williams_brown
# 200
# Added AcceptFlag for marian williams_brown
# 200
# No AcceptFlag for john williamson
# 200
# No AcceptFlag for j_andrew williamson
# 200
# No AcceptFlag for robert williamson
# 200
# No AcceptFlag for andrew willis
# 200
# No AcceptFlag for donald willis
# 200
# No AcceptFlag for james willis
# 200
# Added AcceptFlag for lindsey willis
# 200
# No AcceptFlag for joseph willman
# 200
# No AcceptFlag for robert wills
# 200
# Added AcceptFlag for alexandra wilson
# 200
# Added AcceptFlag for howard wilson
# 200
# No AcceptFlag for james wilson
# 200
# No AcceptFlag for james wilson
# 200
# Added AcceptFlag for janet wilson
# 200
# Added AcceptFlag for janet wilson
# 200
# No AcceptFlag for stephen wilson
# 200
# No AcceptFlag for steve wilson
# 200
# No AcceptFlag for sarah wilson_kennelly
# 200
# No AcceptFlag for e windler
# 200
# No AcceptFlag for bradford winegar
# 200
# No AcceptFlag for mary winsett
# 200
# No AcceptFlag for laura winslett
# 200
# No AcceptFlag for elizabeth winterroth
# 200
# No AcceptFlag for laura wise
# 200
# No AcceptFlag for c wiseman
# 200
# No AcceptFlag for jeremy wiseman
# 200
# No AcceptFlag for gordon witwer
# 200
# No AcceptFlag for ronald wokasien
# 200
# Added AcceptFlag for james wolf
# 200
# No AcceptFlag for lydia wolf
# 200
# No AcceptFlag for annemarie wolfe
# 200
# No AcceptFlag for emily wolfe
# 200
# No AcceptFlag for megan wollan
# 200
# No AcceptFlag for peter wollan
# 200
# No AcceptFlag for peter wollan
# 200
# No AcceptFlag for albert wong
# 200
# No AcceptFlag for frank wong
# 200
# No AcceptFlag for kristin wong
# 200
# No AcceptFlag for mitchel wong
# 200
# No AcceptFlag for robert wong
# 200
# No AcceptFlag for shannon wong
# 200
# No AcceptFlag for april wood
# 200
# No AcceptFlag for glenn wood
# 200
# No AcceptFlag for jeffrey wood
# 200
# No AcceptFlag for prescilla wood
# 200
# No AcceptFlag for sara woods
# 200
# No AcceptFlag for alicia wooldridge
# 200
# Added AcceptFlag for martin woon
# 200
# No AcceptFlag for john worrel
# 200
# No AcceptFlag for sandra worrell
# 200
# Added AcceptFlag for david wright
# 200
# No AcceptFlag for jennifer wright
# 200
# No AcceptFlag for karen wright
# 200
# No AcceptFlag for steven wright
# 200
# No AcceptFlag for william wroe
# 200
# No AcceptFlag for andy wu
# 200
# No AcceptFlag for catherine wu
# 200
# No AcceptFlag for jennifer wu
# 200
# No AcceptFlag for richard wupperman
# 200
# No AcceptFlag for christopher wyatt
# 200
# No AcceptFlag for windy wyatt
# 200
# No AcceptFlag for rey ximenes
# 200
# No AcceptFlag for hayan yacoub
# 200
# No AcceptFlag for vivek yagnik
# 200
# No AcceptFlag for nicholas yagoda
# 200
# No AcceptFlag for vijayalakshmi yalamanchili
# 200
# No AcceptFlag for christopher yang
# 200
# No AcceptFlag for christopher yang
# 200
# No AcceptFlag for jonathan yang
# 200
# No AcceptFlag for sayf yassin
# 200
# No AcceptFlag for courtney yau
# 200
# No AcceptFlag for catherine yee
# 200
# No AcceptFlag for grace yeh
# 200
# No AcceptFlag for shila yelle
# 200
# No AcceptFlag for christina yi
# 200
# No AcceptFlag for david yip
# 200
# Added AcceptFlag for dianna yip
# 200
# Added AcceptFlag for dianna yip
# 200
# No AcceptFlag for michael yium
# 200
# No AcceptFlag for michael yium
# 200
# No AcceptFlag for vanessa yium
# 200
# No AcceptFlag for prameela yoganandan
# 200
# No AcceptFlag for sonja yoo
# 200
# No AcceptFlag for jeffrey yorio
# 200
# No AcceptFlag for jennifer york
# 200
# No AcceptFlag for kathy yoshimura
# 200
# No AcceptFlag for joseph youman
# 200
# No AcceptFlag for joseph youman
# 200
# No AcceptFlag for amy young
# 200
# No AcceptFlag for cindy_ young
# 200
# No AcceptFlag for lindsay young
# 200
# No AcceptFlag for stanford young
# 200
# No AcceptFlag for farheen yousuf
# 200
# No AcceptFlag for sonia yousuf
# 200
# No AcceptFlag for olivia yun
# 200
# No AcceptFlag for stephen yurco
# 200
# Added AcceptFlag for ajay zachariah
# 200
# No AcceptFlag for aveen zachariah
# 200
# No AcceptFlag for james zachary
# 200
# Added AcceptFlag for jamie zachrison
# 200
# Added AcceptFlag for jamie zachrison
# 200
# No AcceptFlag for jason zagrodzky
# 200
# No AcceptFlag for jason zagrodzky
# 200
# No AcceptFlag for jason zagrodzky
# 200
# No AcceptFlag for nida zakiullah
# 200
# No AcceptFlag for nida zakiullah
# 200
# No AcceptFlag for jeffrey zapalac
# 200
# No AcceptFlag for helio zapata
# 200
# No AcceptFlag for thomas zavaleta
# 200
# No AcceptFlag for taimur zeb
# 200
# Added AcceptFlag for mohamad zeineddin
# 200
# No AcceptFlag for chen zhou
# 200
# No AcceptFlag for hana zibdeh_lough
# 200
# No AcceptFlag for frank zidar
# 200
# No AcceptFlag for christopher ziebell
# 200
# No AcceptFlag for carol ziebert
# 200
# No AcceptFlag for carol ziebert
# 200
# No AcceptFlag for john ziebert
# 200
# Added AcceptFlag for david zientek
# 200
# Added AcceptFlag for david zientek
# 200
# No AcceptFlag for michael zimmerman
# 200
# No AcceptFlag for brandon zinn
# 200
# No AcceptFlag for marc zook
# 200
# Added AcceptFlag for r_ zwiener
# 200
# Added AcceptFlag for r_ zwiener
# 200
# Added AcceptFlag for r_ zwiener
# All DocPages scraped!
# You Excel File is ready!

# %% [markdown]
# ### STEP 4: Get Prac NPIs for crossreference
#
# In order to cross reference the docs against our current db, we'll need their individual National Practitioner Number (NPI). For individual docs, thats a Type 1 NPI. We can get that using the NPPES API.
#
#
# CAVEAT: The NPPES API is not foolproof. We'll use name and zipcode to search for NPI, but if there are multiple docs with the same name working in the same Zip, we'll get multiple results.  Here, I'll capture specialty as well, to check against the specialty listed on the hosp roster.  There will still need to be some manual curation of ambiguous NPI matches.  Also, there may need to be manual NPI searches for docs with no NPI results--sometimes they will be listed under previous names or addresses. These edge cases are too specific for a current programatic scrape.

# %%
# Put it all together!
import pandas as pd
import json
import time
import requests
from bs4 import BeautifulSoup
import re
from pandas.io.json import json_normalize

def NPI_API_PROVIDER_NAME(dataframe, delay):
    NPI_API = pd.DataFrame(columns=['basic.first_name', 'basic.last_name','number',  'address_1', 'address_2', 'address_purpose', 'city', 'state', 'postal_code', 'telephone_number', 'fax_number', 'basic.enumeration_date']) #initialize DataFrame
    seconds = delay #define seconds to wait between get requests
    
    for index, row in dataframe.iterrows():
        url_1 = 'https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name='
        url_first_name = row['FirstName']
        url_2 = '&use_first_name_alias=&last_name='
        url_last_name = row['LastName']
        url_3 = '&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code='
        url_zip = row['Zip']
        url_4 = '&country_code=&limit=&skip=&version=2.1'
        url = url_1+url_first_name+url_2+url_last_name+url_3+url_zip+url_4
        print('Query url: '+ url)
        try:
            page = requests.get(url, time.sleep(seconds))
            #print(page.status_code) #for testing
            page_json = json.loads(page.content)
            df = pd.DataFrame.from_dict(json_normalize(page_json['results']), orient='columns')
            taxonomies_with_NPI = pd.io.json.json_normalize(page_json['results'], record_path='taxonomies', meta=['number'])
            df_addresses = pd.merge(df, taxonomies_with_NPI, how='inner', on='number')
            columns_to_keep = ['basic.first_name', 'basic.last_name', 'number',  'desc']
            df_taxonomies_subset = df_addresses.reindex(columns=columns_to_keep)
            #print(df_addresses_subset.head(1)) #for testing
            NPI_API = NPI_API.append(df_taxonomies_subset, ignore_index=True)
            #print(NPI_API.shape) #for testing
            print('NPI added for '+ url_first_name+' '+url_last_name)
        except:
            pass
            print('NPI ERROR for '+ url_first_name+' '+url_last_name)
    return(NPI_API)

# %%
providence_prac_npi = NPI_API_PROVIDER_NAME(FAP_with_affils_formatted, 2)
# Out:
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Chidi&use_first_name_alias=&last_name=Achilefu&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=76712&country_code=&limit=&skip=&version=2.1
# NPI ERROR for Chidi Achilefu
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Joan&use_first_name_alias=&last_name=Admirand&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=78731&country_code=&limit=&skip=&version=2.1
# NPI added for Joan Admirand
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Kathleen&use_first_name_alias=&last_name=Berg&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=76712&country_code=&limit=&skip=&version=2.1
# NPI ERROR for Kathleen Berg
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Kathleen&use_first_name_alias=&last_name=Berg&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=78752&country_code=&limit=&skip=&version=2.1
# NPI ERROR for Kathleen Berg
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=John&use_first_name_alias=&last_name=Biboa&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=76712&country_code=&limit=&skip=&version=2.1
# NPI added for John Biboa
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Adam&use_first_name_alias=&last_name=Borowski&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=76712&country_code=&limit=&skip=&version=2.1
# NPI ERROR for Adam Borowski
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Steven&use_first_name_alias=&last_name=Burgard&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=76712&country_code=&limit=&skip=&version=2.1
# NPI added for Steven Burgard
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Larry&use_first_name_alias=&last_name=Cartmell&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=76710&country_code=&limit=&skip=&version=2.1
# NPI ERROR for Larry Cartmell
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Larry&use_first_name_alias=&last_name=Cartmell&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=76712&country_code=&limit=&skip=&version=2.1
# NPI ERROR for Larry Cartmell
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Cary&use_first_name_alias=&last_name=Chisholm&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=76712&country_code=&limit=&skip=&version=2.1
# NPI ERROR for Cary Chisholm
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=G.&use_first_name_alias=&last_name=Clark&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=76712&country_code=&limit=&skip=&version=2.1
# NPI ERROR for G. Clark
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Amy&use_first_name_alias=&last_name=Coffey&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=78731&country_code=&limit=&skip=&version=2.1
# NPI added for Amy Coffey
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Holly&use_first_name_alias=&last_name=Davis&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=76712&country_code=&limit=&skip=&version=2.1
# NPI added for Holly Davis
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Larry&use_first_name_alias=&last_name=Davis&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=76712&country_code=&limit=&skip=&version=2.1
# NPI added for Larry Davis
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Nelson&use_first_name_alias=&last_name=DeStaffany&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=76712&country_code=&limit=&skip=&version=2.1
# NPI added for Nelson DeStaffany
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Tamara&use_first_name_alias=&last_name=Dutter&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=76712&country_code=&limit=&skip=&version=2.1
# NPI ERROR for Tamara Dutter
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Steven&use_first_name_alias=&last_name=Elwell&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=76712&country_code=&limit=&skip=&version=2.1
# NPI added for Steven Elwell
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Gary&use_first_name_alias=&last_name=Fischer&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=76712&country_code=&limit=&skip=&version=2.1
# NPI added for Gary Fischer
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Nathan&use_first_name_alias=&last_name=Forrest&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=76712&country_code=&limit=&skip=&version=2.1
# NPI added for Nathan Forrest
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Paul&use_first_name_alias=&last_name=Gaudin&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=78731&country_code=&limit=&skip=&version=2.1
# NPI added for Paul Gaudin
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Gary&use_first_name_alias=&last_name=Geldmeier&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=76710&country_code=&limit=&skip=&version=2.1
# NPI ERROR for Gary Geldmeier
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Gary&use_first_name_alias=&last_name=Geldmeier&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=76712&country_code=&limit=&skip=&version=2.1
# NPI ERROR for Gary Geldmeier
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=James&use_first_name_alias=&last_name=Goodsett&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=76712&country_code=&limit=&skip=&version=2.1
# NPI ERROR for James Goodsett
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Christopher&use_first_name_alias=&last_name=Greener&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=76712&country_code=&limit=&skip=&version=2.1
# NPI added for Christopher Greener
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Rebecca&use_first_name_alias=&last_name=Guess&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=76712&country_code=&limit=&skip=&version=2.1
# NPI added for Rebecca Guess
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Casey&use_first_name_alias=&last_name=Hector&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=76712&country_code=&limit=&skip=&version=2.1
# NPI added for Casey Hector
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=R.&use_first_name_alias=&last_name=Hendricks&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=76712&country_code=&limit=&skip=&version=2.1
# NPI ERROR for R. Hendricks
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Eric&use_first_name_alias=&last_name=Higginbotham&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=78752&country_code=&limit=&skip=&version=2.1
# NPI ERROR for Eric Higginbotham
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Eric&use_first_name_alias=&last_name=Higginbotham&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=76712&country_code=&limit=&skip=&version=2.1
# NPI ERROR for Eric Higginbotham
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Adam&use_first_name_alias=&last_name=Johnson&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=76710&country_code=&limit=&skip=&version=2.1
# NPI ERROR for Adam Johnson
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Adam&use_first_name_alias=&last_name=Johnson&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=76712&country_code=&limit=&skip=&version=2.1
# NPI added for Adam Johnson
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Mark&use_first_name_alias=&last_name=Johnson&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=76712&country_code=&limit=&skip=&version=2.1
# NPI ERROR for Mark Johnson
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Soni&use_first_name_alias=&last_name=Jose&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=76712&country_code=&limit=&skip=&version=2.1
# NPI added for Soni Jose
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=James&use_first_name_alias=&last_name=Kavanagh&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=76712&country_code=&limit=&skip=&version=2.1
# NPI added for James Kavanagh
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Howard&use_first_name_alias=&last_name=Klaskin&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=76712&country_code=&limit=&skip=&version=2.1
# NPI added for Howard Klaskin
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Timothy&use_first_name_alias=&last_name=Kolda&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=78731&country_code=&limit=&skip=&version=2.1
# NPI added for Timothy Kolda
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Chandra&use_first_name_alias=&last_name=Krishnan&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=78723&country_code=&limit=&skip=&version=2.1
# NPI ERROR for Chandra Krishnan
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Chandra&use_first_name_alias=&last_name=Krishnan&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=78731&country_code=&limit=&skip=&version=2.1
# NPI added for Chandra Krishnan
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Brent&use_first_name_alias=&last_name=Kutach&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=76712&country_code=&limit=&skip=&version=2.1
# NPI added for Brent Kutach
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Benjamin&use_first_name_alias=&last_name=LaGrone&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=76712&country_code=&limit=&skip=&version=2.1
# NPI added for Benjamin LaGrone
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Suzanne&use_first_name_alias=&last_name=Ledet&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=78731&country_code=&limit=&skip=&version=2.1
# NPI added for Suzanne Ledet
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Derek&use_first_name_alias=&last_name=Lee&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=76712&country_code=&limit=&skip=&version=2.1
# NPI added for Derek Lee
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Jeffrey&use_first_name_alias=&last_name=Manning&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=76712&country_code=&limit=&skip=&version=2.1
# NPI added for Jeffrey Manning
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Amy&use_first_name_alias=&last_name=McCourt&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=76712&country_code=&limit=&skip=&version=2.1
# NPI added for Amy McCourt
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Douglas&use_first_name_alias=&last_name=Michaels&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=76712&country_code=&limit=&skip=&version=2.1
# NPI added for Douglas Michaels
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Douglas&use_first_name_alias=&last_name=Michaels&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=21509&country_code=&limit=&skip=&version=2.1
# NPI ERROR for Douglas Michaels
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Gregory&use_first_name_alias=&last_name=Newman&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=76712&country_code=&limit=&skip=&version=2.1
# NPI added for Gregory Newman
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Alan&use_first_name_alias=&last_name=Northcutt&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=76710&country_code=&limit=&skip=&version=2.1
# NPI ERROR for Alan Northcutt
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Alan&use_first_name_alias=&last_name=Northcutt&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=76712&country_code=&limit=&skip=&version=2.1
# NPI added for Alan Northcutt
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=James&use_first_name_alias=&last_name=Olmsted&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=76712&country_code=&limit=&skip=&version=2.1
# NPI added for James Olmsted
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Susan&use_first_name_alias=&last_name=Pacinda&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=78731&country_code=&limit=&skip=&version=2.1
# NPI added for Susan Pacinda
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Dennis&use_first_name_alias=&last_name=Parks&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=76712&country_code=&limit=&skip=&version=2.1
# NPI added for Dennis Parks
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Erin&use_first_name_alias=&last_name=Prince&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=76712&country_code=&limit=&skip=&version=2.1
# NPI ERROR for Erin Prince
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Amanda&use_first_name_alias=&last_name=Rivera-Begeman&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=78731&country_code=&limit=&skip=&version=2.1
# NPI added for Amanda Rivera-Begeman
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Claudius&use_first_name_alias=&last_name=Robinson&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=76710&country_code=&limit=&skip=&version=2.1
# NPI ERROR for Claudius Robinson
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Claudius&use_first_name_alias=&last_name=Robinson&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=76712&country_code=&limit=&skip=&version=2.1
# NPI added for Claudius Robinson
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Roxann&use_first_name_alias=&last_name=Samples&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=76712&country_code=&limit=&skip=&version=2.1
# NPI added for Roxann Samples
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Roxann&use_first_name_alias=&last_name=Samples&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=76712&country_code=&limit=&skip=&version=2.1
# NPI added for Roxann Samples
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Timothy&use_first_name_alias=&last_name=Schmidt&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=76712&country_code=&limit=&skip=&version=2.1
# NPI added for Timothy Schmidt
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Barry&use_first_name_alias=&last_name=Shefa&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=76712&country_code=&limit=&skip=&version=2.1
# NPI ERROR for Barry Shefa
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Daniel&use_first_name_alias=&last_name=Smith&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=76710&country_code=&limit=&skip=&version=2.1
# NPI added for Daniel Smith
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Daniel&use_first_name_alias=&last_name=Smith&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=76712&country_code=&limit=&skip=&version=2.1
# NPI ERROR for Daniel Smith
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Kathleen&use_first_name_alias=&last_name=Sorensen&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=76712&country_code=&limit=&skip=&version=2.1
# NPI added for Kathleen Sorensen
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Horacio&use_first_name_alias=&last_name=Sosa&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=76712&country_code=&limit=&skip=&version=2.1
# NPI ERROR for Horacio Sosa
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Michael&use_first_name_alias=&last_name=Teichelmann&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=76712&country_code=&limit=&skip=&version=2.1
# NPI added for Michael Teichelmann
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Christopher&use_first_name_alias=&last_name=Thompson&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=76710&country_code=&limit=&skip=&version=2.1
# NPI ERROR for Christopher Thompson
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Christopher&use_first_name_alias=&last_name=Thompson&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=76712&country_code=&limit=&skip=&version=2.1
# NPI added for Christopher Thompson
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Gustavo&use_first_name_alias=&last_name=Villarreal&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=76712&country_code=&limit=&skip=&version=2.1
# NPI ERROR for Gustavo Villarreal
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Min&use_first_name_alias=&last_name=Wang&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=78731&country_code=&limit=&skip=&version=2.1
# NPI added for Min Wang
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Ann&use_first_name_alias=&last_name=White&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=78731&country_code=&limit=&skip=&version=2.1
# NPI added for Ann White
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Jeffery&use_first_name_alias=&last_name=White&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=76712&country_code=&limit=&skip=&version=2.1
# NPI added for Jeffery White
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Thomas&use_first_name_alias=&last_name=White&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=76712&country_code=&limit=&skip=&version=2.1
# NPI added for Thomas White
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Eliot&use_first_name_alias=&last_name=Wickliff&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=76711&country_code=&limit=&skip=&version=2.1
# NPI ERROR for Eliot Wickliff
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Roger&use_first_name_alias=&last_name=Williams&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=76712&country_code=&limit=&skip=&version=2.1
# NPI added for Roger Williams

# %% [markdown]
# #### NPI data carpentry

# %%
#providence_prac_npiLocations = providence_prac_npi[providence_prac_npi["address_purpose"]=='LOCATION']
providence_prac_npi
# Out:
#    address_1 address_2 address_purpose basic.enumeration_date  \
# 0        NaN       NaN             NaN                    NaN
# 1        NaN       NaN             NaN                    NaN
# 2        NaN       NaN             NaN                    NaN
# 3        NaN       NaN             NaN                    NaN
# 4        NaN       NaN             NaN                    NaN
# 5        NaN       NaN             NaN                    NaN
# 6        NaN       NaN             NaN                    NaN
# 7        NaN       NaN             NaN                    NaN
# 8        NaN       NaN             NaN                    NaN
# 9        NaN       NaN             NaN                    NaN
# 10       NaN       NaN             NaN                    NaN
# 11       NaN       NaN             NaN                    NaN
# 12       NaN       NaN             NaN                    NaN
# 13       NaN       NaN             NaN                    NaN
# 14       NaN       NaN             NaN                    NaN
# 15       NaN       NaN             NaN                    NaN
# 16       NaN       NaN             NaN                    NaN
# 17       NaN       NaN             NaN                    NaN
# 18       NaN       NaN             NaN                    NaN
# 19       NaN       NaN             NaN                    NaN
# 20       NaN       NaN             NaN                    NaN
# 21       NaN       NaN             NaN                    NaN
# 22       NaN       NaN             NaN                    NaN
# 23       NaN       NaN             NaN                    NaN
# 24       NaN       NaN             NaN                    NaN
# 25       NaN       NaN             NaN                    NaN
# 26       NaN       NaN             NaN                    NaN
# 27       NaN       NaN             NaN                    NaN
# 28       NaN       NaN             NaN                    NaN
# 29       NaN       NaN             NaN                    NaN
# 30       NaN       NaN             NaN                    NaN
# 31       NaN       NaN             NaN                    NaN
# 32       NaN       NaN             NaN                    NaN
# 33       NaN       NaN             NaN                    NaN
# 34       NaN       NaN             NaN                    NaN
# 35       NaN       NaN             NaN                    NaN
# 36       NaN       NaN             NaN                    NaN
# 37       NaN       NaN             NaN                    NaN
# 38       NaN       NaN             NaN                    NaN
# 39       NaN       NaN             NaN                    NaN
# 40       NaN       NaN             NaN                    NaN
# 41       NaN       NaN             NaN                    NaN
# 42       NaN       NaN             NaN                    NaN
# 43       NaN       NaN             NaN                    NaN
# 44       NaN       NaN             NaN                    NaN
# 45       NaN       NaN             NaN                    NaN
# 46       NaN       NaN             NaN                    NaN
# 47       NaN       NaN             NaN                    NaN
# 48       NaN       NaN             NaN                    NaN
# 49       NaN       NaN             NaN                    NaN
# 50       NaN       NaN             NaN                    NaN
#
#    basic.first_name basic.last_name city  \
# 0              JOAN        ADMIRAND  NaN
# 1              JOHN           BIBOA  NaN
# 2            STEVEN         BURGARD  NaN
# 3               AMY          COFFEY  NaN
# 4               AMY          COFFEY  NaN
# 5             HOLLY           DAVIS  NaN
# 6             LARRY           DAVIS  NaN
# 7            NELSON      DESTAFFANY  NaN
# 8            STEVEN          ELWELL  NaN
# 9              GARY         FISCHER  NaN
# 10           NATHAN         FORREST  NaN
# 11             PAUL          GAUDIN  NaN
# 12      CHRISTOPHER         GREENER  NaN
# 13          REBECCA           GUESS  NaN
# 14            CASEY          HECTOR  NaN
# 15             ADAM         JOHNSON  NaN
# 16             ADAM         JOHNSON  NaN
# 17             SONI            JOSE  NaN
# 18            JAMES        KAVANAGH  NaN
# 19           HOWARD         KLASKIN  NaN
# 20          TIMOTHY           KOLDA  NaN
# 21          CHANDRA        KRISHNAN  NaN
# 22          CHANDRA        KRISHNAN  NaN
# 23            BRENT          KUTACH  NaN
# 24         BENJAMIN         LAGRONE  NaN
# 25          SUZANNE           LEDET  NaN
# 26            DEREK             LEE  NaN
# 27          JEFFREY         MANNING  NaN
# 28              AMY         MCCOURT  NaN
# 29          DOUGLAS        MICHAELS  NaN
# 30          GREGORY          NEWMAN  NaN
# 31             ALAN       NORTHCUTT  NaN
# 32             ALAN       NORTHCUTT  NaN
# 33            JAMES         OLMSTED  NaN
# 34            SUSAN         PACINDA  NaN
# 35           DENNIS           PARKS  NaN
# 36           AMANDA  RIVERA-BEGEMAN  NaN
# 37         CLAUDIUS        ROBINSON  NaN
# 38           ROXANN         SAMPLES  NaN
# 39           ROXANN         SAMPLES  NaN
# 40          TIMOTHY         SCHMIDT  NaN
# 41           DANIEL           SMITH  NaN
# 42           DANIEL           SMITH  NaN
# 43         KATHLEEN        SORENSEN  NaN
# 44          MICHAEL     TEICHELMANN  NaN
# 45      CHRISTOPHER        THOMPSON  NaN
# 46              MIN            WANG  NaN
# 47              ANN           WHITE  NaN
# 48          JEFFERY           WHITE  NaN
# 49           THOMAS           WHITE  NaN
# 50            ROGER        WILLIAMS  NaN
#
#                                                  desc fax_number      number  \
# 0                        Pathology Anatomic Pathology        NaN  1356441596
# 1                                   Internal Medicine        NaN  1083990584
# 2                                      Anesthesiology        NaN  1851480438
# 3   Student in an Organized Health Care Education/...        NaN  1417223389
# 4                        Pathology Anatomic Pathology        NaN  1417223389
# 5                                      Anesthesiology        NaN  1225127749
# 6                                      Legal Medicine        NaN  1285600668
# 7                                      Anesthesiology        NaN  1376598912
# 8                                   Internal Medicine        NaN  1336112556
# 9                                      Anesthesiology        NaN  1578574299
# 10                     Radiology Diagnostic Radiology        NaN  1295795664
# 11                       Pathology Anatomic Pathology        NaN  1134180672
# 12                                     Anesthesiology        NaN  1831288372
# 13                                     Anesthesiology        NaN  1982793519
# 14                                     Anesthesiology        NaN  1225127871
# 15  Pathology Anatomic Pathology & Clinical Pathology        NaN  1477812725
# 16                       Pathology Clinical Pathology        NaN  1477812725
# 17                                  Internal Medicine        NaN  1043431992
# 18                                     Anesthesiology        NaN  1710076328
# 19                     Radiology Diagnostic Radiology        NaN  1710948336
# 20  Pathology Anatomic Pathology & Clinical Pathology        NaN  1295790608
# 21  Pathology Anatomic Pathology & Clinical Pathology        NaN  1679763833
# 22  Pathology Anatomic Pathology & Clinical Pathology        NaN  1679763833
# 23                                     Anesthesiology        NaN  1821187402
# 24                                     Anesthesiology        NaN  1285723882
# 25  Pathology Anatomic Pathology & Clinical Pathology        NaN  1588629901
# 26                                  Internal Medicine        NaN  1437341328
# 27                                     Anesthesiology        NaN  1235228784
# 28                     Radiology Diagnostic Radiology        NaN  1326009721
# 29  Pathology Anatomic Pathology & Clinical Pathology        NaN  1467463059
# 30                                     Anesthesiology        NaN  1679662159
# 31                         Pathology Dermatopathology        NaN  1689685125
# 32  Pathology Anatomic Pathology & Clinical Pathology        NaN  1689685125
# 33                     Radiology Diagnostic Radiology        NaN  1659331601
# 34  Pathology Anatomic Pathology & Clinical Pathology        NaN  1881650208
# 35                     Radiology Diagnostic Radiology        NaN  1346200870
# 36                       Pathology Anatomic Pathology        NaN  1376675371
# 37  Pathology Anatomic Pathology & Clinical Pathology        NaN  1710965421
# 38                                  Internal Medicine        NaN  1184796252
# 39                                  Internal Medicine        NaN  1184796252
# 40                                     Anesthesiology        NaN  1417046046
# 41                            Pathology Cytopathology        NaN  1063774214
# 42  Pathology Anatomic Pathology & Clinical Pathology        NaN  1063774214
# 43                     Radiology Diagnostic Radiology        NaN  1295775765
# 44                                     Anesthesiology        NaN  1922197458
# 45  Pathology Anatomic Pathology & Clinical Pathology        NaN  1366741910
# 46   Pathology Clinical Pathology/Laboratory Medicine        NaN  1982642211
# 47  Pathology Anatomic Pathology & Clinical Pathology        NaN  1164488912
# 48      Radiology Vascular & Interventional Radiology        NaN  1558564641
# 49                                     Anesthesiology        NaN  1174612741
# 50                                     Anesthesiology        NaN  1467643650
#
#    postal_code state telephone_number
# 0          NaN   NaN              NaN
# 1          NaN   NaN              NaN
# 2          NaN   NaN              NaN
# 3          NaN   NaN              NaN
# 4          NaN   NaN              NaN
# 5          NaN   NaN              NaN
# 6          NaN   NaN              NaN
# 7          NaN   NaN              NaN
# 8          NaN   NaN              NaN
# 9          NaN   NaN              NaN
# 10         NaN   NaN              NaN
# 11         NaN   NaN              NaN
# 12         NaN   NaN              NaN
# 13         NaN   NaN              NaN
# 14         NaN   NaN              NaN
# 15         NaN   NaN              NaN
# 16         NaN   NaN              NaN
# 17         NaN   NaN              NaN
# 18         NaN   NaN              NaN
# 19         NaN   NaN              NaN
# 20         NaN   NaN              NaN
# 21         NaN   NaN              NaN
# 22         NaN   NaN              NaN
# 23         NaN   NaN              NaN
# 24         NaN   NaN              NaN
# 25         NaN   NaN              NaN
# 26         NaN   NaN              NaN
# 27         NaN   NaN              NaN
# 28         NaN   NaN              NaN
# 29         NaN   NaN              NaN
# 30         NaN   NaN              NaN
# 31         NaN   NaN              NaN
# 32         NaN   NaN              NaN
# 33         NaN   NaN              NaN
# 34         NaN   NaN              NaN
# 35         NaN   NaN              NaN
# 36         NaN   NaN              NaN
# 37         NaN   NaN              NaN
# 38         NaN   NaN              NaN
# 39         NaN   NaN              NaN
# 40         NaN   NaN              NaN
# 41         NaN   NaN              NaN
# 42         NaN   NaN              NaN
# 43         NaN   NaN              NaN
# 44         NaN   NaN              NaN
# 45         NaN   NaN              NaN
# 46         NaN   NaN              NaN
# 47         NaN   NaN              NaN
# 48         NaN   NaN              NaN
# 49         NaN   NaN              NaN
# 50         NaN   NaN              NaN

# %%
providence_prac_npiLocations_npi_only = providence_prac_npi.loc[:,['basic.first_name', 'basic.last_name', 'number', 'desc']]
providence_prac_npiLocations_npi_only.drop_duplicates(inplace = True)
providence_prac_npiLocations_npi_only.head()
# Out:
#   basic.first_name basic.last_name      number  \
# 0             JOAN        ADMIRAND  1356441596
# 1             JOHN           BIBOA  1083990584
# 2           STEVEN         BURGARD  1851480438
# 3              AMY          COFFEY  1417223389
# 4              AMY          COFFEY  1417223389
#
#                                                 desc
# 0                       Pathology Anatomic Pathology
# 1                                  Internal Medicine
# 2                                     Anesthesiology
# 3  Student in an Organized Health Care Education/...
# 4                       Pathology Anatomic Pathology

# %%
providence_prac_npiLocations_npi_only['FirstName'] = providence_prac_npiLocations_npi_only['basic.first_name'].str.title()
providence_prac_npiLocations_npi_only['LastName'] = providence_prac_npiLocations_npi_only['basic.last_name'].str.title()

providence_hospital_affils_npi = pd.merge(FAP_with_affils_formatted, providence_prac_npiLocations_npi_only, 
                               how = 'left',
                               on = ['FirstName', 'LastName'])
providence_hospital_affils_npi.head()
# Out:
#   FirstName  LastName Credentials  \
# 0     Chidi  Achilefu          MD
# 1      Joan  Admirand          MD
# 2  Kathleen      Berg          MD
# 3  Kathleen      Berg          MD
# 4      John     Biboa          DO
#
#                                         Specialties  \
# 0                                    Anesthesiology
# 1                                         Pathology
# 2  Pediatric Emergency Medicine, Emergency Medicine
# 3  Pediatric Emergency Medicine, Emergency Medicine
# 4                                       Hospitalist
#
#                                               Groups  \
# 0                Mid Tex Anesthesia Associates, P.A.
# 1                      Clinical Pathology Associates
# 2  US Acute Care Solutions, US Acute Care Solutio...
# 3  US Acute Care Solutions, US Acute Care Solutio...
# 4         McLennan County Hospitalist Services, P.C.
#
#                                           MapAddress    Zip  \
# 0        405 Londonderry Dr Suite 105 Waco, TX 76712  76712
# 1  3445 Executive Center Dr. Suite 250 Austin, TX...  78731
# 2                6901 Medical Parkway Waco, TX 76712  76712
# 3       6300 La Calma Dr. Suite 200 Austin, TX 78752  78752
# 4                6901 Medical Parkway Waco, TX 76712  76712
#
#          hospitalAffiliations basic.first_name basic.last_name      number  \
# 0  [Providence Health Center]              NaN             NaN         NaN
# 1  [Providence Health Center]             JOAN        ADMIRAND  1356441596
# 2  [Providence Health Center]              NaN             NaN         NaN
# 3  [Providence Health Center]              NaN             NaN         NaN
# 4  [Providence Health Center]             JOHN           BIBOA  1083990584
#
#                            desc
# 0                           NaN
# 1  Pathology Anatomic Pathology
# 2                           NaN
# 3                           NaN
# 4             Internal Medicine

# %%
providence_hospital_affils_npi.columns
# Out:
# Index(['FirstName', 'LastName', 'Credentials', 'Specialties', 'Groups',
#        'MapAddress', 'hospitalAffiliations', 'basic.first_name',
#        'basic.last_name', 'number'],
#       dtype='object')

# %%
providence_subset = providence_hospital_affils_npi[['FirstName', 'LastName', 'number', 'Credentials', 'Specialties', 'desc','Groups',
       'MapAddress', 'hospitalAffiliations']]
providence_subset.head()
# Out:
#   FirstName  LastName      number Credentials  \
# 0     Chidi  Achilefu         NaN          MD
# 1      Joan  Admirand  1356441596          MD
# 2  Kathleen      Berg         NaN          MD
# 3  Kathleen      Berg         NaN          MD
# 4      John     Biboa  1083990584          DO
#
#                                         Specialties  \
# 0                                    Anesthesiology
# 1                                         Pathology
# 2  Pediatric Emergency Medicine, Emergency Medicine
# 3  Pediatric Emergency Medicine, Emergency Medicine
# 4                                       Hospitalist
#
#                            desc  \
# 0                           NaN
# 1  Pathology Anatomic Pathology
# 2                           NaN
# 3                           NaN
# 4             Internal Medicine
#
#                                               Groups  \
# 0                Mid Tex Anesthesia Associates, P.A.
# 1                      Clinical Pathology Associates
# 2  US Acute Care Solutions, US Acute Care Solutio...
# 3  US Acute Care Solutions, US Acute Care Solutio...
# 4         McLennan County Hospitalist Services, P.C.
#
#                                           MapAddress  \
# 0        405 Londonderry Dr Suite 105 Waco, TX 76712
# 1  3445 Executive Center Dr. Suite 250 Austin, TX...
# 2                6901 Medical Parkway Waco, TX 76712
# 3       6300 La Calma Dr. Suite 200 Austin, TX 78752
# 4                6901 Medical Parkway Waco, TX 76712
#
#          hospitalAffiliations
# 0  [Providence Health Center]
# 1  [Providence Health Center]
# 2  [Providence Health Center]
# 3  [Providence Health Center]
# 4  [Providence Health Center]

# %%
from pandas import ExcelWriter
filename = 'Providence_HospSpecialties_Affiliations_with_NPI.xlsx'

with ExcelWriter(filename) as writer:
        providence_subset.to_excel(writer, sheet_name='ProvidenceHospSpecAffils')
