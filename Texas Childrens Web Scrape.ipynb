# %% [markdown]
# ## Texas Children's Hospital Affiliation Web Scrape
#
# The goal of this project is to find all the provider info from the Seton FAP website (https://www.texaschildrens.org/doctors)
#
# Notes: the complete list of provider info is on that page; each bio page contains affiliation info; same website structure as Seton (both Ascension hosps)
#
# ### Overview
# 1. Get all provider info from initial page
# 3. Scrape affils for all Providers listed on page
#
# ### Get all Provider Info
#
# ##### Notes:
# 1. Search by specialty for the following specialties listed on site (needed to search/manually get these):
#     Anesthesiology (code: 1451; 6 pages)
#     Emergency Medicine (1506; 3 pages)
#     Neonatology (1496; 4 pages)
#     Nuclear Radiology (1641; 2 pages)
#     Pathology (1491; 3 pages)
#     Pediatric Radiology (1521; 3 pages)
#     OBGYN Anesthesiology (1651; 2 pages)
#
# 2. page address structure: "https://www.texaschildrens.org/doctorslist?title=&field_specialty_tid=1451&page=1" (zero start)
#
# 3. User-agent: *
# Crawl-delay: 10

# %%
import pandas as pd
import time
import numpy as np

# %% [markdown]
# #### web scrape testing:
#
# I'll test out the beautiful soup approaches to get the info I want

# %%
import requests
page = requests.get("https://www.texaschildrens.org/doctorslist?title=&field_specialty_tid=1451&page=1")
page.status_code
# Out:
# 200

# %%
from bs4 import BeautifulSoup, CData
soup = BeautifulSoup(page.content, 'html.parser')

# %%
#get all the doc info content on each page
content_entries = soup.find_all(class_='view-content')
content_entries[0]
# Out:
# <div class="view-content">
# <div class="views-responsive-grid views-responsive-grid-horizontal views-columns-4">
# <div class="views-row views-row-1 views-row-first">
# <div class="views-column views-column-1 views-column-first">
# <div class="views-field views-field-field-photo"> <div class="field-content"><a href="/find-a-doctor/kathleen-chen-md-ms"><img alt="" height="165" src="https://www.texaschildrens.org/sites/default/files/styles/search_thumbnail/public/chen.jpeg?itok=LOcKWaRx" typeof="foaf:Image" width="165"/></a></div> </div>
# <div class="views-field views-field-title"> <span class="field-content"><a href="/find-a-doctor/kathleen-chen-md-ms">Kathleen Chen, MD, MS</a></span> </div>
# <div> <div></div> </div> </div>
# <div class="views-column views-column-2">
# <div class="views-field views-field-field-photo"> <div class="field-content"><a href="/find-a-doctor/julia-han-chen-md"><img alt="" height="165" src="https://www.texaschildrens.org/sites/default/files/styles/search_thumbnail/public/Chen%2C%20Julia.1559.1._1CDC77B.jpg?itok=giyJqfq6" typeof="foaf:Image" width="165"/></a></div> </div>
# <div class="views-field views-field-title"> <span class="field-content"><a href="/find-a-doctor/julia-han-chen-md">Julia Han Chen, MD</a></span> </div>
# <div> <div></div> </div> </div>
# <div class="views-column views-column-3">
# <div class="views-field views-field-field-photo"> <div class="field-content"><a href="/find-a-doctor/monica-chen-md"><img alt="" height="165" src="https://www.texaschildrens.org/sites/default/files/styles/search_thumbnail/public/MonicaChen.jpg?itok=QckLLyNT" typeof="foaf:Image" width="165"/></a></div> </div>
# <div class="views-field views-field-title"> <span class="field-content"><a href="/find-a-doctor/monica-chen-md">Monica Chen, MD</a></span> </div>
# <div> <div></div> </div> </div>
# <div class="views-column views-column-4 views-column-last">
# <div class="views-field views-field-field-photo"> <div class="field-content"><a href="/find-a-doctor/kevin-chu-md"><img alt="" height="165" src="https://www.texaschildrens.org/sites/default/files/styles/search_thumbnail/public/KevinChu.jpg?itok=16g-JgfQ" typeof="foaf:Image" width="165"/></a></div> </div>
# <div class="views-field views-field-title"> <span class="field-content"><a href="/find-a-doctor/kevin-chu-md">Kevin Chu, MD</a></span> </div>
# <div> <div></div> </div> </div>
# </div>
# <div class="views-row views-row-2">
# <div class="views-column views-column-1 views-column-first">
# <div class="views-field views-field-field-photo"> <div class="field-content"><a href="/find-a-doctor/nana-e-coleman-md"><img alt="" height="165" src="https://www.texaschildrens.org/sites/default/files/styles/search_thumbnail/public/Coleman.JPG?itok=cycz3lsl" typeof="foaf:Image" width="165"/></a></div> </div>
# <div class="views-field views-field-title"> <span class="field-content"><a href="/find-a-doctor/nana-e-coleman-md">Nana E. Coleman, MD</a></span> </div>
# <div> <div></div> </div> </div>
# <div class="views-column views-column-2">
# <div class="views-field views-field-field-photo"> <div class="field-content"><a href="/find-a-doctor/camille-m-colomb-md"><img alt="" height="165" src="https://www.texaschildrens.org/sites/default/files/styles/search_thumbnail/public/Colomb.Camille.15575.pedi_anest_F0CF.jpg?itok=OM3hwy2p" typeof="foaf:Image" width="165"/></a></div> </div>
# <div class="views-field views-field-title"> <span class="field-content"><a href="/find-a-doctor/camille-m-colomb-md">Camille M. Colomb, MD</a></span> </div>
# <div> <div></div> </div> </div>
# <div class="views-column views-column-3">
# <div class="views-field views-field-field-photo"> <div class="field-content"><a href="/find-a-doctor/michelle-r-dalton-md"><img alt="" height="165" src="https://www.texaschildrens.org/sites/default/files/styles/search_thumbnail/public/Caballero-Dalton%2C%20Michelle.jpg?itok=vLDD59-l" typeof="foaf:Image" width="165"/></a></div> </div>
# <div class="views-field views-field-title"> <span class="field-content"><a href="/find-a-doctor/michelle-r-dalton-md">Michelle R. Dalton, MD</a></span> </div>
# <div> <div></div> </div> </div>
# <div class="views-column views-column-4 views-column-last">
# <div class="views-field views-field-field-photo"> <div class="field-content"><a href="/find-a-doctor/moreshwar-s-desai-md"><img alt="" height="165" src="https://www.texaschildrens.org/sites/default/files/styles/search_thumbnail/public/Desai.Moreshwar.S.143433.Pedi-CC.jpg?itok=ZOy-o8qa" typeof="foaf:Image" width="165"/></a></div> </div>
# <div class="views-field views-field-title"> <span class="field-content"><a href="/find-a-doctor/moreshwar-s-desai-md">Moreshwar S. Desai, MD</a></span> </div>
# <div> <div></div> </div> </div>
# </div>
# <div class="views-row views-row-3">
# <div class="views-column views-column-1 views-column-first">
# <div class="views-field views-field-field-photo"> <div class="field-content"><a href="/find-a-doctor/ronald-blaine-easley-md"><img alt="" height="165" src="https://www.texaschildrens.org/sites/default/files/styles/search_thumbnail/public/Easley%2C%20Ronald%20Blaine.jpg?itok=ogHezRC5" typeof="foaf:Image" width="165"/></a></div> </div>
# <div class="views-field views-field-title"> <span class="field-content"><a href="/find-a-doctor/ronald-blaine-easley-md">Ronald Blaine Easley, MD</a></span> </div>
# <div> <div></div> </div> </div>
# <div class="views-column views-column-2">
# <div class="views-field views-field-field-photo"> <div class="field-content"><a href="/find-a-doctor/amy-fang-md"><img alt="" height="165" src="https://www.texaschildrens.org/sites/default/files/styles/search_thumbnail/public/Amy.jpg?itok=bhNl0bBM" typeof="foaf:Image" width="165"/></a></div> </div>
# <div class="views-field views-field-title"> <span class="field-content"><a href="/find-a-doctor/amy-fang-md">Amy Fang, MD</a></span> </div>
# <div> <div></div> </div> </div>
# <div class="views-column views-column-3">
# <div class="views-field views-field-field-photo"> <div class="field-content"><a href="/find-a-doctor/mary-toni-felberg-md"><img alt="" height="165" src="https://www.texaschildrens.org/sites/default/files/styles/search_thumbnail/public/Felberg.Toni_.671715.pedi_anest_58D8.jpg?itok=v3C0wwwi" typeof="foaf:Image" width="165"/></a></div> </div>
# <div class="views-field views-field-title"> <span class="field-content"><a href="/find-a-doctor/mary-toni-felberg-md">Mary (Toni) A. Felberg, MD</a></span> </div>
# <div> <div></div> </div> </div>
# <div class="views-column views-column-4 views-column-last">
# <div class="views-field views-field-field-photo"> <div class="field-content"><a href="/find-a-doctor/thomas-p-fogarty-iii-md-faap"><img alt="" height="165" src="https://www.texaschildrens.org/sites/default/files/styles/search_thumbnail/public/default_images/05756-000001.jpg?itok=7Q3BxZTM" typeof="foaf:Image" width="165"/></a></div> </div>
# <div class="views-field views-field-title"> <span class="field-content"><a href="/find-a-doctor/thomas-p-fogarty-iii-md-faap">Thomas P. Fogarty III, MD, FAAP</a></span> </div>
# <div> <div></div> </div> </div>
# </div>
# <div class="views-row views-row-4">
# <div class="views-column views-column-1 views-column-first">
# <div class="views-field views-field-field-photo"> <div class="field-content"><a href="/find-a-doctor/clint-fuller-md"><img alt="" height="165" src="https://www.texaschildrens.org/sites/default/files/styles/search_thumbnail/public/ClintFuller.jpg?itok=6yjUkGid" typeof="foaf:Image" width="165"/></a></div> </div>
# <div class="views-field views-field-title"> <span class="field-content"><a href="/find-a-doctor/clint-fuller-md">Clint Fuller, MD</a></span> </div>
# <div> <div></div> </div> </div>
# <div class="views-column views-column-2">
# <div class="views-field views-field-field-photo"> <div class="field-content"><a href="/find-a-doctor/priscilla-j-garcia-md"><img alt="" height="165" src="https://www.texaschildrens.org/sites/default/files/styles/search_thumbnail/public/Garcia%2C%20Priscilla%20Jeanine.38228.PediAnest.jpg?itok=fR7rc9hq" typeof="foaf:Image" width="165"/></a></div> </div>
# <div class="views-field views-field-title"> <span class="field-content"><a href="/find-a-doctor/priscilla-j-garcia-md">Priscilla J. Garcia, MD</a></span> </div>
# <div> <div></div> </div> </div>
# <div class="views-column views-column-3">
# <div class="views-field views-field-field-photo"> <div class="field-content"><a href="/find-a-doctor/maria-carolina-gazzaneo-md"><img alt="" height="165" src="https://www.texaschildrens.org/sites/default/files/styles/search_thumbnail/public/Gazzaneo%202-17-2016.jpg?itok=z6F-xV3v" typeof="foaf:Image" width="165"/></a></div> </div>
# <div class="views-field views-field-title"> <span class="field-content"><a href="/find-a-doctor/maria-carolina-gazzaneo-md">Maria Carolina Gazzaneo, MD</a></span> </div>
# <div> <div></div> </div> </div>
# <div class="views-column views-column-4 views-column-last">
# <div class="views-field views-field-field-photo"> <div class="field-content"><a href="/find-a-doctor/chris-d-glover-md"><img alt="" height="165" src="https://www.texaschildrens.org/sites/default/files/styles/search_thumbnail/public/chris_glover.jpeg?itok=cCuQylwO" typeof="foaf:Image" width="165"/></a></div> </div>
# <div class="views-field views-field-title"> <span class="field-content"><a href="/find-a-doctor/chris-d-glover-md">Chris D. Glover, MD, MBA</a></span> </div>
# <div> <div></div> </div> </div>
# </div>
# <div class="views-row views-row-5 views-row-last">
# <div class="views-column views-column-1 views-column-first">
# <div class="views-field views-field-field-photo"> <div class="field-content"><a href="/find-a-doctor/jordana-r-goldman-md"><img alt="" height="165" src="https://www.texaschildrens.org/sites/default/files/styles/search_thumbnail/public/2k14-0086-AK1_7836%20Jordana%20Goldman.jpg?itok=303D3WB9" typeof="foaf:Image" width="165"/></a></div> </div>
# <div class="views-field views-field-title"> <span class="field-content"><a href="/find-a-doctor/jordana-r-goldman-md">Jordana R. Goldman, MD</a></span> </div>
# <div> <div></div> </div> </div>
# <div class="views-column views-column-2">
# <div class="views-field views-field-field-photo"> <div class="field-content"><a href="/find-a-doctor/cheryl-ann-gore-md-mba-m-ed"><img alt="" height="165" src="https://www.texaschildrens.org/sites/default/files/styles/search_thumbnail/public/Gore%2CCheryl.TCH%20Anest.jpg?itok=ab_mHx_p" typeof="foaf:Image" width="165"/></a></div> </div>
# <div class="views-field views-field-title"> <span class="field-content"><a href="/find-a-doctor/cheryl-ann-gore-md-mba-m-ed">Cheryl Ann Gore, MD, MBA, M Ed</a></span> </div>
# <div> <div></div> </div> </div>
# <div class="views-column views-column-3">
# <div class="views-field views-field-field-photo"> <div class="field-content"><a href="/find-a-doctor/michael-gorena-md"><img alt="" height="165" src="https://www.texaschildrens.org/sites/default/files/styles/search_thumbnail/public/Gorena%2C%20Michael%20Alan.120133.PediAnest.jpg?itok=nBVJcFDg" typeof="foaf:Image" width="165"/></a></div> </div>
# <div class="views-field views-field-title"> <span class="field-content"><a href="/find-a-doctor/michael-gorena-md">Michael Gorena, MD</a></span> </div>
# <div> <div></div> </div> </div>
# <div class="views-column views-column-4 views-column-last">
# <div class="views-field views-field-field-photo"> <div class="field-content"><a href="/find-a-doctor/kalyani-govindan-md"><img alt="" height="165" src="https://www.texaschildrens.org/sites/default/files/styles/search_thumbnail/public/Govindan%2C%20Kalyani.154505.pedi_anest_C4F6.jpg?itok=12YqAUGV" typeof="foaf:Image" width="165"/></a></div> </div>
# <div class="views-field views-field-title"> <span class="field-content"><a href="/find-a-doctor/kalyani-govindan-md">Kalyani Govindan, MD</a></span> </div>
# <div> <div></div> </div> </div>
# </div>
# </div>
# </div>

# %%
# get the doc-specific web string
[ce.a.attrs['href'] for ce in content_entries[0].find_all(class_="views-field-field-photo")]
# Out:
# ['/find-a-doctor/kathleen-chen-md-ms',
#  '/find-a-doctor/julia-han-chen-md',
#  '/find-a-doctor/monica-chen-md',
#  '/find-a-doctor/kevin-chu-md',
#  '/find-a-doctor/nana-e-coleman-md',
#  '/find-a-doctor/camille-m-colomb-md',
#  '/find-a-doctor/michelle-r-dalton-md',
#  '/find-a-doctor/moreshwar-s-desai-md',
#  '/find-a-doctor/ronald-blaine-easley-md',
#  '/find-a-doctor/amy-fang-md',
#  '/find-a-doctor/mary-toni-felberg-md',
#  '/find-a-doctor/thomas-p-fogarty-iii-md-faap',
#  '/find-a-doctor/clint-fuller-md',
#  '/find-a-doctor/priscilla-j-garcia-md',
#  '/find-a-doctor/maria-carolina-gazzaneo-md',
#  '/find-a-doctor/chris-d-glover-md',
#  '/find-a-doctor/jordana-r-goldman-md',
#  '/find-a-doctor/cheryl-ann-gore-md-mba-m-ed',
#  '/find-a-doctor/michael-gorena-md',
#  '/find-a-doctor/kalyani-govindan-md']

# %%
len(content_entries[0].find_all(class_="views-field-field-photo"))
# Out:
# 20

# %%
content_entries[0].find_all(class_="views-field-field-photo")[0].a.attrs['href']
# Out:
# '/find-a-doctor/kathleen-chen-md-ms'

# %%
#get doc name
#views-field-title
[ce.get_text().rstrip().lstrip() for ce in content_entries[0].find_all(class_="views-field-title")]
# Out:
# ['Kathleen Chen, MD, MS',
#  'Julia Han Chen, MD',
#  'Monica Chen, MD',
#  'Kevin Chu, MD',
#  'Nana E. Coleman, MD',
#  'Camille M. Colomb, MD',
#  'Michelle R. Dalton, MD',
#  'Moreshwar S. Desai, MD',
#  'Ronald Blaine Easley, MD',
#  'Amy Fang, MD',
#  'Mary (Toni) A. Felberg, MD',
#  'Thomas P. Fogarty III, MD, FAAP',
#  'Clint Fuller, MD',
#  'Priscilla J. Garcia, MD',
#  'Maria Carolina Gazzaneo, MD',
#  'Chris D. Glover, MD, MBA',
#  'Jordana R. Goldman, MD',
#  'Cheryl Ann Gore, MD, MBA, M Ed',
#  'Michael Gorena, MD',
#  'Kalyani Govindan, MD']

# %%
content_entries[0].find_all(class_="views-field-title")[0].get_text().rstrip().lstrip()
# Out:
# 'Kathleen Chen, MD, MS'

# %%
#import spec id table that I made; to pass the roster scrape function
SpecTable = pd.read_excel("SpecTable.xlsx")
SpecTable.head()
# Out:
#             Specialty  SpecCode  Pages
# 0      Anesthesiology      1451      6
# 1  Emergency Medicine      1506      3
# 2         Neonatology      1496      4
# 3   Nuclear Radiology      1641      1
# 4           Pathology      1491      3

# %%
test_df = SpecTable.loc[SpecTable['Specialty']=='Nuclear Radiology']
test_df.head()
# Out:
#            Specialty  SpecCode  Pages
# 3  Nuclear Radiology      1641      2

# %% [markdown]
# ### Scrape Roster

# %%
#### DEFINE PROVIDER SITE SCRAPE FUNCTION
# https://www.texaschildrens.org/doctorslist?title=&field_specialty_tid=1451&page=1

def ProviderSiteList(dataframe, delay):
    RosterList = []
    seconds = delay #define seconds to wait between get requests
    for index, row in dataframe.iterrows():
        specialty = row['Specialty']
        #print(specialty) #for testing
        specId = row['SpecCode']
        PageNumber = row['Pages']
        for n in range(PageNumber+1):
            page = str(n)
            #print(page) #for testing
            url = "https://www.texaschildrens.org/doctorslist?title=&field_specialty_tid=" + str(specId) + "&page=" + page #concat url
            print(url)
            try:
                #url = "https://www.texaschildrens.org/doctorslist?title=&field_specialty_tid=" + specId + "&page=" + page #concat url
                #print(url)
                rosterpage = requests.get(url,time.sleep(seconds)) #get html from url, with delay to prevent website blacklisting
                #print(rosterpage.status_code) #report status of request
                soup = BeautifulSoup(rosterpage.content, 'html.parser') # make soup!
                content_entries = soup.find_all(class_='view-content')
                #print(content_entries[0]) #for testing
                page_roster_length = len(content_entries[0].find_all(class_="views-field-field-photo"))
                #print(page_roster_length) #for testing
                print("Content Entries scraped")
                for i in range(page_roster_length):
                    site = content_entries[0].find_all(class_="views-field-field-photo")[i].a.attrs['href']
                    name = content_entries[0].find_all(class_="views-field-title")[i].get_text().rstrip().lstrip()
                    dict1 = {'Name': name, 'Specialty': specialty, 'site': site}
                    RosterList.append(dict1)
                    print("Added info for Page: "+page+" & Specialty: "+specialty+" & Provider: "+name)
            except:
                pass
                print("Roster ERROR for Page: "+page+" & Specialty: "+specialty+" & Provider: "+name)
    return(RosterList)

# %%
ChildrensSites = ProviderSiteList(SpecTable, 10)
# Out:
# https://www.texaschildrens.org/doctorslist?title=&field_specialty_tid=1451&page=0
# Content Entries scraped
# Added info for Page: 0 & Specialty: Anesthesiology & Provider: Adam C. Adler, MS, MD, FAAP
# Added info for Page: 0 & Specialty: Anesthesiology & Provider: Dheeraj Ahuja, MD
# Added info for Page: 0 & Specialty: Anesthesiology & Provider: Titilopemi A.O. Aina, MD, MPH
# Added info for Page: 0 & Specialty: Anesthesiology & Provider: Ayse Akcan-Arikan, MD
# Added info for Page: 0 & Specialty: Anesthesiology & Provider: Melanie Jeanne Alo, MD
# Added info for Page: 0 & Specialty: Anesthesiology & Provider: Marc Michael Anders, MD
# Added info for Page: 0 & Specialty: Anesthesiology & Provider: Dean B. Andropoulos, MD, MHCM
# Added info for Page: 0 & Specialty: Anesthesiology & Provider: Amy Sharon Arrington, MD, PhD
# Added info for Page: 0 & Specialty: Anesthesiology & Provider: Rahul Geetendra Baijal, MD
# Added info for Page: 0 & Specialty: Anesthesiology & Provider: Dalia A. Bashir, MD
# Added info for Page: 0 & Specialty: Anesthesiology & Provider: Aarti Bavare, MD
# Added info for Page: 0 & Specialty: Anesthesiology & Provider: Saleh Bhar, MD
# Added info for Page: 0 & Specialty: Anesthesiology & Provider: Tamer Elattary, MD
# Added info for Page: 0 & Specialty: Anesthesiology & Provider: Ronald A. Bronicki, MD
# Added info for Page: 0 & Specialty: Anesthesiology & Provider: Katrin Ann Campbell, MD
# Added info for Page: 0 & Specialty: Anesthesiology & Provider: Carlos Javier Campos-Lopez, MD
# Added info for Page: 0 & Specialty: Anesthesiology & Provider: Lisa A. Caplan, MD
# Added info for Page: 0 & Specialty: Anesthesiology & Provider: Nicholas Patrick Carling, MD
# Added info for Page: 0 & Specialty: Anesthesiology & Provider: Danny Castro, DO
# Added info for Page: 0 & Specialty: Anesthesiology & Provider: Paul A. Checchia, MD
# https://www.texaschildrens.org/doctorslist?title=&field_specialty_tid=1451&page=1
# Content Entries scraped
# Added info for Page: 1 & Specialty: Anesthesiology & Provider: Monica Chen, MD
# Added info for Page: 1 & Specialty: Anesthesiology & Provider: Julia Han Chen, MD
# Added info for Page: 1 & Specialty: Anesthesiology & Provider: Kathleen Chen, MD, MS
# Added info for Page: 1 & Specialty: Anesthesiology & Provider: Kevin Chu, MD
# Added info for Page: 1 & Specialty: Anesthesiology & Provider: Nana E. Coleman, MD
# Added info for Page: 1 & Specialty: Anesthesiology & Provider: Camille M. Colomb, MD
# Added info for Page: 1 & Specialty: Anesthesiology & Provider: Michelle R. Dalton, MD
# Added info for Page: 1 & Specialty: Anesthesiology & Provider: Moreshwar S. Desai, MD
# Added info for Page: 1 & Specialty: Anesthesiology & Provider: Ronald Blaine Easley, MD
# Added info for Page: 1 & Specialty: Anesthesiology & Provider: Amy Fang, MD
# Added info for Page: 1 & Specialty: Anesthesiology & Provider: Mary (Toni) A. Felberg, MD
# Added info for Page: 1 & Specialty: Anesthesiology & Provider: Thomas P. Fogarty III, MD, FAAP
# Added info for Page: 1 & Specialty: Anesthesiology & Provider: Clint Fuller, MD
# Added info for Page: 1 & Specialty: Anesthesiology & Provider: Priscilla J. Garcia, MD
# Added info for Page: 1 & Specialty: Anesthesiology & Provider: Maria Carolina Gazzaneo, MD
# Added info for Page: 1 & Specialty: Anesthesiology & Provider: Chris D. Glover, MD, MBA
# Added info for Page: 1 & Specialty: Anesthesiology & Provider: Jordana R. Goldman, MD
# Added info for Page: 1 & Specialty: Anesthesiology & Provider: Cheryl Ann Gore, MD, MBA, M Ed
# Added info for Page: 1 & Specialty: Anesthesiology & Provider: Michael Gorena, MD
# Added info for Page: 1 & Specialty: Anesthesiology & Provider: Kalyani Govindan, MD
# https://www.texaschildrens.org/doctorslist?title=&field_specialty_tid=1451&page=2
# Content Entries scraped
# Added info for Page: 2 & Specialty: Anesthesiology & Provider: Mackenzi Green, MD
# Added info for Page: 2 & Specialty: Anesthesiology & Provider: Stuart R. Hall, MD
# Added info for Page: 2 & Specialty: Anesthesiology & Provider: Melanie Handley, MD
# Added info for Page: 2 & Specialty: Anesthesiology & Provider: Ali Hassanpour, MD
# Added info for Page: 2 & Specialty: Anesthesiology & Provider: Lisa D. Heyden, MD
# Added info for Page: 2 & Specialty: Anesthesiology & Provider: Paul W. Hopkins, MD
# Added info for Page: 2 & Specialty: Anesthesiology & Provider: Grace Huang, MD
# Added info for Page: 2 & Specialty: Anesthesiology & Provider: Lauren Jacobs, MD
# Added info for Page: 2 & Specialty: Anesthesiology & Provider: Matthew D. James, MD
# Added info for Page: 2 & Specialty: Anesthesiology & Provider: Aimee G. Kakascik, DO
# Added info for Page: 2 & Specialty: Anesthesiology & Provider: Megha Karkera Kanjia, MD
# Added info for Page: 2 & Specialty: Anesthesiology & Provider: Mona Karimullah, MD
# Added info for Page: 2 & Specialty: Anesthesiology & Provider: Helena I. Karlberg, MD
# Added info for Page: 2 & Specialty: Anesthesiology & Provider: Souhail Karram, MD
# Added info for Page: 2 & Specialty: Anesthesiology & Provider: Curtis E. Kennedy, MD
# Added info for Page: 2 & Specialty: Anesthesiology & Provider: Nagendra S. Kodali, M.D.
# Added info for Page: 2 & Specialty: Anesthesiology & Provider: Yi-Chen Lai, MD
# Added info for Page: 2 & Specialty: Anesthesiology & Provider: Benjamin H. Lee, MD, MPH
# Added info for Page: 2 & Specialty: Anesthesiology & Provider: Joyce Liu, DO, MS, MBA
# Added info for Page: 2 & Specialty: Anesthesiology & Provider: Yang Liu, MD
# https://www.texaschildrens.org/doctorslist?title=&field_specialty_tid=1451&page=3
# Content Entries scraped
# Added info for Page: 3 & Specialty: Anesthesiology & Provider: Lauren M.Y. Lobaugh, MD
# Added info for Page: 3 & Specialty: Anesthesiology & Provider: Michelle Ann Lopez, MD
# Added info for Page: 3 & Specialty: Anesthesiology & Provider: Jamel E. Lowery, MD
# Added info for Page: 3 & Specialty: Anesthesiology & Provider: David G. Mann, MD, DBe
# Added info for Page: 3 & Specialty: Anesthesiology & Provider: Julie Ann McWhorter, MD
# Added info for Page: 3 & Specialty: Anesthesiology & Provider: Wanda C. Miller-Hance, MD
# Added info for Page: 3 & Specialty: Anesthesiology & Provider: Shazia Mohammad, MD
# Added info for Page: 3 & Specialty: Anesthesiology & Provider: Emad B. Mossad, MD
# Added info for Page: 3 & Specialty: Anesthesiology & Provider: Pablo Motta, MD
# Added info for Page: 3 & Specialty: Anesthesiology & Provider: Sarah M. Smith, MD
# Added info for Page: 3 & Specialty: Anesthesiology & Provider: Matthew Allen Musick, MD
# Added info for Page: 3 & Specialty: Anesthesiology & Provider: Ann Ng, MD
# Added info for Page: 3 & Specialty: Anesthesiology & Provider: Kim-Phuong Thi Nguyen, MD
# Added info for Page: 3 & Specialty: Anesthesiology & Provider: Barbara Nzegwu, MD
# Added info for Page: 3 & Specialty: Anesthesiology & Provider: Olutoyin A. Olutoye, MD
# Added info for Page: 3 & Specialty: Anesthesiology & Provider: Elyse C. Parchmont, CRNA
# Added info for Page: 3 & Specialty: Anesthesiology & Provider: Nihar V. Patel, MD
# Added info for Page: 3 & Specialty: Anesthesiology & Provider: Matthew Keith Pesek, MD
# Added info for Page: 3 & Specialty: Anesthesiology & Provider: Robert W. Power, MD
# Added info for Page: 3 & Specialty: Anesthesiology & Provider: Miguel A. Prada, MD
# https://www.texaschildrens.org/doctorslist?title=&field_specialty_tid=1451&page=4
# Content Entries scraped
# Added info for Page: 4 & Specialty: Anesthesiology & Provider: Krista Preisberga, MD
# Added info for Page: 4 & Specialty: Anesthesiology & Provider:
MD
# Added info for Page: 0 & Specialty: Pediatric Radiology & Provider: Anna Illner, MD
# Added info for Page: 0 & Specialty: Pediatric Radiology & Provider: Siddharth P. Jadhav, MD
# Added info for Page: 0 & Specialty: Pediatric Radiology & Provider: J. Herman Kan, MD
# Added info for Page: 0 & Specialty: Pediatric Radiology & Provider: Pamela Deaver Ketwaroo, MD
# https://www.texaschildrens.org/doctorslist?title=&field_specialty_tid=1521&page=1
# Content Entries scraped
# Added info for Page: 1 & Specialty: Pediatric Radiology & Provider: Stephen F. Kralik, MD
# Added info for Page: 1 & Specialty: Pediatric Radiology & Provider: Kamlesh U. Kukreja, MD
# Added info for Page: 1 & Specialty: Pediatric Radiology & Provider: Marcia K. Kukreja, MD
# Added info for Page: 1 & Specialty: Pediatric Radiology & Provider: Nadia F. Mahmood, MD
# Added info for Page: 1 & Specialty: Pediatric Radiology & Provider: Maricarmen Nazario Malavé,  MD
# Added info for Page: 1 & Specialty: Pediatric Radiology & Provider: Prakash M. Masand, MD
# Added info for Page: 1 & Specialty: Pediatric Radiology & Provider: Amy Mehollin-Ray, MD
# Added info for Page: 1 & Specialty: Pediatric Radiology & Provider: Avner Meoded, MD
# Added info for Page: 1 & Specialty: Pediatric Radiology & Provider: Amir Pezeshkmehr, MD
# Added info for Page: 1 & Specialty: Pediatric Radiology & Provider: Ronald A. Rauch, MD
# Added info for Page: 1 & Specialty: Pediatric Radiology & Provider: Alicia M. Roman-Colon, MD
# Added info for Page: 1 & Specialty: Pediatric Radiology & Provider: Marla B.K. Sammer, MD
# Added info for Page: 1 & Specialty: Pediatric Radiology & Provider: Erica K. Schallert, MD
# Added info for Page: 1 & Specialty: Pediatric Radiology & Provider: Alan E. Schlesinger, MD
# Added info for Page: 1 & Specialty: Pediatric Radiology & Provider: Victor J. Seghers, MD, PhD
# Added info for Page: 1 & Specialty: Pediatric Radiology & Provider: Ray Somcio, MD
# Added info for Page: 1 & Specialty: Pediatric Radiology & Provider: Huy D. (Brandon) Tran, MD
# Added info for Page: 1 & Specialty: Pediatric Radiology & Provider: Edward A. Duckworth, MD
# Added info for Page: 1 & Specialty: Pediatric Radiology & Provider: Peter T. Kan, MD
# Added info for Page: 1 & Specialty: Pediatric Radiology & Provider: Hsin H. Lu, MD
# https://www.texaschildrens.org/doctorslist?title=&field_specialty_tid=1521&page=2
# Content Entries scraped
# Added info for Page: 2 & Specialty: Pediatric Radiology & Provider: Arnold Delacruz Paulino, MD
# Added info for Page: 2 & Specialty: Pediatric Radiology & Provider: Todd C. Tenenholz, MD, PhD
# https://www.texaschildrens.org/doctorslist?title=&field_specialty_tid=1521&page=3
# Roster ERROR for Page: 3 & Specialty: Pediatric Radiology & Provider: Todd C. Tenenholz, MD, PhD
# https://www.texaschildrens.org/doctorslist?title=&field_specialty_tid=1651&page=0
# Content Entries scraped
# Added info for Page: 0 & Specialty: OBGYN Anesthesiology & Provider: Kulsum Akbar, MD
# Added info for Page: 0 & Specialty: OBGYN Anesthesiology & Provider: Oludayo Adedotun Adeyefa, MD
# Added info for Page: 0 & Specialty: OBGYN Anesthesiology & Provider: Veena Basava, MD
# Added info for Page: 0 & Specialty: OBGYN Anesthesiology & Provider: Tameka Michelle Broussard, MD
# Added info for Page: 0 & Specialty: OBGYN Anesthesiology & Provider: George H. Denfield, MD
# Added info for Page: 0 & Specialty: OBGYN Anesthesiology & Provider: Laurie N. Dykoski, MD
# Added info for Page: 0 & Specialty: OBGYN Anesthesiology & Provider: Lewis I. Gottschalk, MD
# Added info for Page: 0 & Specialty: OBGYN Anesthesiology & Provider: Jonas Scott Hafkin, MD
# Added info for Page: 0 & Specialty: OBGYN Anesthesiology & Provider: Andrew Steven Itkin, MD
# Added info for Page: 0 & Specialty: OBGYN Anesthesiology & Provider: Michelle D. Jordan, MD
# Added info for Page: 0 & Specialty: OBGYN Anesthesiology & Provider: Kelly R. Katcher, MD
# Added info for Page: 0 & Specialty: OBGYN Anesthesiology & Provider: Tony Guest Kim, MD
# Added info for Page: 0 & Specialty: OBGYN Anesthesiology & Provider: Yasmin Natasha Lake, MD
# Added info for Page: 0 & Specialty: OBGYN Anesthesiology & Provider: Neville S. Leibman, MD
# Added info for Page: 0 & Specialty: OBGYN Anesthesiology & Provider: Susan Lynn Luehr, MD
# Added info for Page: 0 & Specialty: OBGYN Anesthesiology & Provider: Mark Alan McMasters, MD
# Added info for Page: 0 & Specialty: OBGYN Anesthesiology & Provider: Rakesh Narayan, MD
# Added info for Page: 0 & Specialty: OBGYN Anesthesiology & Provider: Cenk Ozdogan, MD
# Added info for Page: 0 & Specialty: OBGYN Anesthesiology & Provider: George W. Parker, MD
# Added info for Page: 0 & Specialty: OBGYN Anesthesiology & Provider: Chad A. Pedley, MD
# https://www.texaschildrens.org/doctorslist?title=&field_specialty_tid=1651&page=1
# Content Entries scraped
# Added info for Page: 1 & Specialty: OBGYN Anesthesiology & Provider: Suzanne G. Peltier, MD
# Added info for Page: 1 & Specialty: OBGYN Anesthesiology & Provider: Frederick A. Rhodes, MD
# Added info for Page: 1 & Specialty: OBGYN Anesthesiology & Provider: Eric P. Ritter, MD
# Added info for Page: 1 & Specialty: OBGYN Anesthesiology & Provider: Derek M. Schoppa, MD
# Added info for Page: 1 & Specialty: OBGYN Anesthesiology & Provider: Brandon S. Thompson, MD
# Added info for Page: 1 & Specialty: OBGYN Anesthesiology & Provider: Jo Hsu Tu, DO
# Added info for Page: 1 & Specialty: OBGYN Anesthesiology & Provider: Rolfe M. Williams, MD
# Added info for Page: 1 & Specialty: OBGYN Anesthesiology & Provider: Odile Francoise Yacoub, MD
# https://www.texaschildrens.org/doctorslist?title=&field_specialty_tid=1651&page=2
# Roster ERROR for Page: 2 & Specialty: OBGYN Anesthesiology & Provider: Odile Francoise Yacoub, MD

# %%
Site_df = pd.DataFrame(ChildrensSites)
Site_df.head()
# Out:
#                             Name       Specialty  \
# 0    Adam C. Adler, MS, MD, FAAP  Anesthesiology
# 1              Dheeraj Ahuja, MD  Anesthesiology
# 2  Titilopemi A.O. Aina, MD, MPH  Anesthesiology
# 3          Ayse Akcan-Arikan, MD  Anesthesiology
# 4         Melanie Jeanne Alo, MD  Anesthesiology
#
#                                      site
# 0  /find-a-doctor/adam-c-adler-ms-md-faap
# 1         /find-a-doctor/dheeraj-ahuja-md
# 2    /find-a-doctor/titilopemi-ao-aina-md
# 3     /find-a-doctor/ayse-akcan-arikan-md
# 4    /find-a-doctor/melanie-jeanne-alo-md

# %%
Site_df.shape
# Out:
# (352, 3)

# %% [markdown]
# ### Scrape locations from provider site
#
# Now that I have a list of individual provider sites from the roster, I'll use that as input to scrape affiliations from each doc's profile page

# %% [markdown]
# #### Test profile page beautiful soup components

# %%
#url = 'https://www.texaschildrens.org'+site

url = 'https://www.texaschildrens.org/find-a-doctor/adam-c-adler-ms-md-faap'
affilpage = requests.get(url) #get html from url, with delay to prevent website blacklisting
soup = BeautifulSoup(affilpage.content, 'html.parser') # make soup!
content_entries = soup.find_all(class_='adr')

#views-field-field-campus

# %%
content_entries
# Out:
# [<div class="adr">
#  <div class="street-address">
#  <span itemprop="streetAddress">6621 Fannin Street</span>
#  <div class="additional" itemprop="streetAddress">
#              Suite A3300          </div>
#  </div>
#  <span class="locality" itemprop="addressLocality">Houston,</span>
#  <span class="region" itemprop="addressRegion">TX</span>
#  <span class="postal-code" itemprop="postalCode">77030</span>
#  <div class="country-name" itemprop="addressCountry">United States</div>
#  </div>]

# %%
locations = [ce.get_text().lstrip().rstrip().replace('Location ', '') for ce in soup.find_all(class_="views-field-field-campus")]
locations
# Out:
# ['Texas Medical Center']

# %%
#street-address
[ce.get_text().rstrip().lstrip().replace('\n\n            ', '--') for ce in content_entries[0].find_all(class_="street-address")]
#[ce.get_text().lstrip().rstrip() for ce in soup.find_all(class_="street-address")]
# Out:
# ['6621 Fannin Street--Suite A3300']

# %%
#City
[ce.get_text().replace(',', '') for ce in content_entries[0].find_all(class_="locality")]
#[ce.get_text().lstrip().rstrip() for ce in soup.find_all(class_="locality")]
# Out:
# ['Houston']

# %%
#state
[ce.get_text().rstrip().lstrip() for ce in content_entries[0].find_all(class_="region")]
#[ce.get_text().lstrip().rstrip() for ce in soup.find_all(class_="region")]
# Out:
# ['TX']

# %%
#postal-code
[ce.get_text().rstrip().lstrip() for ce in content_entries[0].find_all(class_="postal-code")]
#[ce.get_text().lstrip().rstrip() for ce in soup.find_all(class_="postal-code")]
# Out:
# ['77030']

# %%
# Phone
[ce.get_text().rstrip().lstrip().replace('Phone: ', '') for ce in soup.find_all(class_="views-field-field-phone")]
# Out:
# ['832-824-5800']

# %% [markdown]
# ### Get Affiliations from each doc's bio page

# %%
#number of provider list sites

def ProviderAffilList(dataframe, delay):
    AffilList = []
    seconds = delay #define seconds to wait between get requests
    for index, row in dataframe.iterrows():
        name = row['Name']
        site_string = row['site']
        try:
            url = "https://www.texaschildrens.org" + site_string #concat url
            page = requests.get(url,time.sleep(seconds)) #get html from url, with delay to prevent website blacklisting
            print(page.status_code) #report status of request
            soup = BeautifulSoup(page.content, 'html.parser') # make soup!
            locations = [ce.get_text().lstrip().rstrip().replace('Location ', '') for ce in soup.find_all(class_="views-field-field-campus")]
            content_entries = soup.find_all(class_='adr')
            street_address = [ce.get_text().rstrip().lstrip().replace('\n\n            ', '--') for ce in content_entries[0].find_all(class_="street-address")]
            city = [ce.get_text().replace(',', '') for ce in content_entries[0].find_all(class_="locality")]
            state = [ce.get_text().rstrip().lstrip() for ce in content_entries[0].find_all(class_="region")]
            zip_office = [ce.get_text().rstrip().lstrip() for ce in content_entries[0].find_all(class_="postal-code")]
            phone = [ce.get_text().rstrip().lstrip().replace('Phone: ', '') for ce in soup.find_all(class_="views-field-field-phone")]
            
            for i in range(len(locations)):
                dict1 = {'Name': name, 'Location': locations[i], 'OfficeAddress': str(street_address), 'OfficeCity': str(city), 'OfficeState': state, 'OfficeZip': zip_office, 'OfficePhone': phone}
                AffilList.append(dict1)
                print("Added Affil for Provider: "+name)
        except:
            pass
            print("Provider Affil ERROR for Page: "+name)
    return(AffilList)

# %% [markdown]
# #### Test run

# %%
test_df = Site_df.iloc[0:3, :]
test_df.head()
# Out:
#                             Name       Specialty  \
# 0    Adam C. Adler, MS, MD, FAAP  Anesthesiology
# 1              Dheeraj Ahuja, MD  Anesthesiology
# 2  Titilopemi A.O. Aina, MD, MPH  Anesthesiology
#
#                                      site
# 0  /find-a-doctor/adam-c-adler-ms-md-faap
# 1         /find-a-doctor/dheeraj-ahuja-md
# 2    /find-a-doctor/titilopemi-ao-aina-md

# %%
test_list = ProviderAffilList(test_df, 5)
# Out:
# 200
# Added Affil for Provider: Adam C. Adler, MS, MD, FAAP
# 200
# Added Affil for Provider: Dheeraj Ahuja, MD
# 200
# Added Affil for Provider: Titilopemi A.O. Aina, MD, MPH

# %%
pd.DataFrame(test_list)
# Out:
#                Location                           Name  \
# 0  Texas Medical Center    Adam C. Adler, MS, MD, FAAP
# 1  Texas Medical Center              Dheeraj Ahuja, MD
# 2  Texas Medical Center  Titilopemi A.O. Aina, MD, MPH
#
#                          OfficeAddress   OfficeCity     OfficePhone  \
# 0  ['6621 Fannin Street--Suite A3300']  ['Houston']  [832-824-5800]
# 1  ['6621 Fannin Street--Suite A3300']  ['Houston']  [832-824-5800]
# 2  ['6621 Fannin Street--Suite A3300']  ['Houston']  [832-824-5800]
#
#   OfficeState OfficeZip
# 0        [TX]   [77030]
# 1        [TX]   [77030]
# 2        [TX]   [77030]

# %% [markdown]
# #### Get that data!

# %%
affil_list = ProviderAffilList(Site_df, 10)
# Out:
# 200
# Added Affil for Provider: Adam C. Adler, MS, MD, FAAP
# 200
# Added Affil for Provider: Dheeraj Ahuja, MD
# 200
# Added Affil for Provider: Titilopemi A.O. Aina, MD, MPH
# 200
# Added Affil for Provider: Ayse Akcan-Arikan, MD
# 200
# Added Affil for Provider: Melanie Jeanne Alo, MD
# 200
# Added Affil for Provider: Marc Michael Anders, MD
# 200
# Added Affil for Provider: Dean B. Andropoulos, MD, MHCM
# 200
# Added Affil for Provider: Amy Sharon Arrington, MD, PhD
# 200
# Added Affil for Provider: Rahul Geetendra Baijal, MD
# 200
# Added Affil for Provider: Dalia A. Bashir, MD
# 200
# Added Affil for Provider: Aarti Bavare, MD
# 200
# Added Affil for Provider: Saleh Bhar, MD
# 200
# Added Affil for Provider: Tamer Elattary, MD
# 200
# Added Affil for Provider: Ronald A. Bronicki, MD
# 200
# Added Affil for Provider: Katrin Ann Campbell, MD
# 200
# Added Affil for Provider: Carlos Javier Campos-Lopez, MD
# 200
# Added Affil for Provider: Lisa A. Caplan, MD
# 200
# Added Affil for Provider: Nicholas Patrick Carling, MD
# 200
# Added Affil for Provider: Danny Castro, DO
# 200
# Added Affil for Provider: Paul A. Checchia, MD
# 200
# Added Affil for Provider: Monica Chen, MD
# 200
# Added Affil for Provider: Julia Han Chen, MD
# 200
# Added Affil for Provider: Kathleen Chen, MD, MS
# 200
# Added Affil for Provider: Kevin Chu, MD
# 200
# Added Affil for Provider: Nana E. Coleman, MD
# 200
# Added Affil for Provider: Camille M. Colomb, MD
# 200
# Added Affil for Provider: Michelle R. Dalton, MD
# 200
# Added Affil for Provider: Moreshwar S. Desai, MD
# 200
# Added Affil for Provider: Ronald Blaine Easley, MD
# 200
# Added Affil for Provider: Amy Fang, MD
# 200
# Added Affil for Provider: Mary (Toni) A. Felberg, MD
# 200
# Added Affil for Provider: Thomas P. Fogarty III, MD, FAAP
# 200
# Added Affil for Provider: Clint Fuller, MD
# 200
# Added Affil for Provider: Priscilla J. Garcia, MD
# 200
# Added Affil for Provider: Maria Carolina Gazzaneo, MD
# 200
# Added Affil for Provider: Chris D. Glover, MD, MBA
# 200
# Added Affil for Provider: Jordana R. Goldman, MD
# 200
# Added Affil for Provider: Cheryl Ann Gore, MD, MBA, M Ed
# 200
# Added Affil for Provider: Michael Gorena, MD
# 200
# Added Affil for Provider: Kalyani Govindan, MD
# 200
# Added Affil for Provider: Mackenzi Green, MD
# 200
# Added Affil for Provider: Stuart R. Hall, MD
# 200
# Added Affil for Provider: Melanie Handley, MD
# 200
# Added Affil for Provider: Ali Hassanpour, MD
# 200
# Added Affil for Provider: Lisa D. Heyden, MD
# 200
# Added Affil for Provider: Paul W. Hopkins, MD
# 200
# Added Affil for Provider: Grace Huang, MD
# 200
# Added Affil for Provider: Lauren Jacobs, MD
# 200
# Added Affil for Provider: Matthew D. James, MD
# 200
# Added Affil for Provider: Aimee G. Kakascik, DO
# 200
# Added Affil for Provider: Megha Karkera Kanjia, MD
# 200
# 200
# Added Affil for Provider: Helena I. Karlberg, MD
# 200
# Added Affil for Provider: Souhail Karram, MD
# 200
# Added Affil for Provider: Curtis E. Kennedy, MD
# 200
# Added Affil for Provider: Nagendra S. Kodali, M.D.
# 200
# Added Affil for Provider: Yi-Chen Lai, MD
# 200
# Added Affil for Provider: Benjamin H. Lee, MD, MPH
# 200
# Added Affil for Provider: Joyce Liu, DO, MS, MBA
# 200
# Added Affil for Provider: Yang Liu, MD
# 200
# Added Affil for Provider: Lauren M.Y. Lobaugh, MD
# 200
# Added Affil for Provider: Michelle Ann Lopez, MD
# 200
# Added Affil for Provider: Jamel E. Lowery, MD
# 200
# Added Affil for Provider: David G. Mann, MD, DBe
# 200
# Provider Affil ERROR for Page: Julie Ann McWhorter, MD
# 200
# Added Affil for Provider: Wanda C. Miller-Hance, MD
# 200
# Added Affil for Provider: Shazia Mohammad, MD
# 200
# Added Affil for Provider: Emad B. Mossad, MD
# 200
# Added Affil for Provider: Pablo Motta, MD
# 200
# Added Affil for Provider: Sarah M. Smith, MD
# 200
# Added Affil for Provider: Matthew Allen Musick, MD
# 200
# Added Affil for Provider: Ann Ng, MD
# 200
# Added Affil for Provider: Kim-Phuong Thi Nguyen, MD
# 200
# Added Affil for Provider: Barbara Nzegwu, MD
# 200
# Added Affil for Provider: Olutoyin A. Olutoye, MD
# 200
# Added Affil for Provider: Elyse C. Parchmont, CRNA
# 200
# Added Affil for Provider: Nihar V. Patel, MD
# 200
# 200
# Added Affil for Provider: Robert W. Power, MD
# 200
# Added Affil for Provider: Miguel A. Prada, MD
# 200
# Added Affil for Provider: Krista Preisberga, MD
# 200
# Added Affil for Provider: Carlos L. Rodriguez, MD
# 200
# Added Affil for Provider: Amber Presson Rogers, MD
# 200
# Added Affil for Provider: Elizabeth Rossmann Beel, MD, MPH
# 200
# Added Affil for Provider: Jaime Leigh Jump, DO
# 200
# Added Affil for Provider: Laura W. Ryan, MD
# 200
# Added Affil for Provider: Julie Schackman, MD
# 200
# Added Affil for Provider: Brent Schakett, MD
# 200
# Added Affil for Provider: Catherine Peishin Seipel, MD
# 200
# Added Affil for Provider: Thomas LaShun Shaw, MD
# 200
# Added Affil for Provider: Lara S. Shekerdemian, MD
# 200
# Added Affil for Provider: Jamie W. Sinton, MD
# 200
# Added Affil for Provider: Stephen A. Stayer, MD
# 200
# 200
# Added Affil for Provider: Caitlin Sutton, MD
# 200
# Added Affil for Provider: Mohammad Hossein Tcharmtchi, MD
# 200
# Added Affil for Provider: James A. Thomas, MD, FAAP
# 200
# Added Affil for Provider: Brian Tinch, MD
# 200
# Added Affil for Provider: Imelda Michelle Tjia, MD
# 200
# Added Affil for Provider: Laura Torres, MD
# 200
# Added Affil for Provider: Premal M. Trivedi, MD
# 200
# Added Affil for Provider: Sebastian C. Tume, MD
# 200
# Added Affil for Provider: Mario Patino Velez, MD
# 200
# Added Affil for Provider: David Freed Vener, MD
# 200
# Added Affil for Provider: Kenneth L. Wayman, MD
# 200
# Added Affil for Provider: Eric A. Williams, MD
# 200
# Added Affil for Provider: Erin S. Williams, MD
# 200
# Added Affil for Provider: Karla Wyatt, MD, MS
# 200
# Added Affil for Provider: Ammar Yamani, MD
# 200
# Added Affil for Provider: David Allan Young, MD
# 200
# Added Affil for Provider: Michael Blaine Zelisko, MD
# 200
# Added Affil for Provider: Nirica Borges MD, FAAP, CMQ
# 200
# 200
# Added Affil for Provider: Aderonke O. Adekunle-Ojo, MD
# 200
# Added Affil for Provider: Kiyetta Hanan Alade, MD
# 200
# Added Affil for Provider: Joseph Yang Allen, MD
# 200
# Added Affil for Provider: David W. Ashby, DO, MS
# 200
# Added Affil for Provider: Brian Scott Bassham, MD
# 200
# Added Affil for Provider: Alecia Koren Borkovich, MD
# 200
# Added Affil for Provider: Patricia Fuyuki Campbell, MD
# 200
# Added Affil for Provider: John M. Carey, MD
# 200
# Added Affil for Provider: Sheebu V. Chacko, MD
# 200
# Added Affil for Provider: Benjamin Choi, MD
# 200
# Added Affil for Provider: Corrie E. Klopcic Chumpitazi, MD
# 200
# Added Affil for Provider: Ann M. Craig, MD
# 200
# Added Affil for Provider: Heather Crouse, MD
# 200
# Added Affil for Provider: Andrea T. Cruz, MD
# 200
# Provider Affil ERROR for Page: Beth Marie D'Amico, MD
# 200
# Added Affil for Provider: David Michael DeLemos, MD
# 200
# Added Affil for Provider: Cara Boyles Doughty, MD
# 200
# Added Affil for Provider: Elaine K. Fielder, MD
# 200
# Added Affil for Provider: Winston Ho, MD
# 200
# Added Affil for Provider: Deborah Hsu, MD
# 200
# Added Affil for Provider: Shyama Kamat, MD
# 200
# Added Affil for Provider: Brent D. Kaziny, MD
# 200
# Added Affil for Provider: Katherine Jennifer Leaming-Van Zandt, MD
# 200
# Added Affil for Provider: Daniel S. Lemke, MD
# 200
# Added Affil for Provider: Stephanie Ka-Wing Leung, MD
# 200
# Added Affil for Provider: Jonathan D. Lewis, MD
# 200
# Added Affil for Provider: Kim Little-Weinert, MD
# 200
# Added Affil for Provider: Michelle Anderson Lyn, MD
# 200
# Added Affil for Provider: Charles G. Macias, MD, MPH
# 200
# Added Affil for Provider: Nina Imasi McFarlane-Johansson, MD
# 200
# Added Affil for Provider: Julie Kathryn McManemy, MD
# 200
# Provider Affil ERROR for Page: Sarah Dennis Meskill, MD
# 200
# Added Affil for Provider: Binita Patel, MD
# 200
# 200
# Added Affil for Provider: Casandra Quinones, MD
# 200
# Added Affil for Provider: Daniel Rubalcava, MD
# 200
# Added Affil for Provider: Marideth Carmelle Rus, MD
# 200
# Added Affil for Provider: Eric A. Russell, MD
# 200
# Added Affil for Provider: Esther Maria Sampayo, MD, MPH
# 200
# Added Affil for Provider: Manish I. Shah, MD, MS
# 200
# Added Affil for Provider: Huma Shaikh, MD
# 200
# Added Affil for Provider: Rohit P. Shenoi, MD
# 200
# Added Affil for Provider: Joan E. Shook, MD, MBA
# 200
# Added Affil for Provider: Nidhi Singh, MD
# 200
# Added Affil for Provider: Paul Edward Sirbaugh, DO, MBA
# 200
# Added Affil for Provider: Susan B. Torrey, MD
# 200
# Added Affil for Provider: Thomas B. Welch-Horan, MD
# 200
# Added Affil for Provider: Shabana Yusuf, MD
# 200
# 200
# Added Affil for Provider: Athis Rajh Arunachalam, MD
# 200
# Added Affil for Provider: Amit A. Bhatt, MD, FAAP
# 200
# Provider Affil ERROR for Page: Joel W. Bonaparte, MD
# 200
# 200
# Added Affil for Provider: Courtney Ann Carmicheal-Swanner, MD
# 200
# Provider Affil ERROR for Page: Rebeca Elizabeth Cavazos, MD
# 200
# Provider Affil ERROR for Page: Amarnath H Chamkur, MD
# 200
# 200
# Added Affil for Provider: Mufeed Al Islam Ashraf, MD
# 200
# Added Affil for Provider: Jonathan Lyle Davies, MD
# 200
# Added Affil for Provider: Melissa M. Carbajal, MD
# 200
# Added Affil for Provider: Xanthi I. Couroucli, MD
# 200
# 200
# Added Affil for Provider: Milenka Cuevas-Guaman, MD
# 200
# Provider Affil ERROR for Page: Shaeequa P. Dasnadi, MD
# 200
# 200
# Added Affil for Provider: Stephanie Blair Deal, MD
# 200
# Added Affil for Provider: Karen T. deVille, MD
# 200
# Provider Affil ERROR for Page: Daniela Dinu, MD
# 200
# Added Affil for Provider: Adel A. ElHennawy, MD
# 200
# Added Affil for Provider: Caraciolo J. Fernandes, MD, MBA
# 200
# Added Affil for Provider: Larissa Adkins Fletcher, MD
# 200
# Added Affil for Provider: Regine M. Fortunov, MD
# 200
# Provider Affil ERROR for Page: Gregory A. Franklin, MD
# 200
# Added Affil for Provider: Mayra L. Freeman-Ladd, MD
# 200
# Added Affil for Provider: Monika M. Gadhia, MD
# 200
# Added Affil for Provider: Bheru B. Gandhi, MD
# 200
# 200
# Added Affil for Provider: K. Suresh Gautham, MD, DM, MS, FAAP
# 200
# Added Affil for Provider: Steven Gwynn Geddie, MD
# 200
# Added Affil for Provider: Paraskevi Georgiadis, MD
# 200
# 200
# Added Affil for Provider: Sharada Hiranya Gowda, MD
# 200
# 200
# Added Affil for Provider: Amy B. Hair, MD
# 200
# Added Affil for Provider: Karen Elaine Johnson, MD
# 200
# Added Affil for Provider: Stella U. Kalu, MD
# 200
# Added Affil for Provider: Lakshmi Iswarya Katakam, MD, MPH, FAAP
# 200
# Provider Affil ERROR for Page: Mona G. Khattab, MD
# 200
# Added Affil for Provider: Madhulika A. Kulkarni, MD
# 200
# Added Affil for Provider: Tommy Leonard Jr., MD
# 200
# 200
# 200
# Added Affil for Provider: Jenelle E. Little, MD
# 200
# Provider Affil ERROR for Page: Pablo Lohmann, MD
# 200
# Provider Affil ERROR for Page: Torey L Mack, MD
# 200
# Added Affil for Provider: Surbhi Maheshwari, MBBS
# 200
# Added Affil for Provider: George Thomas Mandy, MD
# 200
# 200
# 200
# 200
# 200
# Added Affil for Provider: Chinelo I. Onuekwusi, MD
# 200
# Added Affil for Provider: Mohan Pammi, MD
# 200
# Provider Affil ERROR for Page: Frank Xavier Placencia, MD
# 200
# 200
# Added Affil for Provider: Sangeetha Athis Rajh, MD
# 200
# Provider Affil ERROR for Page: Monica Ramos, MD
# 200
# Provider Affil ERROR for Page: Christopher J. Rhee, MD
# 200
# Provider Affil ERROR for Page: Danielle R. Rios, MD
# 200
# 200
# 200
# Provider Affil ERROR for Page: Michael Emery Speer, MD
# 200
# Provider Affil ERROR for Page: Nathan C. Sundgren, MD, PhD
# 200
# Provider Affil ERROR for Page: Cecilia Torres Day, MD
# 200
# 200
# Provider Affil ERROR for Page: Salim Kamruddin Bharwani, MD
# 200
# 200
# 200
# 200
# Provider Affil ERROR for Page: Ines Ruiz-Puyana, MD
# 200
# 200
# Added Affil for Provider: Matthew G. Ditzler, MD
# 200
# Added Affil for Provider: Andrew C. Sher, MD
# 200
# Added Affil for Provider: Adekunle Michael Adesina, MD, PhD
# 200
# Added Affil for Provider: David M. Berger, MD
# 200
# Added Affil for Provider: Gregory J. Buffone, PhD
# 200
# Added Affil for Provider: Jing Cao, PhD, DABCC, FACB
# 200
# Added Affil for Provider: Eumenia Costa Da Cunha Castro, MD, PhD
# 200
# 200
# Added Affil for Provider: James Dunn, PhD, D(ABMM)
# 200
# 200
# Added Affil for Provider: Tarek Elghetany, MD
# 200
# 200
# Added Affil for Provider: Maren Y. Fuller, MD
# 200
# Added Affil for Provider: Eileen McKay, MD
# 200
# Added Affil for Provider: Niveen Issaq, MD
# 200
# Added Affil for Provider: Lisa Hensch, MD
# 200
# Added Affil for Provider: M. John Hicks, MD, DDS
# 200
# 200
# 200
# Added Affil for Provider: Vadim Kostousov, MD
# 200
# Added Affil for Provider: Dolores H. Lopez-Terrada, MD, PhD
# 200
# Added Affil for Provider: Andrea Nicole Marcogliese, MD
# 200
# Added Affil for Provider: Carrie Ann Mohila, MD, PhD
# 200
# Added Affil for Provider: Yuko Mori-Akiyama, MD
# 200
# Added Affil for Provider: Angshumoy Roy, MD, PhD
# 200
# Added Affil for Provider: Kalyani R. Patel, MD
# 200
# Added Affil for Provider: Ninad Patil, MD
# 200
# Added Affil for Provider: Thuy Linh Phung, MD, PhD
# 200
# Added Affil for Provider: Edwina J. Popek, DO
# 200
# Added Affil for Provider: Jyotinder Nain Punia, MD
# 200
# 200
# Added Affil for Provider: Paula Revell, PhD
# 200
# Added Affil for Provider: Tor Savidge, PhD
# 200
# 200
# Added Affil for Provider: Roy V. Sillitoe, PhD
# 200
# Added Affil for Provider: Ila Singh, MD, PhD
# 200
# Added Affil for Provider: Jennifer K. Spinler, PhD
# 200
# Added Affil for Provider: Jun Teruya, MD, DSc, FCAP
# 200
# Added Affil for Provider: James Versalovic, MD, PhD
# 200
# 200
# Provider Affil ERROR for Page: Andrea Diaz de Vivar, MD
# 200
# 200
# Provider Affil ERROR for Page: Ramya P. Masand, MD
# 200
# 200
# 200
# 200
# Provider Affil ERROR for Page: Thomas M. Wheeler, MD
# 200
# Provider Affil ERROR for Page: Marwan A. Yared, MD
# 200
# Added Affil for Provider: Sherri Beth Birchansky, MD
# 200
# 200
# Added Affil for Provider: Marcos P. Ferreira Botelho, MD
# 200
# Added Affil for Provider: Richard M. Braverman, MD
# 200
# Added Affil for Provider: Christopher Ian Cassady, MD
# 200
# Added Affil for Provider: Alex Chau, MD
# 200
# Added Affil for Provider: James E. Crowe, MD
# 200
# Added Affil for Provider: Nilesh K. Desai, MD
# 200
# Added Affil for Provider: Matthew G. Ditzler, MD
# 200
# Added Affil for Provider: Scott R. Dorfman, MD
# 200
# Added Affil for Provider: Christopher Gaffney, M.D.
# 200
# Provider Affil ERROR for Page: Lee M. Goerner (Nakamura), MD
# 200
# Added Affil for Provider: Robert Paul Guillerman, MD
# 200
# Added Affil for Provider: Jose Alberto Hernandez, MD
# 200
# Added Affil for Provider: Thierry A.G.M. Huisman, MD, PD, EDiNR, EDiPNR, FICIS
# 200
# Added Affil for Provider: Jill V. Hunter, MD
# 200
# Added Affil for Provider: Anna Illner, MD
# 200
# Added Affil for Provider: Siddharth P. Jadhav, MD
# 200
# Added Affil for Provider: J. Herman Kan, MD
# 200
# Added Affil for Provider: Pamela Deaver Ketwaroo, MD
# 200
# Added Affil for Provider: Stephen F. Kralik, MD
# 200
# Added Affil for Provider: Kamlesh U. Kukreja, MD
# 200
# Added Affil for Provider: Marcia K. Kukreja, MD
# 200
# Added Affil for Provider: Nadia F. Mahmood, MD
# 200
# Added Affil for Provider: Maricarmen Nazario Malavé,  MD
# 200
# Added Affil for Provider: Prakash M. Masand, MD
# 200
# Added Affil for Provider: Amy Mehollin-Ray, MD
# 200
# Added Affil for Provider: Avner Meoded, MD
# 200
# Added Affil for Provider: Amir Pezeshkmehr, MD
# 200
# Added Affil for Provider: Ronald A. Rauch, MD
# 200
# Added Affil for Provider: Alicia M. Roman-Colon, MD
# 200
# Added Affil for Provider: Marla B.K. Sammer, MD
# 200
# Added Affil for Provider: Erica K. Schallert, MD
# 200
# Added Affil for Provider: Alan E. Schlesinger, MD
# 200
# Added Affil for Provider: Victor J. Seghers, MD, PhD
# 200
# Added Affil for Provider: Ray Somcio, MD
# 200
# Added Affil for Provider: Huy D. (Brandon) Tran, MD
# 200
# Provider Affil ERROR for Page: Edward A. Duckworth, MD
# 200
# Provider Affil ERROR for Page: Peter T. Kan, MD
# 200
# 200
# 200
# Provider Affil ERROR for Page: Todd C. Tenenholz, MD, PhD
# 200
# Provider Affil ERROR for Page: Kulsum Akbar, MD
# 200
# Provider Affil ERROR for Page: Oludayo Adedotun Adeyefa, MD
# 200
# Provider Affil ERROR for Page: Veena Basava, MD
# 200
# Provider Affil ERROR for Page: Tameka Michelle Broussard, MD
# 200
# Provider Affil ERROR for Page: George H. Denfield, MD
# 200
# Provider Affil ERROR for Page: Laurie N. Dykoski, MD
# 200
# Provider Affil ERROR for Page: Lewis I. Gottschalk, MD
# 200
# Provider Affil ERROR for Page: Jonas Scott Hafkin, MD
# 200
# Provider Affil ERROR for Page: Andrew Steven Itkin, MD
# 200
# Provider Affil ERROR for Page: Michelle D. Jordan, MD
# 200
# Provider Affil ERROR for Page: Kelly R. Katcher, MD
# 200
# Provider Affil ERROR for Page: Tony Guest Kim, MD
# 200
# Provider Affil ERROR for Page: Yasmin Natasha Lake, MD
# 200
# Provider Affil ERROR for Page: Neville S. Leibman, MD
# 200
# Provider Affil ERROR for Page: Susan Lynn Luehr, MD
# 200
# Provider Affil ERROR for Page: Mark Alan McMasters, MD
# 200
# Provider Affil ERROR for Page: Rakesh Narayan, MD
# 200
# Provider Affil ERROR for Page: Cenk Ozdogan, MD
# 200
# 200
# Provider Affil ERROR for Page: Chad A. Pedley, MD
# 200
# Provider Affil ERROR for Page: Suzanne G. Peltier, MD
# 200
# Provider Affil ERROR for Page: Frederick A. Rhodes, MD
# 200
# Provider Affil ERROR for Page: Eric P. Ritter, MD
# 200
# Provider Affil ERROR for Page: Derek M. Schoppa, MD
# 200
# 200
# Provider Affil ERROR for Page: Jo Hsu Tu, DO
# 200
# 200
# Provider Affil ERROR for Page: Odile Francoise Yacoub, MD

# %% [markdown]
# #### Check results

# %%
affil_df = pd.DataFrame(affil_list)
affil_df.head(20)
# Out:
#                 Location                            Name  \
# 0   Texas Medical Center     Adam C. Adler, MS, MD, FAAP
# 1   Texas Medical Center               Dheeraj Ahuja, MD
# 2   Texas Medical Center   Titilopemi A.O. Aina, MD, MPH
# 3   Texas Medical Center           Ayse Akcan-Arikan, MD
# 4   Texas Medical Center          Melanie Jeanne Alo, MD
# 5   Texas Medical Center         Marc Michael Anders, MD
# 6   Texas Medical Center   Dean B. Andropoulos, MD, MHCM
# 7   Texas Medical Center   Amy Sharon Arrington, MD, PhD
# 8   Texas Medical Center      Rahul Geetendra Baijal, MD
# 9   Texas Medical Center             Dalia A. Bashir, MD
# 10  Texas Medical Center                Aarti Bavare, MD
# 11  Texas Medical Center                  Saleh Bhar, MD
# 12  Texas Medical Center              Tamer Elattary, MD
# 13  Texas Medical Center          Ronald A. Bronicki, MD
# 14  Texas Medical Center         Katrin Ann Campbell, MD
# 15  Texas Medical Center  Carlos Javier Campos-Lopez, MD
# 16  Texas Medical Center              Lisa A. Caplan, MD
# 17  Texas Medical Center    Nicholas Patrick Carling, MD
# 18  Texas Medical Center                Danny Castro, DO
# 19  Texas Medical Center            Paul A. Checchia, MD
#
#                             OfficeAddress   OfficeCity  \
# 0     ['6621 Fannin Street--Suite A3300']  ['Houston']
# 1     ['6621 Fannin Street--Suite A3300']  ['Houston']
# 2     ['6621 Fannin Street--Suite A3300']  ['Houston']
# 3          ['6651 Main Street--MC E1420']  ['Houston']
# 4     ['6621 Fannin Street--Suite A3300']  ['Houston']
# 5          ['6651 Main Street--MC E1420']  ['Houston']
# 6     ['6621 Fannin Street--Suite A3300']  ['Houston']
# 7          ['6651 Main Street--MC E1420']  ['Houston']
# 8     ['6621 Fannin Street--Suite A3300']  ['Houston']
# 9          ['6651 Main Street--MC E1420']  ['Houston']
# 10         ['6651 Main Street--MC E1420']  ['Houston']
# 11  ['6701 Fannin Street, Suite 1510.09']  ['Houston']
# 12    ['6621 Fannin Street--Suite A3300']  ['Houston']
# 13         ['6651 Main Street--MC E1420']  ['Houston']
# 14    ['6621 Fannin Street--Suite A3300']  ['Houston']
# 15    ['6621 Fannin Street--Suite A3300']  ['Houston']
# 16    ['6621 Fannin Street--Suite A3300']  ['Houston']
# 17    ['6621 Fannin Street--Suite A3300']  ['Houston']
# 18         ['6651 Main Street--MC E1420']  ['Houston']
# 19         ['6651 Main Street--MC E1420']  ['Houston']
#
#                       OfficePhone OfficeState OfficeZip
# 0                  [832-824-5800]        [TX]   [77030]
# 1                  [832-824-5800]        [TX]   [77030]
# 2                  [832-824-5800]        [TX]   [77030]
# 3                  [832-826-6230]        [TX]   [77030]
# 4                  [832-824-5800]        [TX]   [77030]
# 5                  [832-826-6230]        [TX]   [77030]
# 6                  [832-824-5800]        [TX]   [77030]
# 7                  [832-826-5048]        [TX]   [77030]
# 8                  [832-824-5800]        [TX]   [77030]
# 9                  [832-822-6230]        [TX]   [77030]
# 10                 [832-826-6230]        [TX]   [77030]
# 11                 [832-822-4242]        [TX]   [77030]
# 12                 [832-824-5800]        [TX]   [77030]
# 13                 [832-826-6230]        [TX]   [77030]
# 14                 [832-824-5800]        [TX]   [77030]
# 15                 [832-824-5800]        [TX]   [77030]
# 16  [832-82-HEART (832) 824-3278]        [TX]   [77030]
# 17                 [832-824-5800]        [TX]   [77030]
# 18                 [832-826-6230]        [TX]   [77030]
# 19                 [832-826-6230]        [TX]   [77030]

# %%
# Merge affil data back to Roster
affil_specs_df = pd.merge(Site_df, affil_df, how = 'left', on = 'Name')
affil_specs_df.head(20)
# Out:
#                               Name       Specialty  \
# 0      Adam C. Adler, MS, MD, FAAP  Anesthesiology
# 1                Dheeraj Ahuja, MD  Anesthesiology
['6621 Fannin Street--Suite A3300']  ['Houston']
# 17    ['6621 Fannin Street--Suite A3300']  ['Houston']
# 18         ['6651 Main Street--MC E1420']  ['Houston']
# 19         ['6651 Main Street--MC E1420']  ['Houston']
#
#                       OfficePhone OfficeState OfficeZip
# 0                  [832-824-5800]        [TX]   [77030]
# 1                  [832-824-5800]        [TX]   [77030]
# 2                  [832-824-5800]        [TX]   [77030]
# 3                  [832-826-6230]        [TX]   [77030]
# 4                  [832-824-5800]        [TX]   [77030]
# 5                  [832-826-6230]        [TX]   [77030]
# 6                  [832-824-5800]        [TX]   [77030]
# 7                  [832-826-5048]        [TX]   [77030]
# 8                  [832-824-5800]        [TX]   [77030]
# 9                  [832-822-6230]        [TX]   [77030]
# 10                 [832-826-6230]        [TX]   [77030]
# 11                 [832-822-4242]        [TX]   [77030]
# 12                 [832-824-5800]        [TX]   [77030]
# 13                 [832-826-6230]        [TX]   [77030]
# 14                 [832-824-5800]        [TX]   [77030]
# 15                 [832-824-5800]        [TX]   [77030]
# 16  [832-82-HEART (832) 824-3278]        [TX]   [77030]
# 17                 [832-824-5800]        [TX]   [77030]
# 18                 [832-826-6230]        [TX]   [77030]
# 19                 [832-826-6230]        [TX]   [77030]

# %%
# write out results
from pandas import ExcelWriter
filename = 'TexasChildrensRosterAffilsRaw.xlsx'

with ExcelWriter(filename) as writer:
        affil_specs_df.to_excel(writer, sheet_name='TX_Childrens_RawRoster')

# %% [markdown]
# ### Split Names for NPI Search
#
# In order to cross reference the docs in our DB, we'll need to get their National Provider Number (NPI) from the NPPES website.
#
# CAVEAT: I'll use practive state and doc name to search, but there might be ambiguous serach results for docs with the same name.

# %%
#split name/degrees

# new data frame with split value columns 
new = affil_specs_df.Name.str.split(',', 1, expand = True) 
  
# making separate first name column from new data frame 
affil_specs_df['Name']= new[0] 
  
# making separate last name column from new data frame 
affil_specs_df['Degree']= new[1]

# %%
# new data frame with split value columns 
new = affil_specs_df.Name.str.split(' ', 1, expand = True) 
 
# making separate first name column from new data frame 
affil_specs_df['FirstName']= new[0] 

#split from right for last name
new2 = affil_specs_df["Name"].str.rsplit(" ", n = 1, expand = True) 

# making separate last name column from new data frame 
affil_specs_df['LastName']= new2[1]

# %%
affil_specs_df.head()
# Out:
#                    Name       Specialty  \
# 0         Adam C. Adler  Anesthesiology
# 1         Dheeraj Ahuja  Anesthesiology
# 2  Titilopemi A.O. Aina  Anesthesiology
# 3     Ayse Akcan-Arikan  Anesthesiology
# 4    Melanie Jeanne Alo  Anesthesiology
#
#                                      site              Location  \
# 0  /find-a-doctor/adam-c-adler-ms-md-faap  Texas Medical Center
# 1         /find-a-doctor/dheeraj-ahuja-md  Texas Medical Center
# 2    /find-a-doctor/titilopemi-ao-aina-md  Texas Medical Center
# 3     /find-a-doctor/ayse-akcan-arikan-md  Texas Medical Center
# 4    /find-a-doctor/melanie-jeanne-alo-md  Texas Medical Center
#
#                          OfficeAddress   OfficeCity     OfficePhone  \
# 0  ['6621 Fannin Street--Suite A3300']  ['Houston']  [832-824-5800]
# 1  ['6621 Fannin Street--Suite A3300']  ['Houston']  [832-824-5800]
# 2  ['6621 Fannin Street--Suite A3300']  ['Houston']  [832-824-5800]
# 3       ['6651 Main Street--MC E1420']  ['Houston']  [832-826-6230]
# 4  ['6621 Fannin Street--Suite A3300']  ['Houston']  [832-824-5800]
#
#   OfficeState OfficeZip         Degree   FirstName      LastName
# 0        [TX]   [77030]   MS, MD, FAAP        Adam         Adler
# 1        [TX]   [77030]             MD     Dheeraj         Ahuja
# 2        [TX]   [77030]        MD, MPH  Titilopemi          Aina
# 3        [TX]   [77030]             MD        Ayse  Akcan-Arikan
# 4        [TX]   [77030]             MD     Melanie           Alo

# %%
# write out results
from pandas import ExcelWriter
filename = 'TexasChildrensRosterAffilsRaw.xlsx'

with ExcelWriter(filename) as writer:
        affil_specs_df.to_excel(writer, sheet_name='TX_Childrens_RawRoster')

# %% [markdown]
# ### Get Prac NPIs (including address and specialty, by name and state)
#
# In order to get more specific NPI results/cross check them against the specialty listed on the hosp site, I'll query for doc address and specialty code as well

# %%
# Put it all together!
import pandas as pd
import json
import time
import requests
from bs4 import BeautifulSoup
import re
from pandas.io.json import json_normalize

def NPI_API_PROVIDER_NAME(dataframe, delay):
    NPI_API = pd.DataFrame(columns=['basic.first_name', 'basic.last_name','number',  'address_1', 'address_2', 'address_purpose', 'city', 'state', 'postal_code', 'telephone_number', 'fax_number', 'basic.enumeration_date', 'desc']) #initialize DataFrame
    seconds = delay #define seconds to wait between get requests
    
    for index, row in dataframe.iterrows():
        url_1 = 'https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name='
        url_first_name = row['FirstName']
        url_2 = '&use_first_name_alias=&last_name='
        url_last_name = row['LastName']
        url_3 = '&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=&country_code=&limit=&skip=&version=2.1'
        url = url_1+url_first_name+url_2+url_last_name+url_3
        print('Query url: '+ url)
        try:
            page = requests.get(url, time.sleep(seconds))
            #print(page.status_code) #for testing
            page_json = json.loads(page.content)
            df = pd.DataFrame.from_dict(json_normalize(page_json['results']), orient='columns') 
            addresses_with_NPI = pd.io.json.json_normalize(page_json['results'], record_path='addresses', meta=['number'])
            df_addresses = pd.merge(df, addresses_with_NPI, how='inner', on='number')
            columns_to_keep = ['basic.first_name', 'basic.last_name', 'number',  'address_1', 'address_2', 'address_purpose', 'city', 'state', 'postal_code', 'telephone_number', 'fax_number', 'basic.enumeration_date']
            df_addresses_subset = df_addresses.reindex(columns=columns_to_keep)
            taxonomies_with_NPI = pd.io.json.json_normalize(page_json['results'], record_path='taxonomies', meta=['number'])
            df_taxonomies = pd.merge(df_addresses_subset, taxonomies_with_NPI, how='inner', on=['number'])
            tax_columns_to_keep = ['basic.first_name', 'basic.last_name', 'number',  'desc','address_1', 'address_2', 'address_purpose', 'city', 'state', 'postal_code', 'telephone_number', 'fax_number', 'basic.enumeration_date']
            df_taxonomies_subset = df_taxonomies.reindex(columns=tax_columns_to_keep)
            #print(df_addresses_subset.head(1)) #for testing
            NPI_API = NPI_API.append(df_taxonomies_subset, ignore_index=True)
            #print(NPI_API.shape) #for testing
            print('NPI added for '+ url_first_name+' '+url_last_name)
        except:
            pass
            print('NPI ERROR for '+ url_first_name+' '+url_last_name)
    return(NPI_API)

# %%
#read in ambiNPIs
#this is the list of ambiguous NPIs to cross check against specialty
tx_childrens = pd.read_excel('TexasChildrensRosterAffilsRaw.xlsx')
tx_childrens.head()
# Out:
#                    Name       Specialty  \
# 0         Adam C. Adler  Anesthesiology
# 1         Dheeraj Ahuja  Anesthesiology
# 2  Titilopemi A.O. Aina  Anesthesiology
# 3     Ayse Akcan-Arikan  Anesthesiology
# 4    Melanie Jeanne Alo  Anesthesiology
#
#                                      site              Location  \
# 0  /find-a-doctor/adam-c-adler-ms-md-faap  Texas Medical Center
# 1         /find-a-doctor/dheeraj-ahuja-md  Texas Medical Center
# 2    /find-a-doctor/titilopemi-ao-aina-md  Texas Medical Center
# 3     /find-a-doctor/ayse-akcan-arikan-md  Texas Medical Center
# 4    /find-a-doctor/melanie-jeanne-alo-md  Texas Medical Center
#
#                          OfficeAddress   OfficeCity       OfficePhone  \
# 0  ['6621 Fannin Street--Suite A3300']  ['Houston']  ['832-824-5800']
# 1  ['6621 Fannin Street--Suite A3300']  ['Houston']  ['832-824-5800']
# 2  ['6621 Fannin Street--Suite A3300']  ['Houston']  ['832-824-5800']
# 3       ['6651 Main Street--MC E1420']  ['Houston']  ['832-826-6230']
# 4  ['6621 Fannin Street--Suite A3300']  ['Houston']  ['832-824-5800']
#
#   OfficeState  OfficeZip         Degree   FirstName      LastName
# 0      ['TX']  ['77030']   MS, MD, FAAP        Adam         Adler
# 1      ['TX']  ['77030']             MD     Dheeraj         Ahuja
# 2      ['TX']  ['77030']        MD, MPH  Titilopemi          Aina
# 3      ['TX']  ['77030']             MD        Ayse  Akcan-Arikan
# 4      ['TX']  ['77030']             MD     Melanie           Alo

# %%
tx_childrens.shape
# Out:
# (354, 12)

# %%
#get NPPES API results
npi_specs = NPI_API_PROVIDER_NAME(tx_childrens, 2)
# Out:
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Adam&use_first_name_alias=&last_name=Adler&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=&country_code=&limit=&skip=&version=2.1
# NPI added for Adam Adler
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Dheeraj&use_first_name_alias=&last_name=Ahuja&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=&country_code=&limit=&skip=&version=2.1
# NPI ERROR for Dheeraj Ahuja
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Titilopemi&use_first_name_alias=&last_name=Aina&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=&country_code=&limit=&skip=&version=2.1
# NPI ERROR for Titilopemi Aina
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Ayse&use_first_name_alias=&last_name=Akcan-Arikan&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=&country_code=&limit=&skip=&version=2.1
# NPI ERROR for Ayse Akcan-Arikan
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Melanie&use_first_name_alias=&last_name=Alo&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=&country_code=&limit=&skip=&version=2.1
# NPI added for Melanie Alo
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Marc&use_first_name_alias=&last_name=Anders&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=&country_code=&limit=&skip=&version=2.1
# NPI added for Marc Anders
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Dean&use_first_name_alias=&last_name=Andropoulos&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=&country_code=&limit=&skip=&version=2.1
# NPI added for Dean Andropoulos
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Amy&use_first_name_alias=&last_name=Arrington&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=&country_code=&limit=&skip=&version=2.1
# NPI added for Amy Arrington
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Rahul&use_first_name_alias=&last_name=Baijal&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=&country_code=&limit=&skip=&version=2.1
# NPI ERROR for Rahul Baijal
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Dalia&use_first_name_alias=&last_name=Bashir&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=&country_code=&limit=&skip=&version=2.1
# NPI added for Dalia Bashir
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Aarti&use_first_name_alias=&last_name=Bavare&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=&country_code=&limit=&skip=&version=2.1
# NPI added for Aarti Bavare
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Saleh&use_first_name_alias=&last_name=Bhar&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=&country_code=&limit=&skip=&version=2.1
# NPI added for Saleh Bhar
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Tamer&use_first_name_alias=&last_name=Elattary&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=&country_code=&limit=&skip=&version=2.1
# NPI added for Tamer Elattary
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Ronald&use_first_name_alias=&last_name=Bronicki&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=&country_code=&limit=&skip=&version=2.1
# NPI ERROR for Ronald Bronicki
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Katrin&use_first_name_alias=&last_name=Campbell&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=&country_code=&limit=&skip=&version=2.1
# NPI added for Katrin Campbell
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Carlos&use_first_name_alias=&last_name=Campos-Lopez&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=&country_code=&limit=&skip=&version=2.1
# NPI added for Carlos Campos-Lopez
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Lisa&use_first_name_alias=&last_name=Caplan&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=&country_code=&limit=&skip=&version=2.1
# NPI added for Lisa Caplan
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Nicholas&use_first_name_alias=&last_name=Carling&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=&country_code=&limit=&skip=&version=2.1
# NPI added for Nicholas Carling
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Danny&use_first_name_alias=&last_name=Castro&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=&country_code=&limit=&skip=&version=2.1
# NPI added for Danny Castro
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Paul&use_first_name_alias=&last_name=Checchia&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=&country_code=&limit=&skip=&version=2.1
# NPI ERROR for Paul Checchia
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Monica&use_first_name_alias=&last_name=Chen&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=&country_code=&limit=&skip=&version=2.1
# NPI added for Monica Chen
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Julia&use_first_name_alias=&last_name=Chen&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=&country_code=&limit=&skip=&version=2.1
# NPI added for
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Andrew&use_first_name_alias=&last_name=Itkin&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=&country_code=&limit=&skip=&version=2.1
# NPI added for Andrew Itkin
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Michelle&use_first_name_alias=&last_name=Jordan&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=&country_code=&limit=&skip=&version=2.1
# NPI added for Michelle Jordan
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Kelly&use_first_name_alias=&last_name=Katcher&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=&country_code=&limit=&skip=&version=2.1
# NPI added for Kelly Katcher
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Tony&use_first_name_alias=&last_name=Kim&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=&country_code=&limit=&skip=&version=2.1
# NPI added for Tony Kim
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Yasmin&use_first_name_alias=&last_name=Lake&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=&country_code=&limit=&skip=&version=2.1
# NPI added for Yasmin Lake
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Neville&use_first_name_alias=&last_name=Leibman&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=&country_code=&limit=&skip=&version=2.1
# NPI added for Neville Leibman
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Susan&use_first_name_alias=&last_name=Luehr&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=&country_code=&limit=&skip=&version=2.1
# NPI added for Susan Luehr
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Mark&use_first_name_alias=&last_name=McMasters&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=&country_code=&limit=&skip=&version=2.1
# NPI added for Mark McMasters
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Rakesh&use_first_name_alias=&last_name=Narayan&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=&country_code=&limit=&skip=&version=2.1
# NPI added for Rakesh Narayan
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Cenk&use_first_name_alias=&last_name=Ozdogan&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=&country_code=&limit=&skip=&version=2.1
# NPI added for Cenk Ozdogan
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=George&use_first_name_alias=&last_name=Parker&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=&country_code=&limit=&skip=&version=2.1
# NPI added for George Parker
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Chad&use_first_name_alias=&last_name=Pedley&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=&country_code=&limit=&skip=&version=2.1
# NPI added for Chad Pedley
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Suzanne&use_first_name_alias=&last_name=Peltier&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=&country_code=&limit=&skip=&version=2.1
# NPI added for Suzanne Peltier
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Frederick&use_first_name_alias=&last_name=Rhodes&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=&country_code=&limit=&skip=&version=2.1
# NPI added for Frederick Rhodes
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Eric&use_first_name_alias=&last_name=Ritter&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=&country_code=&limit=&skip=&version=2.1
# NPI added for Eric Ritter
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Derek&use_first_name_alias=&last_name=Schoppa&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=&country_code=&limit=&skip=&version=2.1
# NPI added for Derek Schoppa
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Brandon&use_first_name_alias=&last_name=Thompson&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=&country_code=&limit=&skip=&version=2.1
# NPI added for Brandon Thompson
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Jo&use_first_name_alias=&last_name=Tu&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=&country_code=&limit=&skip=&version=2.1
# NPI added for Jo Tu
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Rolfe&use_first_name_alias=&last_name=Williams&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=&country_code=&limit=&skip=&version=2.1
# NPI added for Rolfe Williams
# Query url: https://npiregistry.cms.hhs.gov/api/?number=&enumeration_type=&taxonomy_description=&first_name=Odile&use_first_name_alias=&last_name=Yacoub&organization_name=&address_purpose=LOCATION&city=&state=TX&postal_code=&country_code=&limit=&skip=&version=2.1
# NPI added for Odile Yacoub

# %% [markdown]
# #### Data Carpentry

# %%
npi_specs = npi_specs[['basic.first_name', 'basic.last_name', 'number',  'desc','address_1', 'address_2', 'address_purpose', 'city', 'state', 'postal_code', 'telephone_number', 'fax_number', 'basic.enumeration_date']]
npi_specs
# Out:
#      basic.first_name basic.last_name      number  \
# 0                ADAM           ADLER  1104141886
# 1                ADAM           ADLER  1104141886
# 2                ADAM           ADLER  1104141886
# 3                ADAM           ADLER  1104141886
# 4                ADAM           ADLER  1104141886
# 5                ADAM           ADLER  1104141886
# 6             MELANIE             ALO  1689671240
# 7             MELANIE             ALO  1689671240
# 8                MARC          ANDERS  1053708503
# 9                MARC          ANDERS  1053708503
# 10               MARC          ANDERS  1053708503
# 11               MARC          ANDERS  1053708503
# 12               DEAN     ANDROPOULOS  1366449779
# 13               DEAN     ANDROPOULOS  1366449779
# 14                AMY       ARRINGTON  1144574591
# 15                AMY       ARRINGTON  1144574591
# 16              DALIA          BASHIR  1164652269
# 17              DALIA          BASHIR  1164652269
# 18              DALIA          BASHIR  1164652269
# 19              DALIA          BASHIR  1164652269
# 20              AARTI          BAVARE  1396911715
# 21              AARTI          BAVARE  1396911715
# 22              SALEH            BHAR  1457667529
# 23              SALEH            BHAR  1457667529
# 24              SALEH            BHAR  1457667529
# 25              SALEH            BHAR  1457667529
# 26              TAMER        ELATTARY  1427469980
# 27              TAMER        ELATTARY  1427469980
# 28             KATRIN        CAMPBELL  1700964046
# 29             KATRIN        CAMPBELL  1700964046
# 1126                                     Anesthesiology
# 1127                                     Anesthesiology
# 1128  Specialist/Technologist, Other Surgical Techno...
# 1129  Specialist/Technologist, Other Surgical Techno...
# 1130                                     Anesthesiology
# 1131                                     Anesthesiology
# 1132                                     Anesthesiology
# 1133                                     Anesthesiology
# 1134                                     Anesthesiology
# 1135                                     Anesthesiology
# 1136                                     Anesthesiology
# 1137                                     Anesthesiology
# 1138                                     Anesthesiology
# 1139                                     Anesthesiology
#
#                           address_1                 address_2 address_purpose  \
# 0                    6701 FANNIN ST                                  LOCATION
# 1                    6701 FANNIN ST                                  LOCATION
# 2                    6701 FANNIN ST                                  LOCATION
# 3                    2 GREENWAY PLZ                 SUITE 300         MAILING
# 4                    2 GREENWAY PLZ                 SUITE 300         MAILING
# 5                    2 GREENWAY PLZ                 SUITE 300         MAILING
# 6                       6621 FANNIN                                  LOCATION
# 7                TWO GREENWAY PLAZA                 SUITE 900         MAILING
# 8                    6621 FANNIN ST  SECTION OF CRITICAL CARE        LOCATION
# 9                    6621 FANNIN ST  SECTION OF CRITICAL CARE        LOCATION
# 10                   6621 FANNIN ST  SECTION OF CRITICAL CARE         MAILING
# 11                   6621 FANNIN ST  SECTION OF CRITICAL CARE         MAILING
# 12                   6621 FANNIN ST                                  LOCATION
# 13                 2 E GREENWAY PLZ                 SUITE 900         MAILING
# 14               6621 FANNIN, W6006                                  LOCATION
# 15               6621 FANNIN, W6006                                   MAILING
# 16                   6701 FANNIN ST                                  LOCATION
# 17                   6701 FANNIN ST                                  LOCATION
# 18    2450 HOLCOMBE BLVD STE NB-34L                                   MAILING
# 19    2450 HOLCOMBE BLVD STE NB-34L                                   MAILING
# 20             6621 FANNIN, WT6-006                                  LOCATION
# 21                 300 LONGWOOD AVE                                   MAILING
# 22                   6701 FANNIN ST                                  LOCATION
# 23                   6701 FANNIN ST                                  LOCATION
# 24           2 GREENWAY PLZ STE 300                                   MAILING
# 25           2 GREENWAY PLZ STE 300                                   MAILING
# 26                   6621 FANNIN ST                                  LOCATION
# 27     2828 OLD SPANISH TRL APT 468                                   MAILING
# 28                   6621 FANNIN ST                                  LOCATION
# 29                 2 E GREENWAY PLZ                 SUITE 900         MAILING
# ...                             ...                       ...             ...
# 1110             1500 CITYWEST BLVD                  STE. 300        LOCATION
# 1111                  PO BOX 650865                                   MAILING
# 1112          2411 FOUNTAIN VIEW DR                  STE. 200        LOCATION
# 1113          2411 FOUNTAIN VIEW DR                  STE. 200        LOCATION
# 1114          2411 FOUNTAIN VIEW DR                  STE. 200         MAILING
# 1115          2411 FOUNTAIN VIEW DR                  STE. 200         MAILING
# 1116             1500 CITYWEST BLVD                  STE. 300        LOCATION
# 1117                  PO BOX 650865                                   MAILING
# 1118               13601 PRESTON RD                 STE 1000W        LOCATION
# 1119                  PO BOX 840853                                   MAILING
# 1120             1500 CITYWEST BLVD                  STE. 300        LOCATION
# 1121             1500 CITYWEST BLVD                  STE. 300        LOCATION
# 1122             1500 CITYWEST BLVD                  STE. 300        LOCATION
# 1123                  PO BOX 650865                                   MAILING
# 1124                  PO BOX 650865                                   MAILING
# 1125                  PO BOX 650865                                   MAILING
# 1126             1500 CITYWEST BLVD                  STE. 300        LOCATION
# 1127                  PO BOX 650865                                   MAILING
# 1128                   7401 S. MAIN                                  LOCATION
# 1129                   7401 MAIN ST                                   MAILING
# 1130             1500 CITYWEST BLVD                  STE. 300        LOCATION
# 1131             1500 CITYWEST BLVD                  STE. 300        LOCATION
# 1132                  PO BOX 650865                                   MAILING
# 1133                  PO BOX 650865                                   MAILING
# 1134             1500 CITYWEST BLVD                  STE. 300        LOCATION
# 1135                  PO BOX 650865                                   MAILING
# 1136             1500 CITYWEST BLVD                  STE. 300        LOCATION
# 1137                  PO BOX 650865                                   MAILING
# 1138          2411 FOUNTAIN VIEW DR                 SUITE 200        LOCATION
# 1139  2411 FOUNTAIN VIEW DR STE 200                                   MAILING
#
#          city state postal_code telephone_number    fax_number  \
# 0     HOUSTON   NaN   770302608     832-824-1000           NaN
# 1     HOUSTON   NaN   770302608     832-824-1000           NaN
# 2     HOUSTON   NaN   770302608     832-824-1000           NaN
# 3     HOUSTON   NaN   770460297     832-828-3660           NaN
# 4     HOUSTON   NaN   770460297     832-828-3660           NaN
# 5     HOUSTON   NaN   770460297     832-828-3660           NaN
# 6     HOUSTON   NaN       77030     832-824-5800  832-825-5801
# 7     HOUSTON   NaN       77046     713-798-1750  713-798-1187
# 8     HOUSTON   NaN   770302358     832-824-1000           NaN
# 9     HOUSTON   NaN   770302358     832-824-1000           NaN
# 10    HOUSTON   NaN   770302358     832-824-1000           NaN
# 11    HOUSTON   NaN   770302358     832-824-1000           NaN
# 12    HOUSTON   NaN   770302303     832-824-5800  832-825-5801
# 13    HOUSTON   NaN   770460297     713-798-1750  713-798-1187
# 14    HOUSTON   NaN       77030     832-826-6230           NaN
# 15    HOUSTON   NaN       77030     832-826-6230           NaN
# 16    HOUSTON   NaN   770302608     832-824-1000           NaN
# 17    HOUSTON   NaN   770302608     832-824-1000           NaN
# 18    HOUSTON   NaN   770212039     832-828-3660           NaN
# 19    HOUSTON   NaN   770212039     832-828-3660           NaN
# 20    HOUSTON   NaN       77030     832-826-6230           NaN
# 21     BOSTON   NaN   021155724     617-355-7701           NaN
# 22    HOUSTON   NaN   770302608     832-824-1000           NaN
# 23    HOUSTON   NaN   770302608     832-824-1000           NaN
# 24    HOUSTON   NaN   770460207     832-828-3660           NaN
# 25    HOUSTON   NaN   770460207     832-828-3660           NaN
# 26    HOUSTON   NaN   770302358     716-343-5680           NaN
# 27    HOUSTON   NaN   770542258     716-343-5680           NaN
# 28    HOUSTON   NaN   770302303     832-824-5809           NaN
# 29    HOUSTON   NaN   770460297     713-798-1750  713-798-1144
# ...       ...   ...         ...              ...           ...
# 1110  HOUSTON   NaN   770422300     713-620-4000  713-458-4229
# 1111   DALLAS   NaN   752650865     972-233-1999  972-233-3666
# 1112  HOUSTON   NaN   770574817     713-620-4000           NaN
# 1113  HOUSTON   NaN   770574817     713-620-4000           NaN
# 1114  HOUSTON   NaN   770574817     713-620-4000           NaN
# 1115  HOUSTON   NaN   770574817     713-620-4000           NaN
# 1116  HOUSTON   NaN   770422300     713-620-4000  713-458-4229
# 1117   DALLAS   NaN   752650865     972-233-1999  972-233-3666
# 1118   DALLAS   NaN       75240     972-715-5000           NaN
# 1119   DALLAS   NaN   752840802     972-715-5000  972-233-3666
# 1120  HOUSTON   NaN   770422300     713-620-4000  713-458-4229
# 1121  HOUSTON   NaN   770422300     713-620-4000  713-458-4229
# 1122  HOUSTON   NaN   770422300     713-620-4000  713-458-4229
# 1123   DALLAS   NaN   752650865     972-233-1999  972-233-3666
# 1124   DALLAS   NaN   752650865     972-233-1999  972-233-3666
# 1125   DALLAS   NaN   752650865     972-233-1999  972-233-3666
# 1126  HOUSTON   NaN   770422300     713-620-4000  713-458-4229
# 1127   DALLAS   NaN   752650865     972-233-1999  972-233-3666
# 1128  HOUSTON   NaN       77030     713-799-2300  713-383-5201
# 1129  HOUSTON   NaN   770304509     713-799-2300  713-794-3380
# 1130  HOUSTON   NaN   770422300     713-620-4000  713-458-4229
# 1131  HOUSTON   NaN   770422300     713-620-4000  713-458-4229
# 1132   DALLAS   NaN   752650865     972-233-1999  972-233-3666
# 1133   DALLAS   NaN   752650865     972-233-1999  972-233-3666
# 1134  HOUSTON   NaN   770422300     713-620-4000  713-458-4229
# 1135   DALLAS   NaN   752650865     972-233-1999  972-233-3666
# 1136  HOUSTON   NaN   770422300     713-620-4000  713-458-4229
# 1137   DALLAS   NaN   752650865     972-233-1999  972-233-3666
# 1138  HOUSTON   NaN   770574817     713-458-4185           NaN
# 1139  HOUSTON   NaN   770574832     713-620-4000           NaN
#
#      basic.enumeration_date
# 0                2010-04-06
# 1                2010-04-06
# 2                2010-04-06
# 3                2010-04-06
# 4                2010-04-06
# 5                2010-04-06
# 6                2005-06-28
# 7                2005-06-28
# 8                2015-04-22
# 9                2015-04-22
# 10               2015-04-22
# 11               2015-04-22
# 12               2005-06-30
# 13               2005-06-30
# 14               2012-11-07
# 15               2012-11-07
# 16               2009-07-23
# 17               2009-07-23
# 18               2009-07-23
# 19               2009-07-23
# 20               2008-05-06
# 21               2008-05-06
# 22               2010-08-26
# 23               2010-08-26
# 24               2010-08-26
# 25               2010-08-26
# 26               2014-05-17
# 27               2014-05-17
# 28               2006-11-02
# 29               2006-11-02
# ...                     ...
# 1110             2007-01-16
# 1111             2007-01-16
# 1112             2009-02-19
# 1113             2009-02-19
# 1114             2009-02-19
# 1115             2009-02-19
# 1116             2007-01-16
# 1117             2007-01-16
# 1118             2006-03-08
# 1119             2006-03-08
# 1120             2008-07-25
# 1121             2008-07-25
# 1122             2008-07-25
# 1123             2008-07-25
# 1124             2008-07-25
# 1125             2008-07-25
# 1126             2007-01-18
# 1127             2007-01-18
# 1128             2005-10-27
# 1129             2005-10-27
# 1130             2008-06-26
# 1131             2008-06-26
# 1132             2008-06-26
# 1133             2008-06-26
# 1134             2007-01-24
# 1135             2007-01-24
# 1136             2007-01-30
# 1137             2007-01-30
# 1138             2007-01-24
# 1139             2007-01-24
#
# [1140 rows x 13 columns]

# %%
npi_specs_location = npi_specs.loc[npi_specs['address_purpose']=='LOCATION', ]
npi_specs_location.head()
# Out:
#   basic.first_name basic.last_name      number  \
# 0             ADAM           ADLER  1104141886
# 1             ADAM           ADLER  1104141886
# 2             ADAM           ADLER  1104141886
# 6          MELANIE             ALO  1689671240
# 8             MARC          ANDERS  1053708503
#
#                                                 desc       address_1  \
# 0                                     Anesthesiology  6701 FANNIN ST
# 1  Student in an Organized Health Care Education/...  6701 FANNIN ST
# 2            Anesthesiology Pediatric Anesthesiology  6701 FANNIN ST
# 6                                     Anesthesiology     6621 FANNIN
# 8               General Acute Care Hospital Children  6621 FANNIN ST
#
#                   address_2 address_purpose     city state postal_code  \
# 0                                  LOCATION  HOUSTON   NaN   770302608
# 1                                  LOCATION  HOUSTON   NaN   770302608
# 2                                  LOCATION  HOUSTON   NaN   770302608
# 6                                  LOCATION  HOUSTON   NaN       77030
# 8  SECTION OF CRITICAL CARE        LOCATION  HOUSTON   NaN   770302358
#
#   telephone_number    fax_number basic.enumeration_date
# 0     832-824-1000           NaN             2010-04-06
# 1     832-824-1000           NaN             2010-04-06
# 2     832-824-1000           NaN             2010-04-06
# 6     832-824-5800  832-825-5801             2005-06-28
# 8     832-824-1000           NaN             2015-04-22

# %%
npi_specs_location['FirstName'] = npi_specs_location['basic.first_name'].str.title()
npi_specs_location['LastName'] = npi_specs_location['basic.last_name'].str.title()

npi_specs_location.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   basic.first_name basic.last_name      number  \
# 0             ADAM           ADLER  1104141886
# 1             ADAM           ADLER  1104141886
# 2             ADAM           ADLER  1104141886
# 6          MELANIE             ALO  1689671240
# 8             MARC          ANDERS  1053708503
#
#                                                 desc       address_1  \
# 0                                     Anesthesiology  6701 FANNIN ST
# 1  Student in an Organized Health Care Education/...  6701 FANNIN ST
# 2            Anesthesiology Pediatric Anesthesiology  6701 FANNIN ST
# 6                                     Anesthesiology     6621 FANNIN
# 8               General Acute Care Hospital Children  6621 FANNIN ST
#
#                   address_2 address_purpose     city state postal_code  \
# 0                                  LOCATION  HOUSTON   NaN   770302608
# 1                                  LOCATION  HOUSTON   NaN   770302608
# 2                                  LOCATION  HOUSTON   NaN   770302608
# 6                                  LOCATION  HOUSTON   NaN       77030
# 8  SECTION OF CRITICAL CARE        LOCATION  HOUSTON   NaN   770302358
#
#   telephone_number    fax_number basic.enumeration_date FirstName LastName
# 0     832-824-1000           NaN             2010-04-06      Adam    Adler
# 1     832-824-1000           NaN             2010-04-06      Adam    Adler
# 2     832-824-1000           NaN             2010-04-06      Adam    Adler
# 6     832-824-5800  832-825-5801             2005-06-28   Melanie      Alo
# 8     832-824-1000           NaN             2015-04-22      Marc   Anders

# %%
#join NPIs back to affil roster
Texas_childrens_roster_npis = pd.merge(tx_childrens, npi_specs_location, how = 'left', on = ['FirstName', 'LastName'])
Texas_childrens_roster_npis.head(20)
# Out:
#                       Name       Specialty  \
# 0            Adam C. Adler  Anesthesiology
# 1            Adam C. Adler  Anesthesiology
# 2            Adam C. Adler  Anesthesiology
# 3            Dheeraj Ahuja  Anesthesiology
# 4     Titilopemi A.O. Aina  Anesthesiology
# 5        Ayse Akcan-Arikan  Anesthesiology
# 6       Melanie Jeanne Alo  Anesthesiology
# 7      Marc Michael Anders  Anesthesiology
# 8      Marc Michael Anders  Anesthesiology
# 9      Dean B. Andropoulos  Anesthesiology
# 10    Amy Sharon Arrington  Anesthesiology
# 11  Rahul Geetendra Baijal  Anesthesiology
# 12         Dalia A. Bashir  Anesthesiology
# 13         Dalia A. Bashir  Anesthesiology
# 14            Aarti Bavare  Anesthesiology
# 15              Saleh Bhar  Anesthesiology
# 16              Saleh Bhar  Anesthesiology
# 17          Tamer Elattary  Anesthesiology
# 18      Ronald A. Bronicki  Anesthesiology
# 19     Katrin Ann Campbell  Anesthesiology
#
#                                           site              Location  \
# 0       /find-a-doctor/adam-c-adler-ms-md-faap  Texas Medical Center
# 1       /find-a-doctor/adam-c-adler-ms-md-faap  Texas Medical Center
# 2       /find-a-doctor/adam-c-adler-ms-md-faap  Texas Medical Center
# 3              /find-a-doctor/dheeraj-ahuja-md  Texas Medical Center
# 4         /find-a-doctor/titilopemi-ao-aina-md  Texas Medical Center
# 5          /find-a-doctor/ayse-akcan-arikan-md  Texas Medical Center
# 6         /find-a-doctor/melanie-jeanne-alo-md  Texas Medical Center
# 7        /find-a-doctor/marc-michael-anders-md  Texas Medical Center
# 8        /find-a-doctor/marc-michael-anders-md  Texas Medical Center
# 9    /find-a-doctor/dean-b-andropoulos-md-mhcm  Texas Medical Center
# 10  /find-a-doctor/amy-sharon-arrington-md-phd  Texas Medical Center
# 11    /find-a-doctor/rahul-geetendra-baijal-md  Texas Medical Center
# 12              /find-a-doctor/dalia-bashir-md  Texas Medical Center
# 13              /find-a-doctor/dalia-bashir-md  Texas Medical Center
# 14              /find-a-doctor/aarti-bavare-md  Texas Medical Center
# 15                /find-a-doctor/saleh-bhar-md  Texas Medical Center
# 16                /find-a-doctor/saleh-bhar-md  Texas Medical Center
# 17            /find-a-doctor/tamer-elattary-md  Texas Medical Center
# 18           /find-a-doctor/ronald-bronicki-md  Texas Medical Center
# 19       /find-a-doctor/katrin-ann-campbell-md  Texas Medical Center
#
#                             OfficeAddress   OfficeCity       OfficePhone  \
# 0     ['6621 Fannin Street--Suite A3300']  ['Houston']  ['832-824-5800']
# 1     ['6621 Fannin Street--Suite A3300']  ['Houston']  ['832-824-5800']
# 2     ['6621 Fannin Street--Suite A3300']  ['Houston']  ['832-824-5800']
# 3     ['6621 Fannin Street--Suite A3300']  ['Houston']  ['832-824-5800']
# 4     ['6621 Fannin Street--Suite A3300']  ['Houston']  ['832-824-5800']
# 5          ['6651 Main Street--MC E1420']  ['Houston']  ['832-826-6230']
# 6     ['6621 Fannin Street--Suite A3300']  ['Houston']  ['832-824-5800']
# 7          ['6651 Main Street--MC E1420']  ['Houston']  ['832-826-6230']
# 8          ['6651 Main Street--MC E1420']  ['Houston']  ['832-826-6230']
# 9     ['6621 Fannin Street--Suite A3300']  ['Houston']  ['832-824-5800']
# 10         ['6651 Main Street--MC E1420']  ['Houston']  ['832-826-5048']
# 11    ['6621 Fannin Street--Suite A3300']  ['Houston']  ['832-824-5800']
# 12         ['6651 Main Street--MC E1420']  ['Houston']  ['832-822-6230']
# 13         ['6651 Main Street--MC E1420']  ['Houston']  ['832-822-6230']
# 14         ['6651 Main Street--MC E1420']  ['Houston']  ['832-826-6230']
# 15  ['6701 Fannin Street, Suite 1510.09']  ['Houston']  ['832-822-4242']
# 16  ['6701 Fannin Street, Suite 1510.09']  ['Houston']  ['832-822-4242']
# 17    ['6621 Fannin Street--Suite A3300']  ['Houston']  ['832-824-5800']
# 18         ['6651 Main Street--MC E1420']  ['Houston']  ['832-826-6230']
# 19    ['6621 Fannin Street--Suite A3300']  ['Houston']  ['832-824-5800']
#
#    OfficeState  OfficeZip         Degree          ...            \
# 0       ['TX']  ['77030']   MS, MD, FAAP          ...
# 1       ['TX']  ['77030']   MS, MD, FAAP          ...
# 2       ['TX']  ['77030']   MS, MD, FAAP          ...
# 3       ['TX']  ['77030']             MD          ...
# 4       ['TX']  ['77030']        MD, MPH          ...
# 5       ['TX']  ['77030']             MD          ...
# 6       ['TX']  ['77030']             MD          ...
# 7       ['TX']  ['77030']             MD          ...
# 8       ['TX']  ['77030']             MD          ...
# 9       ['TX']  ['77030']       MD, MHCM          ...
# 10      ['TX']  ['77030']        MD, PhD          ...
# 11      ['TX']  ['77030']             MD          ...
# 12      ['TX']  ['77030']             MD          ...
# 13      ['TX']  ['77030']             MD          ...
# 14      ['TX']  ['77030']             MD          ...
# 15      ['TX']  ['77030']             MD          ...
# 16      ['TX']  ['77030']             MD          ...
# 17      ['TX']  ['77030']             MD          ...
# 18      ['TX']  ['77030']             MD          ...
# 19      ['TX']  ['77030']             MD          ...
#
#                                                  desc             address_1  \
# 0                                      Anesthesiology        6701 FANNIN ST
# 1   Student in an Organized Health Care Education/...        6701 FANNIN ST
# 2             Anesthesiology Pediatric Anesthesiology        6701 FANNIN ST
# 3                                                 NaN                   NaN
# 4                                                 NaN                   NaN
# 5                                                 NaN                   NaN
# 6                                      Anesthesiology           6621 FANNIN
# 7                General Acute Care Hospital Children        6621 FANNIN ST
# 8         Pediatrics Pediatric Critical Care Medicine        6621 FANNIN ST
# 9                                      Anesthesiology        6621 FANNIN ST
# 10        Pediatrics Pediatric Critical Care Medicine    6621 FANNIN, W6006
# 11                                                NaN                   NaN
# 12                                         Pediatrics        6701 FANNIN ST
# 13        Pediatrics Pediatric Critical Care Medicine        6701 FANNIN ST
# 14        Pediatrics Pediatric Critical Care Medicine  6621 FANNIN, WT6-006
# 15  Student in an Organized Health Care Education/...        6701 FANNIN ST
# 16           Pediatrics Pediatric Hematology-Oncology        6701 FANNIN ST
# 17                                     Anesthesiology        6621 FANNIN ST
# 18                                                NaN                   NaN
# 19                                     Anesthesiology        6621 FANNIN ST
#
#                    address_2 address_purpose     city state postal_code  \
# 0                                   LOCATION  HOUSTON   NaN   770302608
# 1                                   LOCATION  HOUSTON   NaN   770302608
# 2                                   LOCATION  HOUSTON   NaN   770302608
# 3                        NaN             NaN      NaN   NaN         NaN
# 4                        NaN             NaN      NaN   NaN         NaN
# 5                        NaN             NaN      NaN   NaN         NaN
# 6                                   LOCATION  HOUSTON   NaN       77030
# 7   SECTION OF CRITICAL CARE        LOCATION  HOUSTON   NaN   770302358
# 8   SECTION OF CRITICAL CARE        LOCATION  HOUSTON   NaN   770302358
# 9                                   LOCATION  HOUSTON   NaN   770302303
# 10                                  LOCATION  HOUSTON   NaN       77030
# 11                       NaN             NaN      NaN   NaN         NaN
# 12                                  LOCATION  HOUSTON   NaN   770302608
# 13                                  LOCATION  HOUSTON   NaN   770302608
# 14                                  LOCATION  HOUSTON   NaN       77030
# 15                                  LOCATION  HOUSTON   NaN   770302608
# 16                                  LOCATION  HOUSTON   NaN   770302608
# 17                                  LOCATION  HOUSTON   NaN   770302358
# 18                       NaN             NaN      NaN   NaN         NaN
# 19                                  LOCATION  HOUSTON   NaN   770302303
#
#    telephone_number    fax_number basic.enumeration_date
# 0      832-824-1000           NaN             2010-04-06
# 1      832-824-1000           NaN             2010-04-06
# 2      832-824-1000           NaN             2010-04-06
# 3               NaN           NaN                    NaN
# 4               NaN           NaN                    NaN
# 5               NaN           NaN                    NaN
# 6      832-824-5800  832-825-5801             2005-06-28
# 7      832-824-1000           NaN             2015-04-22
# 8      832-824-1000           NaN             2015-04-22
# 9      832-824-5800  832-825-5801             2005-06-30
# 10     832-826-6230           NaN             2012-11-07
# 11              NaN           NaN                    NaN
# 12     832-824-1000           NaN             2009-07-23
# 13     832-824-1000           NaN             2009-07-23
# 14     832-826-6230           NaN             2008-05-06
# 15     832-824-1000           NaN             2010-08-26
# 16     832-824-1000           NaN             2010-08-26
# 17     716-343-5680           NaN             2014-05-17
# 18              NaN           NaN                    NaN
# 19     832-824-5809           NaN             2006-11-02
#
# [20 rows x 25 columns]

# %%
#write out file!
from pandas import ExcelWriter
filename = 'TexasChildrensNPIScrape.xlsx'

with ExcelWriter(filename) as writer:
       Texas_childrens_roster_npis.to_excel(writer, sheet_name='NPI_with_spec')
